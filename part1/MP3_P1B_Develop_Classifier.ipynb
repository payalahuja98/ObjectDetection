# %% [markdown]
# # Assignment 3 Part 1: Developing Your Own Classifier

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# # Check cuda version on colab and run the following PyTorch installation commands respectively.
# RUN IF 
# 1. RuntimeError: each element in list of batch should be of equal size

# Check cuda version on colab and run the following PyTorch installation commands respectively.
# !nvcc --version

# If CUDA 10.2 is installed
# !pip install torch==1.5.1 torchvision==0.6.1

# If CUDA 10.1 is installed 
# !pip install torch==1.5.1+cu101 torchvision==0.6.1+cu101 -f https://download.pytorch.org/whl/torch_stable.html

# If CUDA 9.2 is installed
# !pip install torch==1.5.1 torchvision==0.6.1

# If CUDA 10.1 is installed 
# !pip install torch==1.5.1+cu101 torchvision==0.6.1+cu101 -f https://download.pytorch.org/whl/torch_stable.html

# If CUDA 9.2 is installed
# !pip install torch==1.5.1+cu92 torchvision==0.6.1+cu92 -f https://download.pytorch.org/whl/torch_stable.htmlion
# !pip install torch==1.5.1+cu101 torchvision==0.6.1+cu101 -f https://download.pytorch.org/whl/torch_stable.html
# Out:
# nvcc: NVIDIA (R) Cuda compiler driver
# Copyright (c) 2005-2019 NVIDIA Corporation
# Built on Sun_Jul_28_19:07:16_PDT_2019
# Cuda compilation tools, release 10.1, V10.1.243
# Looking in links: https://download.pytorch.org/whl/torch_stable.html
# Collecting torch==1.5.1+cu101
#   Downloading https://download.pytorch.org/whl/cu101/torch-1.5.1%2Bcu101-cp36-cp36m-linux_x86_64.whl (704.4MB)
#      |████████████████████████████████| 704.4MB 25kB/s
# Collecting torchvision==0.6.1+cu101
#   Downloading https://download.pytorch.org/whl/cu101/torchvision-0.6.1%2Bcu101-cp36-cp36m-linux_x86_64.whl (6.6MB)
#      |████████████████████████████████| 6.6MB 5.0MB/s
# Requirement already satisfied: future in /usr/local/lib/python3.6/dist-packages (from torch==1.5.1+cu101) (0.16.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.6/dist-packages (from torch==1.5.1+cu101) (1.18.5)
# Requirement already satisfied: pillow>=4.1.1 in /usr/local/lib/python3.6/dist-packages (from torchvision==0.6.1+cu101) (7.0.0)
# Installing collected packages: torch, torchvision
#   Found existing installation: torch 1.7.0+cu101
#     Uninstalling torch-1.7.0+cu101:
#       Successfully uninstalled torch-1.7.0+cu101
#   Found existing installation: torchvision 0.8.1+cu101
#     Uninstalling torchvision-0.8.1+cu101:
#       Successfully uninstalled torchvision-0.8.1+cu101
# Successfully installed torch-1.5.1+cu101 torchvision-0.6.1+cu101

# %%
import os
os.chdir('/content/drive/My Drive/FA2020/CS498/assignment3_p1_starterkit.zip (Unzipped Files)/assignment3_p1_starterkit')
import numpy as np
import torch
import torch.nn as nn
import torchvision

from torchvision import transforms
from sklearn.metrics import average_precision_score
from PIL import Image, ImageDraw
import matplotlib.pyplot as plt
from kaggle_submission import output_submission_csv
# from classifier import SimpleClassifier, Classifier#, AlexNet
from voc_dataloader import VocDataset, VOC_CLASSES

from imgaug import augmenters as iaa
import imgaug as ia
import matplotlib.pyplot as plt

# %matplotlib inline
# %load_ext autoreload
# %autoreload 2

# %%
# !sh download_data.sh

# %%
import shutil 
shutil.copyfile("VOCtrainval_06-Nov-2007.tar", "/content/VOCtrainval_06-Nov-2007.tar")
# !tar -xf "/content/VOCtrainval_06-Nov-2007.tar" -C "/content/" 
shutil.move("/content/VOCdevkit/", "/content/VOCdevkit_2007")

shutil.copyfile("VOCtest_06-Nov-2007.tar", "/content/VOCtest_06-Nov-2007.tar")
# !tar -xf "/content/VOCtest_06-Nov-2007.tar" -C "/content/" 
shutil.move("/content/VOCdevkit/VOC2007", "/content/VOCdevkit_2007/VOC2007test")
# Out:
# '/content/VOCdevkit_2007/VOC2007test'

# %% [markdown]
# # Part 1B: Design your own network
#
# In this notebook, your task is to create and train your own model for multi-label classification on VOC Pascal.
#
# ## What to do
# 1. You will make change on network architecture in ```classifier.py```.
# 2. You may also want to change other hyperparameters to assist your training to get a better performances. Hints will be given in the below instructions.
#
# ## What to submit
# Check the submission template for details what to submit.

# %% [markdown]
# ## Classifier cell

# %%
import torch
import torch.nn as nn
from torch.autograd import Variable
import torch.nn.functional as F
from torch import optim
import numpy as np

NUM_CLASSES = 21

class Alexnet(nn.Module):
  def __init__(self):
      super(Alexnet, self).__init__()
      self.conv1 = nn.Conv2d(3, 64, kernel_size=5, padding=2)
      self.conv2 = nn.Conv2d(64, 192, kernel_size=5, padding=2)
      self.conv3 = nn.Conv2d(192, 384, kernel_size=3, padding=1)
      self.conv4 = nn.Conv2d(384, 256, kernel_size=3, padding=1)
      self.conv5 = nn.Conv2d(256, 256, kernel_size=3, padding=1)
      self.pool = nn.MaxPool2d(kernel_size=2)
      self.fc1 = nn.Linear(256 * 7 * 7, 4096)
      self.fc2 = nn.Linear(4096, 4096)
      self.fc3 = nn.Linear(4096, NUM_CLASSES)
      self.drop = nn.Dropout()

      self.bn1 = nn.BatchNorm2d(64)
      self.bn2 = nn.BatchNorm2d(192)
      self.bn3 = nn.BatchNorm2d(384)
      self.bn4 = nn.BatchNorm2d(256)

      # self.avgpool = nn.AdaptiveAvgPool2d((6, 6))
  def forward(self, x): 
      x = self.bn1(self.conv1(x))
      x = self.pool(F.relu(x))     
      x = self.bn2(self.conv2(x))
      x = self.pool(F.relu(x))
      x = self.bn3(self.conv3(x))
      x = self.pool(F.relu(x))
      x = self.bn4(self.conv4(x))
      x = self.pool(F.relu(x))
      x = self.pool(F.relu(self.conv5(x)))
      x = x.view(x.size()[0], 256 * 7 * 7)
      x = self.drop(x)
      x = F.relu(self.fc1(x))
      x = self.drop(x)
      x = F.relu(self.fc2(x))
      x = self.fc3(x)
      return x

      
class Classifier(nn.Module):
  # TODO: implement me
  def __init__(self):
      super(Classifier, self).__init__()
      # self.conv0 = nn.Conv2d(3, 256, 4)
      self.conv1 = nn.Conv2d(3, 128, 5)#in_channel, out_chafeatunnel, kernel
      self.conv2 = nn.Conv2d(128, 64, 5)#in_channel, out_chafeatunnel, kernel
      self.conv3 = nn.Conv2d(64, 32, 3)
      self.conv4 = nn.Conv2d(32, 16, 3)
      self.pool = nn.MaxPool2d(2, 2)
      self.fc1 = nn.Linear(16* 11 * 11, 120)
      self.fc2 = nn.Linear(120, 84)
      self.fc3 = nn.Linear(84, NUM_CLASSES)
      self.drop = nn.Dropout(0.2)
      
  
  def forward(self, x):

      # x = self.pool(F.relu(self.conv0(x)))

      x = self.pool(F.relu(self.conv1(x)))
      x = self.pool(F.relu(self.conv2(x)))
      x = self.pool(F.relu(self.conv3(x)))
      x = self.pool(F.relu(self.conv4(x)))
      # print('x size is', x.size())
      x = x.view(x.size()[0], 16* 11 * 11)
      x = F.relu(self.fc1(x))
      x = self.drop(x)
      x = F.relu(self.fc2(x))
      x = self.fc3(x)

      # x = self.pool(F.relu(self.conv1(x)))
      # x = self.pool(F.relu(self.conv2(x)))
      # x = self.pool(F.relu(self.conv3(x)))
      # x = x.view(x.size()[0], 16 * 26 * 26)
      # x = F.relu(self.fc1(x))
      # x = F.relu(self.fc2(x))
      # x = self.fc3(x)
      return x

# %%
def train_classifier(train_loader, classifier, criterion, optimizer):
    classifier.train()
    loss_ = 0.0
    losses = []
    for i, (images, labels, _) in enumerate(train_loader):
        # print(type(images), images.size())
        # images = images.permute(0, 3, 1, 2)
        images, labels = images.to(device), labels.to(device)
        optimizer.zero_grad()
        logits = classifier(images)
        loss = criterion(logits, labels)
        loss.backward()
        optimizer.step()
        losses.append(loss)
    return torch.stack(losses).mean().item()

# %%
def test_classifier(test_loader, classifier, criterion, print_ind_classes=True, print_total=True):
    classifier.eval()
    losses = []
    with torch.no_grad():
        y_true = np.zeros((0,21))
        y_score = np.zeros((0,21))
        for i, (images, labels, _) in enumerate(test_loader):
            # images = images.permute(0, 3, 1, 2)
            images, labels = images.to(device), labels.to(device)
            # print(type(images), images.size())

            logits = classifier(images)
            y_true = np.concatenate((y_true, labels.cpu().numpy()), axis=0)
            y_score = np.concatenate((y_score, logits.cpu().numpy()), axis=0)
            loss = criterion(logits, labels)
            losses.append(loss.item())
        aps = []
        # ignore first class which is background
        for i in range(1, y_true.shape[1]):
            ap = average_precision_score(y_true[:, i], y_score[:, i])
            if print_ind_classes:
                print('-------  Class: {:<12}     AP: {:>8.4f}  -------'.format(VOC_CLASSES[i], ap))
            aps.append(ap)
        
        mAP = np.mean(aps)
        test_loss = np.mean(losses)
        if print_total:
            print('mAP: {0:.4f}'.format(mAP))
            print('Avg loss: {}'.format(test_loss))
        
    return mAP, test_loss, aps

# %%
def plot_losses(train, val, test_frequency, num_epochs):
    plt.plot(train, label="train")
    indices = [i for i in range(num_epochs) if ((i+1)%test_frequency == 0 or i ==0)]
    plt.plot(indices, val, label="val")
    plt.title("Loss Plot")
    plt.ylabel("Loss")
    plt.xlabel("Epoch")
    plt.legend()
    plt.show()
    
def plot_mAP(train, val, test_frequency, num_epochs):
    indices = [i for i in range(num_epochs) if ((i+1)%test_frequency == 0 or i ==0)]
    plt.plot(indices, train, label="train")
    plt.plot(indices, val, label="val")
    plt.title("mAP Plot")
    plt.ylabel("mAP")
    plt.xlabel("Epoch")
    plt.legend()
    plt.show()

# %%
def train(classifier, num_epochs, train_loader, val_loader, criterion, optimizer, test_frequency=5):
    train_losses = []
    train_mAPs = []
    val_losses = []
    val_mAPs = []

    for epoch in range(1,num_epochs+1):
        print("Starting epoch number " + str(epoch))
        train_loss = train_classifier(train_loader, classifier, criterion, optimizer)
        train_losses.append(train_loss)
        print("Loss for Training on Epoch " +str(epoch) + " is "+ str(train_loss))
        if(epoch%test_frequency==0 or epoch==1):
            mAP_train, _, _ = test_classifier(train_loader, classifier, criterion, False, False)
            train_mAPs.append(mAP_train)
            mAP_val, val_loss, _ = test_classifier(val_loader, classifier, criterion)
            print('Evaluating classifier')
            print("Mean Precision Score for Testing on Epoch " +str(epoch) + " is "+ str(mAP_val))
            val_losses.append(val_loss)
            val_mAPs.append(mAP_val)
    
    return classifier, train_losses, val_losses, train_mAPs, val_mAPs

# %%
def ImageAugmentation():
  normalize = transforms.Normalize(mean=[0.485, 0.456, 0.406],
                                      std= [0.229, 0.224, 0.225])
  train_transform = transforms.Compose([
      transforms.Resize(227),
      transforms.ColorJitter(hue=.05, saturation=.05, brightness= 0.05, contrast = 0.05),
      transforms.RandomHorizontalFlip(),
      transforms.RandomRotation(20),
      transforms.CenterCrop(227),
      transforms.RandomVerticalFlip(),
      transforms.ToTensor(),
      normalize,
  ])
      
  # train_transform = ImgAugTransform()
  test_transform = transforms.Compose([
              transforms.Resize(227),
              transforms.CenterCrop(227),
              transforms.ToTensor(),
              normalize,
          ])

  ds_train = VocDataset('/content/VOCdevkit_2007/VOC2007','train',train_transform)
  ds_val = VocDataset('/content/VOCdevkit_2007/VOC2007','val',test_transform)
  return ds_train, ds_val

# %%
def ImageExtraction():
  device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

  normalize = transforms.Normalize(mean=[0.485, 0.456, 0.406],
                                      std= [0.229, 0.224, 0.225])

  train_transform = transforms.Compose([
              transforms.Resize(227),
              transforms.CenterCrop(227),
              transforms.ToTensor(),
              normalize
          ])

  test_transform = transforms.Compose([
              transforms.Resize(227),
              transforms.CenterCrop(227),
              transforms.ToTensor(),
              normalize,
          ])
  ds_train = VocDataset('/content/VOCdevkit_2007/VOC2007','train',train_transform)
  ds_val = VocDataset('/content/VOCdevkit_2007/VOC2007','val',test_transform)
  return ds_train, ds_val

# %% [markdown]
# # Developing Your Own Model

# %% [markdown]
# ### Goal
# To meet the benchmark for this assignment you will need to improve the network. Note you should have noticed pretrained Alenxt performs really well, but training Alexnet from scratch performs much worse. We hope you can design a better architecture over both the simple classifier and AlexNet to train from scratch.
#
# ### How to start
# You may take inspiration from other published architectures and architectures discussed in lecture. However, you are NOT allowed to use predefined models (e.g. models from torchvision) or use pretrained weights. Training must be done from scratch with your own custom model.
#
# #### Some hints
# There are a variety of different approaches you should try to improve performance from the simple classifier:
#
# * Network architecture changes
#     * Number of layers: try adding layers to make your network deeper
#     * Batch normalization: adding batch norm between layers will likely give you a significant performance increase
#     * Residual connections: as you increase the depth of your network, you will find that having residual connections like those in ResNet architectures will be helpful
# * Optimizer: Instead of plain SGD, you may want to add a learning rate schedule, add momentum, or use one of the other optimizers you have learned about like Adam. Check the `torch.optim` package for other optimizers
# * Data augmentation: You should use the `torchvision.transforms` module to try adding random resized crops and horizontal flips of the input data. Check `transforms.RandomResizedCrop` and `transforms.RandomHorizontalFlip` for this. Feel free to apply more [transforms](https://pytorch.org/docs/stable/torchvision/transforms.html) for data augmentation which can lead to better performance.
# * Epochs: Once you have found a generally good hyperparameter setting try training for more epochs
# * Loss function: You might want to add weighting to the `MultiLabelSoftMarginLoss` for classes that are less well represented or experiment with a different loss function
#
#
#
# #### Note
# We will soon be providing some initial expectations of mAP values as a function of epoch so you can get an early idea whether your implementation works without waiting a long time for training to converge.
#
# ### What to submit
# Submit your best model to Kaggle and save all plots for the writeup.

# %% [markdown]
# ## Train on Alexnet

# %%
num_epochs = 30
test_frequency = 5
batch_size = 64
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")


train_loader = torch.utils.data.DataLoader(dataset=ds_train,
                                               batch_size=batch_size, 
                                               shuffle=True,
                                               num_workers=1)

val_loader = torch.utils.data.DataLoader(dataset=ds_val,
                                               batch_size=batch_size, 
                                               shuffle=True,
                                               num_workers=1)

# test_loader = torch.utils.data.DataLoader(dataset=ds_test,
#                                                batch_size=batch_size, 
#                                                shuffle=False,
#                                                num_workers=1)

# %%
# TODO: Run your own classifier here
classifier = Alexnet().to(device)

criterion = nn.MultiLabelSoftMarginLoss()
optimizer = torch.optim.SGD(classifier.parameters(), lr=0.01, momentum=0.9)
# optimizer = torch.optim.Adam(classifier.parameters(), lr=1e-4)

classifier, train_losses, val_losses, train_mAPs, val_mAPs = train(classifier, num_epochs, train_loader, val_loader, criterion, optimizer, test_frequency)
# Out:
# Starting epoch number 1
# Loss for Training on Epoch 1 is 0.33032509684562683
# -------  Class: aeroplane        AP:   0.0500  -------
# -------  Class: bicycle          AP:   0.0678  -------
# -------  Class: bird             AP:   0.0926  -------
# -------  Class: boat             AP:   0.0457  -------
# -------  Class: bottle           AP:   0.0475  -------
# -------  Class: bus              AP:   0.0389  -------
# -------  Class: car              AP:   0.1396  -------
# -------  Class: cat              AP:   0.0688  -------
# -------  Class: chair            AP:   0.1131  -------
# -------  Class: cow              AP:   0.0494  -------
# -------  Class: diningtable      AP:   0.0521  -------
# -------  Class: dog              AP:   0.0869  -------
# -------  Class: horse            AP:   0.0703  -------
# -------  Class: motorbike        AP:   0.0464  -------
# -------  Class: person           AP:   0.4348  -------
# -------  Class: pottedplant      AP:   0.0675  -------
# -------  Class: sheep            AP:   0.0403  -------
# -------  Class: sofa             AP:   0.0751  -------
# -------  Class: train            AP:   0.0872  -------
# -------  Class: tvmonitor        AP:   0.0403  -------
# mAP: 0.0857
# Avg loss: 0.24106169156730176
# Evaluating classifier
# Mean Precision Score for Testing on Epoch 1 is 0.08570964895874476
# Starting epoch number 2
# Loss for Training on Epoch 2 is 0.23896947503089905
# Starting epoch number 3
# Loss for Training on Epoch 3 is 0.2359629124403
# Starting epoch number 4
# Loss for Training on Epoch 4 is 0.2329976111650467
# Starting epoch number 5
# Loss for Training on Epoch 5 is 0.23102298378944397
# -------  Class: aeroplane        AP:   0.2795  -------
# -------  Class: bicycle          AP:   0.1140  -------
# -------  Class: bird             AP:   0.1104  -------
# -------  Class: boat             AP:   0.0925  -------
# -------  Class: bottle           AP:   0.0714  -------
# -------  Class: bus              AP:   0.0854  -------
# -------  Class: car              AP:   0.2369  -------
# -------  Class: cat              AP:   0.1769  -------
# -------  Class: chair            AP:   0.2094  -------
# -------  Class: cow              AP:   0.0438  -------
# -------  Class: diningtable      AP:   0.1145  -------
# -------  Class: dog              AP:   0.1422  -------
# -------  Class: horse            AP:   0.1087  -------
# -------  Class: motorbike        AP:   0.1170  -------
# -------  Class: person           AP:   0.5035  -------
# -------  Class: pottedplant      AP:   0.1109  -------
# -------  Class: sheep            AP:   0.0601  -------
# -------  Class: sofa             AP:   0.1582  -------
# -------  Class: train            AP:   0.1220  -------
# -------  Class: tvmonitor        AP:   0.0545  -------
# mAP: 0.1456
# Avg loss: 0.2357583999633789
# Evaluating classifier
# Mean Precision Score for Testing on Epoch 5 is 0.1455875949417629
# Starting epoch number 6
# Loss for Training on Epoch 6 is 0.22839680314064026
# Starting epoch number 7
# Loss for Training on Epoch 7 is 0.22528770565986633
# Starting epoch number 8
# Loss for Training on Epoch 8 is 0.2210414856672287
# Starting epoch number 9
# Loss for Training on Epoch 9 is 0.2194935381412506
# Starting epoch number 10
# Loss for Training on Epoch 10 is 0.21671615540981293
# -------  Class: aeroplane        AP:   0.4021  -------
# -------  Class: bicycle          AP:   0.1192  -------
# -------  Class: bird             AP:   0.1190  -------
# -------  Class: boat             AP:   0.1838  -------
# -------  Class: bottle           AP:   0.0875  -------
# -------  Class: bus              AP:   0.1147  -------
# -------  Class: car              AP:   0.3237  -------
# -------  Class: cat              AP:   0.2381  -------
# -------  Class: chair            AP:   0.2569  -------
# -------  Class: cow              AP:   0.0426  -------
# -------  Class: diningtable      AP:   0.1833  -------
# -------  Class: dog              AP:   0.1640  -------
# -------  Class: horse            AP:   0.1069  -------
# -------  Class: motorbike        AP:   0.1710  -------
# -------  Class: person           AP:   0.5706  -------
# -------  Class: pottedplant      AP:   0.1014  -------
# -------  Class: sheep            AP:   0.0852  -------
# -------  Class: sofa             AP:   0.1560  -------
# -------  Class: train            AP:   0.1394  -------
# -------  Class: tvmonitor        AP:   0.0823  -------
# mAP: 0.1824
# Avg loss: 0.2252420622855425
# Evaluating classifier
# Mean Precision Score for Testing on Epoch 10 is 0.18238450298724115
# Starting epoch number 11
# Loss for Training on Epoch 11 is 0.21391642093658447
# Starting epoch number 12
# Loss for Training on Epoch 12 is 0.2124878168106079
# Starting epoch number 13
# Loss for Training on Epoch 13 is 0.21210840344429016
# Starting epoch number 14
# Loss for Training on Epoch 14 is 0.20953893661499023
# Starting epoch number 15
# Loss for Training on Epoch 15 is 0.21018938720226288
# -------  Class: aeroplane        AP:   0.4087  -------
# -------  Class: bicycle          AP:   0.1458  -------
# -------  Class: bird             AP:   0.1433  -------
# -------  Class: boat             AP:   0.1689  -------
# -------  Class: bottle           AP:   0.0980  -------
# -------  Class: bus              AP:   0.1044  -------
# -------  Class: car              AP:   0.3777  -------
# -------  Class: cat              AP:   0.2566  -------
# -------  Class: chair            AP:   0.2417  -------
# -------  Class: cow              AP:   0.0594  -------
# -------  Class: diningtable      AP:   0.1581  -------
# -------  Class: dog              AP:   0.1843  -------
# -------  Class: horse            AP:   0.2365  -------
# -------  Class: motorbike        AP:   0.2003  -------
# -------  Class: person           AP:   0.5968  -------
# -------  Class: pottedplant      AP:   0.1028  -------
# -------  Class: sheep            AP:   0.1075  -------
# -------  Class: sofa             AP:   0.1668  -------
# -------  Class: train            AP:   0.1779  -------
# -------  Class: tvmonitor        AP:   0.0935  -------
# mAP: 0.2014
# Avg loss: 0.2323048047721386
# Evaluating classifier
# Mean Precision Score for Testing on Epoch 15 is 0.20144441334594726
# Starting epoch number 16
# Loss for Training on Epoch 16 is 0.2075316160917282
# Starting epoch number 17
# Loss for Training on Epoch 17 is 0.20595505833625793
# Starting epoch number 18
# Loss for Training on Epoch 18 is 0.20430783927440643
# Starting epoch number 19
# Loss for Training on Epoch 19 is 0.20273876190185547
# Starting epoch number 20
# Loss for Training on Epoch 20 is 0.20376692712306976
# -------  Class: aeroplane        AP:   0.4102  -------
# -------  Class: bicycle          AP:   0.2023  -------
# -------  Class: bird             AP:   0.1800  -------
# -------  Class: boat             AP:   0.1996  -------
# -------  Class: bottle           AP:   0.1040  -------
# -------  Class: bus              AP:   0.1199  -------
# -------  Class: car              AP:   0.4370  -------
# -------  Class: cat              AP:   0.2781  -------
# -------  Class: chair            AP:   0.2756  -------
# -------  Class: cow              AP:   0.0805  -------
# -------  Class: diningtable      AP:   0.1841  -------
# -------  Class: dog              AP:   0.1895  -------
# -------  Class: horse            AP:   0.3058  -------
# -------  Class: motorbike        AP:   0.1835  -------
# -------  Class: person           AP:   0.6133  -------
# -------  Class: pottedplant      AP:   0.1056  -------
# -------  Class: sheep            AP:   0.1441  -------
# -------  Class: sofa             AP:   0.1885  -------
# -------  Class: train            AP:   0.2030  -------
# -------  Class: tvmonitor        AP:   0.0983  -------
# mAP: 0.2252
# Avg loss: 0.21847862601280213
# Evaluating classifier
# Mean Precision Score for Testing on Epoch 20 is 0.2251533816420896
# Starting epoch number 21
# Loss for Training on Epoch 21 is 0.20143058896064758
# Starting epoch number 22
# Loss for Training on Epoch 22 is 0.20519088208675385
# Starting epoch number 23
# Loss for Training on Epoch 23 is 0.200475811958313
# Starting epoch number 24
# Loss for Training on Epoch 24 is 0.1995449811220169
# Starting epoch number 25
# Loss for Training on Epoch 25 is 0.1984148472547531
# -------  Class: aeroplane        AP:   0.4295  -------
# -------  Class: bicycle          AP:   0.2449  -------
# -------  Class: bird             AP:   0.1778  -------
# -------  Class: boat             AP:   0.2123  -------
# -------  Class: bottle           AP:   0.1154  -------
# -------  Class: bus              AP:   0.1462  -------
# -------  Class: car              AP:   0.4468  -------
# -------  Class: cat              AP:   0.2664  -------
# -------  Class: chair            AP:   0.2897  -------
# -------  Class: cow              AP:   0.1031  -------
# -------  Class: diningtable      AP:   0.2001  -------
# -------  Class: dog              AP:   0.2002  -------
# -------  Class: horse            AP:   0.3273  -------
# -------  Class: motorbike        AP:   0.1810  -------
# -------  Class: person           AP:   0.6214  -------
# -------  Class: pottedplant      AP:   0.1220  -------
# -------  Class: sheep            AP:   0.1446  -------
# -------  Class: sofa             AP:   0.1812  -------
# -------  Class: train            AP:   0.2160  -------
# -------  Class: tvmonitor        AP:   0.1295  -------
# mAP: 0.2378
# Avg loss: 0.2152755033224821
# Evaluating classifier
# Mean Precision Score for Testing on Epoch 25 is 0.23777092602609443
# Starting epoch number 26
# Loss for Training on Epoch 26 is 0.1986525058746338
# Starting epoch number 27
# Loss for Training on Epoch 27 is 0.19728925824165344
# Starting epoch number 28
# Loss for Training on Epoch 28 is 0.19769446551799774
# Starting epoch number 29
# Loss for Training on Epoch 29 is 0.19494716823101044
# Starting epoch number 30
# Loss for Training on Epoch 30 is 0.19670866429805756
# -------  Class: aeroplane        AP:   0.4600  -------
# -------  Class: bicycle          AP:   0.2737  -------
# -------  Class: bird             AP:   0.1859  -------
# -------  Class: boat             AP:   0.2167  -------
# -------  Class: bottle           AP:   0.1150  -------
# -------  Class: bus              AP:   0.1618  -------
# -------  Class: car              AP:   0.4857  -------
# -------  Class: cat              AP:   0.2848  -------
# -------  Class: chair            AP:   0.2709  -------
# -------  Class: cow              AP:   0.1229  -------
# -------  Class: diningtable      AP:   0.1780  -------
# -------  Class: dog              AP:   0.2089  -------
# -------  Class: horse            AP:   0.3217  -------
# -------  Class: motorbike        AP:   0.1946  -------
# -------  Class: person           AP:   0.6495  -------
# -------  Class: pottedplant      AP:   0.1161  -------
# -------  Class: sheep            AP:   0.1294  -------
# -------  Class: sofa             AP:   0.1835  -------
# -------  Class: train            AP:   0.2457  -------
# -------  Class: tvmonitor        AP:   0.1445  -------
# mAP: 0.2475
# Avg loss: 0.21788416393101215
# Evaluating classifier
# Mean Precision Score for Testing on Epoch 30 is 0.24746576500009193

# %% [markdown]
# # Image Augmentation
# - I trained the model with Classifier first, then AlexNet

# %%
ds_train, ds_val = ImageAugmentation()

normalize = transforms.Normalize(mean=[0.485, 0.456, 0.406],
                                     std= [0.229, 0.224, 0.225])
test_transform = transforms.Compose([
            transforms.Resize(227),
            transforms.CenterCrop(227),
            transforms.ToTensor(),
            normalize,
        ])
ds_test = VocDataset('/content/VOCdevkit_2007/VOC2007test/','test', test_transform)
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

# %%
num_epochs = 5
test_frequency = 5
batch_size = 64


train_loader = torch.utils.data.DataLoader(dataset=ds_train,
                                               batch_size=batch_size, 
                                               shuffle=True,
                                               num_workers=1)

val_loader = torch.utils.data.DataLoader(dataset=ds_val,
                                               batch_size=batch_size, 
                                               shuffle=True,
                                               num_workers=1)

test_loader = torch.utils.data.DataLoader(dataset=ds_test,
                                               batch_size=batch_size, 
                                               shuffle=False,
                                               num_workers=1)

# %%
# TODO: Run your own classifier here
classifier = Classifier().to(device)

criterion = nn.MultiLabelSoftMarginLoss()
optimizer = torch.optim.SGD(classifier.parameters(), lr=0.01, momentum=0.9)
# optimizer = torch.optim.Adam(classifier.parameters(), lr=1e-4)

classifier, train_losses, val_losses, train_mAPs, val_mAPs = train(classifier, num_epochs, train_loader, val_loader, criterion, optimizer, test_frequency)
# Out:
# Starting epoch number 1
# Loss for Training on Epoch 1 is 0.6768534779548645
# -------  Class: aeroplane        AP:   0.0972  -------
# -------  Class: bicycle          AP:   0.0486  -------
# -------  Class: bird             AP:   0.0751  -------
# -------  Class: boat             AP:   0.0891  -------
# -------  Class: bottle           AP:   0.0426  -------
# -------  Class: bus              AP:   0.0279  -------
# -------  Class: car              AP:   0.1115  -------
# -------  Class: cat              AP:   0.0615  -------
# -------  Class: chair            AP:   0.1155  -------
# -------  Class: cow              AP:   0.0315  -------
# -------  Class: diningtable      AP:   0.0557  -------
# -------  Class: dog              AP:   0.1154  -------
# -------  Class: horse            AP:   0.0615  -------
# -------  Class: motorbike        AP:   0.0370  -------
# -------  Class: person           AP:   0.4607  -------
# -------  Class: pottedplant      AP:   0.0415  -------
# -------  Class: sheep            AP:   0.0294  -------
# -------  Class: sofa             AP:   0.0940  -------
# -------  Class: train            AP:   0.0392  -------
# -------  Class: tvmonitor        AP:   0.0530  -------
# mAP: 0.0844
# Avg loss: 0.643744507431984
# Evaluating classifier
# Mean Precision Score for Testing on Epoch 1 is 0.08440263440011973
# Starting epoch number 2
# Loss for Training on Epoch 2 is 0.39103057980537415
# Starting epoch number 3
# Loss for Training on Epoch 3 is 0.24739901721477509
# Starting epoch number 4

# %% [markdown]
# # AlexNet with batchnorm

# %%
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

normalize = transforms.Normalize(mean=[0.485, 0.456, 0.406],
                                     std= [0.229, 0.224, 0.225])

train_transform = transforms.Compose([
            transforms.Resize(227),
            transforms.CenterCrop(227),
            transforms.ToTensor(),
            normalize
        ])

test_transform = transforms.Compose([
            transforms.Resize(227),
            transforms.CenterCrop(227),
            transforms.ToTensor(),
            normalize,
        ])
ds_train = VocDataset('/content/VOCdevkit_2007/VOC2007','train',train_transform)
ds_val = VocDataset('/content/VOCdevkit_2007/VOC2007','val',test_transform)

# %% [markdown]
# ### epochs = 5

# %%
num_epochs = 5
test_frequency = 5
batch_size = 64

train_loader = torch.utils.data.DataLoader(dataset=ds_train,
                                               batch_size=batch_size, 
                                               shuffle=True,
                                               num_workers=1)

val_loader = torch.utils.data.DataLoader(dataset=ds_val,
                                               batch_size=batch_size, 
                                               shuffle=True,
                                               num_workers=1)

test_loader = torch.utils.data.DataLoader(dataset=ds_test,
                                               batch_size=batch_size, 
                                               shuffle=False,
                                               num_workers=1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-11-c1821d93e41f> in <module>()
#      13                                                num_workers=1)
#      14
# ---> 15 test_loader = torch.utils.data.DataLoader(dataset=ds_test,
#      16                                                batch_size=batch_size,
#      17                                                shuffle=False,
#
# NameError: name 'ds_test' is not defined

# %%
# TODO: Run your own classifier here
classifier = Alexnet().to(device)

criterion = nn.MultiLabelSoftMarginLoss()
optimizer = torch.optim.SGD(classifier.parameters(), lr=0.01, momentum=0.9)
# optimizer = torch.optim.Adam(classifier.parameters(), lr=1e-4)

classifier, train_losses, val_losses, train_mAPs, val_mAPs = train(classifier, num_epochs, train_loader, val_loader, criterion, optimizer, test_frequency)
# Out:
# Starting epoch number 1
# Loss for Training on Epoch 1 is 0.33617305755615234
# -------  Class: aeroplane        AP:   0.0812  -------
# -------  Class: bicycle          AP:   0.0550  -------
# -------  Class: bird             AP:   0.1124  -------
# -------  Class: boat             AP:   0.0513  -------
# -------  Class: bottle           AP:   0.0477  -------
# -------  Class: bus              AP:   0.0424  -------
# -------  Class: car              AP:   0.1489  -------
# -------  Class: cat              AP:   0.0745  -------
# -------  Class: chair            AP:   0.1133  -------
# -------  Class: cow              AP:   0.0450  -------
# -------  Class: diningtable      AP:   0.0534  -------
# -------  Class: dog              AP:   0.0895  -------
# -------  Class: horse            AP:   0.0646  -------
# -------  Class: motorbike        AP:   0.0388  -------
# -------  Class: person           AP:   0.4901  -------
# -------  Class: pottedplant      AP:   0.0619  -------
# -------  Class: sheep            AP:   0.0373  -------
# -------  Class: sofa             AP:   0.0767  -------
# -------  Class: train            AP:   0.0874  -------
# -------  Class: tvmonitor        AP:   0.0415  -------
# mAP: 0.0906
# Avg loss: 0.23904067911207677
# Evaluating classifier
# Mean Precision Score for Testing on Epoch 1 is 0.09064846625881454
# Starting epoch number 2
# Loss for Training on Epoch 2 is 0.23674093186855316
# Starting epoch number 3
# Loss for Training on Epoch 3 is 0.2348107546567917
# Starting epoch number 4
# Loss for Training on Epoch 4 is 0.2351686805486679
# Starting epoch number 5
# Loss for Training on Epoch 5 is 0.2286156713962555
# -------  Class: aeroplane        AP:   0.2982  -------
# -------  Class: bicycle          AP:   0.1265  -------
# -------  Class: bird             AP:   0.1557  -------
# -------  Class: boat             AP:   0.1859  -------
# -------  Class: bottle           AP:   0.0936  -------
# -------  Class: bus              AP:   0.1098  -------
# -------  Class: car              AP:   0.2709  -------
# -------  Class: cat              AP:   0.1790  -------
# -------  Class: chair            AP:   0.2227  -------
# -------  Class: cow              AP:   0.0468  -------
# -------  Class: diningtable      AP:   0.1547  -------
# -------  Class: dog              AP:   0.1650  -------
# -------  Class: horse            AP:   0.1164  -------
# -------  Class: motorbike        AP:   0.1187  -------
# -------  Class: person           AP:   0.5295  -------
# -------  Class: pottedplant      AP:   0.1248  -------
# -------  Class: sheep            AP:   0.0607  -------
# -------  Class: sofa             AP:   0.1577  -------
# -------  Class: train            AP:   0.2397  -------
# -------  Class: tvmonitor        AP:   0.0702  -------
# mAP: 0.1713
# Avg loss: 0.22753635719418525
# Evaluating classifier
# Mean Precision Score for Testing on Epoch 5 is 0.17133469806045426

# %% [markdown]
# ### epochs = 30

# %%
num_epochs = 30
test_frequency = 5
batch_size = 64


train_loader = torch.utils.data.DataLoader(dataset=ds_train,
                                               batch_size=batch_size, 
                                               shuffle=True,
                                               num_workers=1)

val_loader = torch.utils.data.DataLoader(dataset=ds_val,
                                               batch_size=batch_size, 
                                               shuffle=True,
                                               num_workers=1)

# TODO: Run your own classifier here
classifier = Alexnet().to(device)

criterion = nn.MultiLabelSoftMarginLoss()
optimizer = torch.optim.SGD(classifier.parameters(), lr=0.01, momentum=0.9)
# optimizer = torch.optim.Adam(classifier.parameters(), lr=1e-4)

classifier, train_losses, val_losses, train_mAPs, val_mAPs = train(classifier, num_epochs, train_loader, val_loader, criterion, optimizer, test_frequency)
# Out:
# Starting epoch number 1
# Loss for Training on Epoch 1 is 0.33533772826194763
# -------  Class: aeroplane        AP:   0.0567  -------
# -------  Class: bicycle          AP:   0.0546  -------
# -------  Class: bird             AP:   0.0871  -------
# -------  Class: boat             AP:   0.0406  -------
# -------  Class: bottle           AP:   0.0540  -------
# -------  Class: bus              AP:   0.0392  -------
# -------  Class: car              AP:   0.1349  -------
# -------  Class: cat              AP:   0.0812  -------
# -------  Class: chair            AP:   0.1278  -------
# -------  Class: cow              AP:   0.0421  -------
# -------  Class: diningtable      AP:   0.0628  -------
# -------  Class: dog              AP:   0.0936  -------
# -------  Class: horse            AP:   0.0649  -------
# -------  Class: motorbike        AP:   0.0432  -------
# -------  Class: person           AP:   0.4884  -------
# -------  Class: pottedplant      AP:   0.0651  -------
# -------  Class: sheep            AP:   0.0294  -------
# -------  Class: sofa             AP:   0.0846  -------
# -------  Class: train            AP:   0.0788  -------
# -------  Class: tvmonitor        AP:   0.0443  -------
# mAP: 0.0887
# Avg loss: 0.24322208464145662
# Evaluating classifier
# Mean Precision Score for Testing on Epoch 1 is 0.08867551372241986
# Starting epoch number 2
# Loss for Training on Epoch 2 is 0.24006377160549164
# Starting epoch number 3
# Loss for Training on Epoch 3 is 0.23758037388324738
# Starting epoch number 4
# Loss for Training on Epoch 4 is 0.23555593192577362
# Starting epoch number 5
# Loss for Training on Epoch 5 is 0.2300187200307846
# -------  Class: aeroplane        AP:   0.2862  -------
# -------  Class: bicycle          AP:   0.1060  -------
# -------  Class: bird             AP:   0.1530  -------
# -------  Class: boat             AP:   0.1219  -------
# -------  Class: bottle           AP:   0.0823  -------
# -------  Class: bus              AP:   0.0939  -------
# -------  Class: car              AP:   0.2543  -------
# -------  Class: cat              AP:   0.1675  -------
# -------  Class: chair            AP:   0.2084  -------
# -------  Class: cow              AP:   0.0497  -------
# -------  Class: diningtable      AP:   0.1250  -------
# -------  Class: dog              AP:   0.1532  -------
# -------  Class: horse            AP:   0.1177  -------
# -------  Class: motorbike        AP:   0.1075  -------
# -------  Class: person           AP:   0.5281  -------
# -------  Class: pottedplant      AP:   0.1212  -------
# -------  Class: sheep            AP:   0.0596  -------
# -------  Class: sofa             AP:   0.1407  -------
# -------  Class: train            AP:   0.2384  -------
# -------  Class: tvmonitor        AP:   0.0576  -------
# mAP: 0.1586
# Avg loss: 0.22623538970947266
# Evaluating classifier
# Mean Precision Score for Testing on Epoch 5 is 0.15862311502554727
# Starting epoch number 6
# Loss for Training on Epoch 6 is 0.2276046723127365
# Starting epoch number 7
# Loss for Training on Epoch 7 is 0.22136735916137695
# Starting epoch number 8
# Loss for Training on Epoch 8 is 0.21657705307006836
# Starting epoch number 9
# Loss for Training on Epoch 9 is 0.21388383209705353
# Starting epoch number 10
# Loss for Training on Epoch 10 is 0.2105078250169754
# -------  Class: aeroplane        AP:   0.4102  -------
# -------  Class: bicycle          AP:   0.1393  -------
# -------  Class: bird             AP:   0.1514  -------
# -------  Class: boat             AP:   0.2036  -------
# -------  Class: bottle           AP:   0.1307  -------
# -------  Class: bus              AP:   0.1346  -------
# -------  Class: car              AP:   0.3564  -------
# -------  Class: cat              AP:   0.2510  -------
# -------  Class: chair            AP:   0.2720  -------
# -------  Class: cow              AP:   0.0688  -------
# -------  Class: diningtable      AP:   0.2333  -------
# -------  Class: dog              AP:   0.1755  -------
# -------  Class: horse            AP:   0.1299  -------
# -------  Class: motorbike        AP:   0.1712  -------
# -------  Class: person           AP:   0.5863  -------
# -------  Class: pottedplant      AP:   0.1021  -------
# -------  Class: sheep            AP:   0.0781  -------
# -------  Class: sofa             AP:   0.1683  -------
# -------  Class: train            AP:   0.2601  -------
# -------  Class: tvmonitor        AP:   0.0844  -------
# mAP: 0.2054
# Avg loss: 0.21516937725245952
# Evaluating classifier
# Mean Precision Score for Testing on Epoch 10 is 0.20536389933502766
# Starting epoch number 11
# Loss for Training on Epoch 11 is 0.20781807601451874
# Starting epoch number 12
# Loss for Training on Epoch 12 is 0.20426921546459198
# Starting epoch number 13
# Loss for Training on Epoch 13 is 0.2043260633945465
# Starting epoch number 14
# Loss for Training on Epoch 14 is 0.2025040239095688
# Starting epoch number 15
# Loss for Training on Epoch 15 is 0.2009088099002838
# -------  Class: aeroplane        AP:   0.4205  -------
# -------  Class: bicycle          AP:   0.1617  -------
# -------  Class: bird             AP:   0.1726  -------
# -------  Class: boat             AP:   0.2745  -------
# -------  Class: bottle           AP:   0.1243  -------
# -------  Class: bus              AP:   0.1308  -------
# -------  Class: car              AP:   0.4502  -------
# -------  Class: cat              AP:   0.3248  -------
# -------  Class: chair            AP:   0.3034  -------
# -------  Class: cow              AP:   0.0786  -------
# -------  Class: diningtable      AP:   0.2274  -------
# -------  Class: dog              AP:   0.1997  -------
# -------  Class: horse            AP:   0.2840  -------
# -------  Class: motorbike        AP:   0.1895  -------
# -------  Class: person           AP:   0.6304  -------
# -------  Class: pottedplant      AP:   0.1188  -------
# -------  Class: sheep            AP:   0.0992  -------
# -------  Class: sofa             AP:   0.1868  -------
# -------  Class: train            AP:   0.2846  -------
# -------  Class: tvmonitor        AP:   0.1327  -------
# mAP: 0.2397
# Avg loss: 0.21757796667516233
# Evaluating classifier
# Mean Precision Score for Testing on Epoch 15 is 0.2397134944132237
# Starting epoch number 16
# Loss for Training on Epoch 16 is 0.19919328391551971
# Starting epoch number 17
# Loss for Training on Epoch 17 is 0.1944805234670639
# Starting epoch number 18
# Loss for Training on Epoch 18 is 0.1922483891248703
# Starting epoch number 19
# Loss for Training on Epoch 19 is 0.19041214883327484
# Starting epoch number 20
# Loss for Training on Epoch 20 is 0.191007599234581
# -------  Class: aeroplane        AP:   0.4604  -------
# -------  Class: bicycle          AP:   0.2188  -------
# -------  Class: bird             AP:   0.1905  -------
# -------  Class: boat             AP:   0.2659  -------
# -------  Class: bottle           AP:   0.1569  -------
# -------  Class: bus              AP:   0.1524  -------
# -------  Class: car              AP:   0.4808  -------
# -------  Class: cat              AP:   0.3606  -------
# -------  Class: chair            AP:   0.3369  -------
# -------  Class: cow              AP:   0.1146  -------
# -------  Class: diningtable      AP:   0.2711  -------
# -------  Class: dog              AP:   0.2148  -------
# -------  Class: horse            AP:   0.3529  -------
# -------  Class: motorbike        AP:   0.2041  -------
# -------  Class: person           AP:   0.6569  -------
# -------  Class: pottedplant      AP:   0.1308  -------
# -------  Class: sheep            AP:   0.1400  -------
# -------  Class: sofa             AP:   0.2296  -------
# -------  Class: train            AP:   0.2940  -------
# -------  Class: tvmonitor        AP:   0.1810  -------
# mAP: 0.2707
# Avg loss: 0.22542280443012713
# Evaluating classifier
# Mean Precision Score for Testing on Epoch 20 is 0.2706603434915828
# Starting epoch number 21
# Loss for Training on Epoch 21 is 0.18746589124202728
# Starting epoch number 22
# Loss for Training on Epoch 22 is 0.18552148342132568
# Starting epoch number 23
# Loss for Training on Epoch 23 is 0.18534934520721436
# Starting epoch number 24
# Loss for Training on Epoch 24 is 0.18488243222236633
# Starting epoch number 25
# Loss for Training on Epoch 25 is 0.18202361464500427
# -------  Class: aeroplane        AP:   0.4856  -------
# -------  Class: bicycle          AP:   0.2992  -------
# -------  Class: bird             AP:   0.1689  -------
# -------  Class: boat             AP:   0.2850  -------
# -------  Class: bottle           AP:   0.1252  -------
# -------  Class: bus              AP:   0.1632  -------
# -------  Class: car              AP:   0.4844  -------
# -------  Class: cat              AP:   0.2932  -------
# -------  Class: chair            AP:   0.3557  -------
# -------  Class: cow              AP:   0.1114  -------
# -------  Class: diningtable      AP:   0.2227  -------
# -------  Class: dog              AP:   0.2067  -------
# -------  Class: horse            AP:   0.3611  -------
# -------  Class: motorbike        AP:   0.1777  -------
# -------  Class: person           AP:   0.6623  -------
# -------  Class: pottedplant      AP:   0.1391  -------
# -------  Class: sheep            AP:   0.1040  -------
# -------  Class: sofa             AP:   0.2305  -------
# -------  Class: train            AP:   0.3197  -------
# -------  Class: tvmonitor        AP:   0.2251  -------
# mAP: 0.2710
# Avg loss: 0.21349278129637242
# Evaluating classifier
# Mean Precision Score for Testing on Epoch 25 is 0.2710334810543198
# Starting epoch number 26
# Loss for Training on Epoch 26 is 0.180567666888237
# Starting epoch number 27
# Loss for Training on Epoch 27 is 0.1781974732875824
# Starting epoch number 28
# Loss for Training on Epoch 28 is 0.17594321072101593
# Starting epoch number 29
# Loss for Training on Epoch 29 is 0.17672400176525116
# Starting epoch number 30
# Loss for Training on Epoch 30 is 0.1730973720550537
# -------  Class: aeroplane        AP:   0.5294  -------
# -------  Class: bicycle          AP:   0.3201  -------
# -------  Class: bird             AP:   0.1760  -------
# -------  Class: boat             AP:   0.2848  -------
# -------  Class: bottle           AP:   0.1428  -------
# -------  Class: bus              AP:   0.1846  -------
# -------  Class: car              AP:   0.5184  -------
# -------  Class: cat              AP:   0.3668  -------
# -------  Class: chair            AP:   0.3925  -------
# -------  Class: cow              AP:   0.1342  -------
# -------  Class: diningtable      AP:   0.2963  -------
# -------  Class: dog              AP:   0.2177  -------
# -------  Class: horse            AP:   0.3629  -------
# -------  Class: motorbike        AP:   0.2325  -------
# -------  Class: person           AP:   0.7002  -------
# -------  Class: pottedplant      AP:   0.1454  -------
# -------  Class: sheep            AP:   0.1475  -------
# -------  Class: sofa             AP:   0.2629  -------
# -------  Class: train            AP:   0.3912  -------
# -------  Class: tvmonitor        AP:   0.2306  -------
# mAP: 0.3018
# Avg loss: 0.20676110088825225
# Evaluating classifier
# Mean Precision Score for Testing on Epoch 30 is 0.3018462722440289

# %% [markdown]
# ### epochs = 100

# %%
num_epochs = 100
test_frequency = 5
batch_size = 64


train_loader = torch.utils.data.DataLoader(dataset=ds_train,
                                               batch_size=batch_size, 
                                               shuffle=True,
                                               num_workers=1)

val_loader = torch.utils.data.DataLoader(dataset=ds_val,
                                               batch_size=batch_size, 
                                               shuffle=True,
                                               num_workers=1)

# TODO: Run your own classifier here
classifier = Alexnet().to(device)

criterion = nn.MultiLabelSoftMarginLoss()
optimizer = torch.optim.SGD(classifier.parameters(), lr=0.01, momentum=0.9, weight_decay=0.7)
# optimizer = torch.optim.Adam(classifier.parameters(), lr=1e-4)

classifier, train_losses, val_losses, train_mAPs, val_mAPs = train(classifier, num_epochs, train_loader, val_loader, criterion, optimizer, test_frequency)
# Out:
# Starting epoch number 1
# Loss for Training on Epoch 1 is 0.34303018450737
# -------  Class: aeroplane        AP:   0.0577  -------
# -------  Class: bicycle          AP:   0.0505  -------
# -------  Class: bird             AP:   0.1030  -------
# -------  Class: boat             AP:   0.0436  -------
# -------  Class: bottle           AP:   0.0476  -------
# -------  Class: bus              AP:   0.0341  -------
# -------  Class: car              AP:   0.1373  -------
# -------  Class: cat              AP:   0.0986  -------
# -------  Class: chair            AP:   0.1173  -------
# -------  Class: cow              AP:   0.0483  -------
# -------  Class: diningtable      AP:   0.0545  -------
# -------  Class: dog              AP:   0.0952  -------
# -------  Class: horse            AP:   0.0638  -------
# -------  Class: motorbike        AP:   0.0369  -------
# -------  Class: person           AP:   0.4351  -------
# -------  Class: pottedplant      AP:   0.0544  -------
# -------  Class: sheep            AP:   0.0360  -------
# -------  Class: sofa             AP:   0.0844  -------
# -------  Class: train            AP:   0.0829  -------
# -------  Class: tvmonitor        AP:   0.0434  -------
# mAP: 0.0862
# Avg loss: 0.24384491369128228
# Evaluating classifier
# Mean Precision Score for Testing on Epoch 1 is 0.08624197317701734
# Starting epoch number 2
# Loss for Training on Epoch 2 is 0.23732176423072815
# Starting epoch number 3
# Loss for Training on Epoch 3 is 0.23556314408779144
# Starting epoch number 4
# Loss for Training on Epoch 4 is 0.23160557448863983
# Starting epoch number 5
# Loss for Training on Epoch 5 is 0.22891865670681
# -------  Class: aeroplane        AP:   0.2957  -------
# -------  Class: bicycle          AP:   0.1072  -------
# -------  Class: bird             AP:   0.1512  -------
# -------  Class: boat             AP:   0.1494  -------
# -------  Class: bottle           AP:   0.0855  -------
# -------  Class: bus              AP:   0.0980  -------
# -------  Class: car              AP:   0.2744  -------
# -------  Class: cat              AP:   0.1696  -------
# -------  Class: chair            AP:   0.2183  -------
# -------  Class: cow              AP:   0.0493  -------
# -------  Class: diningtable      AP:   0.1353  -------
# -------  Class: dog              AP:   0.1570  -------
# -------  Class: horse            AP:   0.1129  -------
# -------  Class: motorbike        AP:   0.1038  -------
# -------  Class: person           AP:   0.5280  -------
# -------  Class: pottedplant      AP:   0.1254  -------
# -------  Class: sheep            AP:   0.0551  -------
# -------  Class: sofa             AP:   0.1492  -------
# -------  Class: train            AP:   0.2105  -------
# -------  Class: tvmonitor        AP:   0.0671  -------
# mAP: 0.1621
# Avg loss: 0.22722466960549353
# Evaluating classifier
# Mean Precision Score for Testing on Epoch 5 is 0.1621482240052548
# Starting epoch number 6
# Loss for Training on Epoch 6 is 0.22531099617481232
# Starting epoch number 7
# Loss for Training on Epoch 7 is 0.2196286916732788
# Starting epoch number 8
# Loss for Training on Epoch 8 is 0.21735608577728271
# Starting epoch number 9
# Loss for Training on Epoch 9 is 0.21213574707508087
# Starting epoch number 10
# Loss for Training on Epoch 10 is 0.20860524475574493
# -------  Class: aeroplane        AP:   0.4140  -------
# -------  Class: bicycle          AP:   0.1477  -------
# -------  Class: bird             AP:   0.1557  -------
# -------  Class: boat             AP:   0.2050  -------
# -------  Class: bottle           AP:   0.1201  -------
# -------  Class: bus              AP:   0.1314  -------
# -------  Class: car              AP:   0.3862  -------
# -------  Class: cat              AP:   0.2400  -------
# -------  Class: chair            AP:   0.2655  -------
# -------  Class: cow              AP:   0.0658  -------
# -------  Class: diningtable      AP:   0.2104  -------
# -------  Class: dog              AP:   0.2001  -------
# -------  Class: horse            AP:   0.1565  -------
# -------  Class: motorbike        AP:   0.1632  -------
# -------  Class: person           AP:   0.5983  -------
# -------  Class: pottedplant      AP:   0.0968  -------
# -------  Class: sheep            AP:   0.0667  -------
# -------  Class: sofa             AP:   0.1549  -------
# -------  Class: train            AP:   0.2392  -------
# -------  Class: tvmonitor        AP:   0.0867  -------
# mAP: 0.2052
# Avg loss: 0.2186131589114666
# Evaluating classifier
# Mean Precision Score for Testing on Epoch 10 is 0.20521031706270354
# Starting epoch number 11
# Loss for Training on Epoch 11 is 0.2092069685459137
# Starting epoch number 12
# Loss for Training on Epoch 12 is 0.20319612324237823
# Starting epoch number 13
# Loss for Training on Epoch 13 is 0.20570054650306702
# Starting epoch number 14
# Loss for Training on Epoch 14 is 0.20042932033538818
# Starting epoch number 15
# Loss for Training on Epoch 15 is 0.1982697993516922
# -------  Class: aeroplane        AP:   0.4335  -------
# -------  Class: bicycle          AP:   0.2176  -------
# -------  Class: bird             AP:   0.1763  -------
# -------  Class: boat             AP:   0.2403  -------
# -------  Class: bottle           AP:   0.1030  -------
# -------  Class: bus              AP:   0.1554  -------
# -------  Class: car              AP:   0.4452  -------
# -------  Class: cat              AP:   0.2983  -------
# -------  Class: chair            AP:   0.3192  -------
# -------  Class: cow              AP:   0.1023  -------
# -------  Class: diningtable      AP:   0.1904  -------
# -------  Class: dog              AP:   0.2206  -------
# -------  Class: horse            AP:   0.2829  -------
# -------  Class: motorbike        AP:   0.1881  -------
# -------  Class: person           AP:   0.6396  -------
# -------  Class: pottedplant      AP:   0.1063  -------
# -------  Class: sheep            AP:   0.1051  -------
# -------  Class: sofa             AP:   0.1854  -------
# -------  Class: train            AP:   0.2779  -------
# -------  Class: tvmonitor        AP:   0.1460  -------
# mAP: 0.2417
# Avg loss: 0.2115803562104702
# Evaluating classifier
# Mean Precision Score for Testing on Epoch 15 is 0.24167268191591482
# Starting epoch number 16
# Loss for Training on Epoch 16 is 0.19756676256656647
# Starting epoch number 17
# Loss for Training on Epoch 17 is 0.19545391201972961
# Starting epoch number 18
# Loss for Training on Epoch 18 is 0.1930008828639984
# Starting epoch number 19
# Loss for Training on Epoch 19 is 0.1901647001504898
# Starting epoch number 20
# Loss for Training on Epoch 20 is 0.18931682407855988
# -------  Class: aeroplane        AP:   0.4706  -------
# -------  Class: bicycle          AP:   0.2332  -------
# -------  Class: bird             AP:   0.1965  -------
# -------  Class: boat             AP:   0.2683  -------
# -------  Class: bottle           AP:   0.1199  -------
# -------  Class: bus              AP:   0.1890  -------
# -------  Class: car              AP:   0.4880  -------
# -------  Class: cat              AP:   0.3412  -------
# -------  Class: chair            AP:   0.3550  -------
# -------  Class: cow              AP:   0.1552  -------
# -------  Class: diningtable      AP:   0.2430  -------
# -------  Class: dog              AP:   0.2250  -------
# -------  Class: horse            AP:   0.3381  -------
# -------  Class: motorbike        AP:   0.1795  -------
# -------  Class: person           AP:   0.6665  -------
# -------  Class: pottedplant      AP:   0.1273  -------
# -------  Class: sheep            AP:   0.1545  -------
# -------  Class: sofa             AP:   0.2253  -------
# -------  Class: train            AP:   0.3416  -------
# -------  Class: tvmonitor        AP:   0.1637  -------
# mAP: 0.2741
# Avg loss: 0.22599900402128698
# Evaluating classifier
# Mean Precision Score for Testing on Epoch 20 is 0.27407444320317864
# Starting epoch number 21
# Loss for Training on Epoch 21 is 0.18894094228744507
# Starting epoch number 22
# Loss for Training on Epoch 22 is 0.18701204657554626
# Starting epoch number 23
# Loss for Training on Epoch 23 is 0.18549519777297974
# Starting epoch number 24
# Loss for Training on Epoch 24 is 0.18398678302764893
# Starting epoch number 25
# Loss for Training on Epoch 25 is 0.17975087463855743
# -------  Class: aeroplane        AP:   0.4886  -------
# -------  Class: bicycle          AP:   0.2794  -------
# -------  Class: bird             AP:   0.1851  -------
# -------  Class: boat             AP:   0.2984  -------
# -------  Class: bottle           AP:   0.1234  -------
# -------  Class: bus              AP:   0.1795  -------
# -------  Class: car              AP:   0.5029  -------
# -------  Class: cat              AP:   0.3118  -------
# -------  Class: chair            AP:   0.3590  -------
# -------  Class: cow              AP:   0.1411  -------
# -------  Class: diningtable      AP:   0.2434  -------
# -------  Class: dog              AP:   0.2218  -------
# -------  Class: horse            AP:   0.3642  -------
# -------  Class: motorbike        AP:   0.1995  -------
# -------  Class: person           AP:   0.6896  -------
# -------  Class: pottedplant      AP:   0.1275  -------
# -------  Class: sheep            AP:   0.1278  -------
# -------  Class: sofa             AP:   0.2454  -------
# -------  Class: train            AP:   0.3319  -------
# -------  Class: tvmonitor        AP:   0.1966  -------
# mAP: 0.2808
# Avg loss: 0.20773231238126755
# Evaluating classifier
# Mean Precision Score for Testing on Epoch 25 is 0.2808378927236444
# Starting epoch number 26
# Loss for Training on Epoch 26 is 0.17683789134025574
# Starting epoch number 27
# Loss for Training on Epoch 27 is 0.17433880269527435
# Starting epoch number 28
# Loss for Training on Epoch 28 is 0.17500881850719452
# Starting epoch number 29
# Loss for Training on Epoch 29 is 0.17385393381118774
# Starting epoch number 30
# Loss for Training on Epoch 30 is 0.17249618470668793
# -------  Class: aeroplane        AP:   0.5304  -------
# -------  Class: bicycle          AP:   0.3099  -------
# -------  Class: bird             AP:   0.2035  -------
# -------  Class: boat             AP:   0.3364  -------
# -------  Class: bottle           AP:   0.1540  -------
# -------  Class: bus              AP:   0.2043  -------
# -------  Class: car              AP:   0.5294  -------
# -------  Class: cat              AP:   0.3526  -------
# -------  Class: chair            AP:   0.4227  -------
# -------  Class: cow              AP:   0.1574  -------
# -------  Class: diningtable      AP:   0.3370  -------
# -------  Class: dog              AP:   0.2287  -------
# -------  Class: horse            AP:   0.3898  -------
# -------  Class: motorbike        AP:   0.2740  -------
# -------  Class: person           AP:   0.6980  -------
# -------  Class: pottedplant      AP:   0.1779  -------
# -------  Class: sheep            AP:   0.1539  -------
# -------  Class: sofa             AP:   0.2630  -------
# -------  Class: train            AP:   0.4245  -------
# -------  Class: tvmonitor        AP:   0.2533  -------
# mAP: 0.3200
# Avg loss: 0.20574413985013962
# Evaluating classifier
# Mean Precision Score for Testing on Epoch 30 is 0.3200382355410346
# Starting epoch number 31
# Loss for Training on Epoch 31 is 0.16990023851394653
# Starting epoch number 32
# Loss for Training on Epoch 32 is 0.16813287138938904
# Starting epoch number 33
# Loss for Training on Epoch 33 is 0.16915272176265717
# Starting epoch number 34
# Loss for Training on Epoch 34 is 0.16507506370544434
# Starting epoch number 35
# Loss for Training on Epoch 35 is 0.16361194849014282
# -------  Class: aeroplane        AP:   0.5507  -------
# -------  Class: bicycle          AP:   0.3010  -------
# -------  Class: bird             AP:   0.1951  -------
# -------  Class: boat             AP:   0.2878  -------
# -------  Class: bottle           AP:   0.1425  -------
# -------  Class: bus              AP:   0.2122  -------
# -------  Class: car              AP:   0.5038  -------
# -------  Class: cat              AP:   0.3412  -------
# -------  Class: chair            AP:   0.4289  -------
# -------  Class: cow              AP:   0.1567  -------
# -------  Class: diningtable      AP:   0.3440  -------
# -------  Class: dog              AP:   0.2234  -------
# -------  Class: horse            AP:   0.3934  -------
# -------  Class: motorbike        AP:   0.2251  -------
# -------  Class: person           AP:   0.6952  -------
# -------  Class: pottedplant      AP:   0.1597  -------
# -------  Class: sheep            AP:   0.1548  -------
# -------  Class: sofa             AP:   0.3020  -------
# -------  Class: train            AP:   0.4261  -------
# -------  Class: tvmonitor        AP:   0.2205  -------
# mAP: 0.3132
# Avg loss: 0.21703541353344918
# Evaluating classifier
# Mean Precision Score for Testing on Epoch 35 is 0.3131999603350447
# Starting epoch number 36
# Loss for Training on Epoch 36 is 0.162611186504364
# Starting epoch number 37
# Loss for Training on Epoch 37 is 0.160592183470726
# Starting epoch number 38
# Loss for Training on Epoch 38 is 0.15851274132728577
# Starting epoch number 39
# Loss for Training on Epoch 39 is 0.1558140367269516
# Starting epoch number 40
# Loss for Training on Epoch 40 is 0.15424534678459167
# -------  Class: aeroplane        AP:   0.5562  -------
# -------  Class: bicycle          AP:   0.3368  -------
# -------  Class: bird             AP:   0.2243  -------
# -------  Class: boat             AP:   0.3414  -------
# -------  Class: bottle           AP:   0.1704  -------
# -------  Class: bus              AP:   0.2652  -------
# -------  Class: car              AP:   0.5050  -------
# -------  Class: cat              AP:   0.3819  -------
# -------  Class: chair            AP:   0.4306  -------
# -------  Class: cow              AP:   0.1636  -------
# -------  Class: diningtable      AP:   0.3813  -------
# -------  Class: dog              AP:   0.2361  -------
# -------  Class: horse            AP:   0.4427  -------
# -------  Class: motorbike        AP:   0.2895  -------
# -------  Class: person           AP:   0.7270  -------
# -------  Class: pottedplant      AP:   0.1906  -------
# -------  Class: sheep            AP:   0.1633  -------
# -------  Class: sofa             AP:   0.2702  -------
# -------  Class: train            AP:   0.4725  -------
# -------  Class: tvmonitor        AP:   0.2636  -------
# mAP: 0.3406
# Avg loss: 0.21552805453538895
# Evaluating classifier
# Mean Precision Score for Testing on Epoch 40 is 0.34060549245787836
# Starting epoch number 41
# Loss for Training on Epoch 41 is 0.15153495967388153
# Starting epoch number 42
# Loss for Training on Epoch 42 is 0.15262819826602936
# Starting epoch number 43
# Loss for Training on Epoch 43 is 0.15030398964881897
# Starting epoch number 44
# Loss for Training on Epoch 44 is 0.1476363241672516
# Starting epoch number 45
# Loss for Training on Epoch 45 is 0.1465579718351364
# -------  Class: aeroplane        AP:   0.5662  -------
# -------  Class: bicycle          AP:   0.2777  -------
# -------  Class: bird             AP:   0.2342  -------
# -------  Class: boat             AP:   0.3479  -------
# -------  Class: bottle           AP:   0.1477  -------
# -------  Class: bus              AP:   0.2398  -------
# -------  Class: car              AP:   0.5509  -------
# -------  Class: cat              AP:   0.3578  -------
# -------  Class: chair            AP:   0.4500  -------
# -------  Class: cow              AP:   0.1962  -------
# -------  Class: diningtable      AP:   0.3636  -------
# -------  Class: dog              AP:   0.2612  -------
# -------  Class: horse            AP:   0.4508  -------
# -------  Class: motorbike        AP:   0.4066  -------
# -------  Class: person           AP:   0.7213  -------
# -------  Class: pottedplant      AP:   0.1854  -------
# -------  Class: sheep            AP:   0.1520  -------
# -------  Class: sofa             AP:   0.3132  -------
# -------  Class: train            AP:   0.4325  -------
# -------  Class: tvmonitor        AP:   0.2867  -------
# mAP: 0.3471
# Avg loss: 0.23087841942906379
# Evaluating classifier
# Mean Precision Score for Testing on Epoch 45 is 0.34708231949414103
# Starting epoch number 46
# Loss for Training on Epoch 46 is 0.14397932589054108
# Starting epoch number 47
# Loss for Training on Epoch 47 is 0.14038582146167755
# Starting epoch number 48
# Loss for Training on Epoch 48 is 0.1397642195224762
# Starting epoch number 49
# Loss for Training on Epoch 49 is 0.13923029601573944
# Starting epoch number 50
# Loss for Training on Epoch 50 is 0.13602451980113983
# -------  Class: aeroplane        AP:   0.5654  -------
# -------  Class: bicycle          AP:   0.3407  -------
# -------  Class: bird             AP:   0.2535  -------
# -------  Class: boat             AP:   0.3657  -------
# -------  Class: bottle           AP:   0.1425  -------
# -------  Class: bus              AP:   0.2816  -------
# -------  Class: car              AP:   0.5406  -------
# -------  Class: cat              AP:   0.3944  -------
# -------  Class: chair            AP:   0.4580  -------
# -------  Class: cow              AP:   0.1856  -------
# -------  Class: diningtable      AP:   0.3863  -------
# -------  Class: dog              AP:   0.2628  -------
# -------  Class: horse            AP:   0.4519  -------
# -------  Class: motorbike        AP:   0.4152  -------
# -------  Class: person           AP:   0.7342  -------
# -------  Class: pottedplant      AP:   0.1891  -------
# -------  Class: sheep            AP:   0.1578  -------
# -------  Class: sofa             AP:   0.2989  -------
# -------  Class: train            AP:   0.5448  -------
# -------  Class: tvmonitor        AP:   0.2959  -------
# mAP: 0.3632
# Avg loss: 0.2111781131476164
# Evaluating classifier
# Mean Precision Score for Testing on Epoch 50 is 0.3632381832307083
# Starting epoch number 51
# Loss for Training on Epoch 51 is 0.13335102796554565
# Starting epoch number 52
# Loss for Training on Epoch 52 is 0.134297713637352
# Starting epoch number 53
# Loss for Training on Epoch 53 is 0.13202638924121857
# Starting epoch number 54
# Loss for Training on Epoch 54 is 0.13361738622188568
# Starting epoch number 55
# Loss for Training on Epoch 55 is 0.12557344138622284
# -------  Class: aeroplane        AP:   0.5707  -------
# -------  Class: bicycle          AP:   0.3875  -------
# -------  Class: bird             AP:   0.2594  -------
# -------  Class: boat             AP:   0.3403  -------
# -------  Class: bottle           AP:   0.1592  -------
# -------  Class: bus              AP:   0.2608  -------
# -------  Class: car              AP:   0.5484  -------
# -------  Class: cat              AP:   0.3906  -------
# -------  Class: chair            AP:   0.4552  -------
# -------  Class: cow              AP:   0.1772  -------
# -------  Class: diningtable      AP:   0.4094  -------
# -------  Class: dog              AP:   0.2601  -------
# -------  Class: horse            AP:   0.4765  -------
# -------  Class: motorbike        AP:   0.4112  -------
# -------  Class: person           AP:   0.7480  -------
# -------  Class: pottedplant      AP:   0.1835  -------
# -------  Class: sheep            AP:   0.1712  -------
# -------  Class: sofa             AP:   0.3242  -------
# -------  Class: train            AP:   0.5394  -------
# -------  Class: tvmonitor        AP:   0.3047  -------
# mAP: 0.3689
# Avg loss: 0.2158700477331877
# Evaluating classifier
# Mean Precision Score for Testing on Epoch 55 is 0.36887684162412077
# Starting epoch number 56
# Loss for Training on Epoch 56 is 0.12440047413110733
# Starting epoch number 57
# Loss for Training on Epoch 57 is 0.12171508371829987
# Starting epoch number 58
# Loss for Training on Epoch 58 is 0.11770271509885788
# Starting epoch number 59
# Loss for Training on Epoch 59 is 0.11895197629928589
# Starting epoch number 60
# Loss for Training on Epoch 60 is 0.11604674160480499
# -------  Class: aeroplane        AP:   0.5847  -------
# -------  Class: bicycle          AP:   0.3344  -------
# -------  Class: bird             AP:   0.2368  -------
# -------  Class: boat             AP:   0.3785  -------
# -------  Class: bottle           AP:   0.1286  -------
# -------  Class: bus              AP:   0.2515  -------
# -------  Class: car              AP:   0.5416  -------
# -------  Class: cat              AP:   0.3288  -------
# -------  Class: chair            AP:   0.4494  -------
# -------  Class: cow              AP:   0.1658  -------
# -------  Class: diningtable      AP:   0.3735  -------
# -------  Class: dog              AP:   0.2510  -------
# -------  Class: horse            AP:   0.4497  -------
# -------  Class: motorbike        AP:   0.4288  -------
# -------  Class: person           AP:   0.7424  -------
# -------  Class: pottedplant      AP:   0.1695  -------
# -------  Class: sheep            AP:   0.1476  -------
# -------  Class: sofa             AP:   0.3157  -------
# -------  Class: train            AP:   0.5552  -------
# -------  Class: tvmonitor        AP:   0.2625  -------
# mAP: 0.3548
# Avg loss: 0.23242845498025416
# Evaluating classifier
# Mean Precision Score for Testing on Epoch 60 is 0.35479689419891514
# Starting epoch number 61
# Loss for Training on Epoch 61 is 0.11273052543401718
# Starting epoch number 62
# Loss for Training on Epoch 62 is 0.11156468838453293
# Starting epoch number 63
# Loss for Training on Epoch 63 is 0.11624344438314438
# Starting epoch number 64
# Loss for Training on Epoch 64 is 0.10580962151288986
# Starting epoch number 65
# Loss for Training on Epoch 65 is 0.1043250784277916
# -------  Class: aeroplane        AP:   0.5971  -------
# -------  Class: bicycle          AP:   0.3632  -------
# -------  Class: bird             AP:   0.2557  -------
# -------  Class: boat             AP:   0.3807  -------
# -------  Class: bottle           AP:   0.1544  -------
# -------  Class: bus              AP:   0.2958  -------
# -------  Class: car              AP:   0.5098  -------
# -------  Class: cat              AP:   0.3759  -------
# -------  Class: chair            AP:   0.3996  -------
# -------  Class: cow              AP:   0.1798  -------
# -------  Class: diningtable      AP:   0.3946  -------
# -------  Class: dog              AP:   0.2332  -------
# -------  Class: horse            AP:   0.4696  -------
# -------  Class: motorbike        AP:   0.4234  -------
# -------  Class: person           AP:   0.7420  -------
# -------  Class: pottedplant      AP:   0.1685  -------
# -------  Class: sheep            AP:   0.1556  -------
# -------  Class: sofa             AP:   0.2658  -------
# -------  Class: train            AP:   0.4953  -------
# -------  Class: tvmonitor        AP:   0.2856  -------
# mAP: 0.3573
# Avg loss: 0.23099325373768806
# Evaluating classifier
# Mean Precision Score for Testing on Epoch 65 is 0.35727838899504893
# Starting epoch number 66
# Loss for Training on Epoch 66 is 0.1050342544913292
# Starting epoch number 67
# Loss for Training on Epoch 67 is 0.102960504591465
# Starting epoch number 68
# Loss for Training on Epoch 68 is 0.09654195606708527
# Starting epoch number 69
# Loss for Training on Epoch 69 is 0.0940948873758316
# Starting epoch number 70
# Loss for Training on Epoch 70 is 0.09435811638832092
# -------  Class: aeroplane        AP:   0.5712  -------
# -------  Class: bicycle          AP:   0.3677  -------
# -------  Class: bird             AP:   0.2392  -------
# -------  Class: boat             AP:   0.3703  -------
# -------  Class: bottle           AP:   0.1161  -------
# -------  Class: bus              AP:   0.2468  -------
# -------  Class: car              AP:   0.4899  -------
# -------  Class: cat              AP:   0.3818  -------
# -------  Class: chair            AP:   0.3891  -------
# -------  Class: cow              AP:   0.1458  -------
# -------  Class: diningtable      AP:   0.3590  -------
# -------  Class: dog              AP:   0.2255  -------
# -------  Class: horse            AP:   0.4460  -------
# -------  Class: motorbike        AP:   0.3676  -------
# -------  Class: person           AP:   0.7229  -------
# -------  Class: pottedplant      AP:   0.1641  -------
# -------  Class: sheep            AP:   0.2016  -------
# -------  Class: sofa             AP:   0.2451  -------
# -------  Class: train            AP:   0.4204  -------
# -------  Class: tvmonitor        AP:   0.2737  -------
# mAP: 0.3372
# Avg loss: 0.34221711605787275
# Evaluating classifier
# Mean Precision Score for Testing on Epoch 70 is 0.33718701557942043
# Starting epoch number 71
# Loss for Training on Epoch 71 is 0.09479942172765732
# Starting epoch number 72
# Loss for Training on Epoch 72 is 0.09157651662826538
# Starting epoch number 73
# Loss for Training on Epoch 73 is 0.08797702938318253
# Starting epoch number 74
# Loss for Training on Epoch 74 is 0.08123358339071274
# Starting epoch number 75
# Loss for Training on Epoch 75 is 0.08110734075307846
# -------  Class: aeroplane        AP:   0.5953  -------
# -------  Class: bicycle          AP:   0.4001  -------
# -------  Class: bird             AP:   0.2135  -------
# -------  Class: boat             AP:   0.3952  -------
# -------  Class: bottle           AP:   0.1397  -------
# -------  Class: bus              AP:   0.2739  -------
# -------  Class: car              AP:   0.5019  -------
# -------  Class: cat              AP:   0.3716  -------
# -------  Class: chair            AP:   0.4099  -------
# -------  Class: cow              AP:   0.1689  -------
# -------  Class: diningtable      AP:   0.3789  -------
# -------  Class: dog              AP:   0.2412  -------
# -------  Class: horse            AP:   0.4563  -------
# -------  Class: motorbike        AP:   0.4428  -------
# -------  Class: person           AP:   0.7349  -------
# -------  Class: pottedplant      AP:   0.1684  -------
# -------  Class: sheep            AP:   0.1395  -------
# -------  Class: sofa             AP:   0.2612  -------
# -------  Class: train            AP:   0.5683  -------
# -------  Class: tvmonitor        AP:   0.2488  -------
# mAP: 0.3555
# Avg loss: 0.24653526321053504
# Evaluating classifier
# Mean Precision Score for Testing on Epoch 75 is 0.35550222239796214
# Starting epoch number 76
# Loss for Training on Epoch 76 is 0.09090293943881989
# Starting epoch number 77
# Loss for Training on Epoch 77 is 0.0770699679851532
# Starting epoch number 78
# Loss for Training on Epoch 78 is 0.0797509178519249
# Starting epoch number 79
# Loss for Training on Epoch 79 is 0.07165579497814178
# Starting epoch number 80
# Loss for Training on Epoch 80 is 0.06832284480333328
# -------  Class: aeroplane        AP:   0.6057  -------
# -------  Class: bicycle          AP:   0.3049  -------
# -------  Class: bird             AP:   0.2707  -------
# -------  Class: boat             AP:   0.4212  -------
# -------  Class: bottle           AP:   0.1312  -------
# -------  Class: bus              AP:   0.2171  -------
# -------  Class: car              AP:   0.4863  -------
# -------  Class: cat              AP:   0.3930  -------
# -------  Class: chair            AP:   0.4121  -------
# -------  Class: cow              AP:   0.1898  -------
# -------  Class: diningtable      AP:   0.3580  -------
# -------  Class: dog              AP:   0.2456  -------
# -------  Class: horse            AP:   0.4321  -------
# -------  Class: motorbike        AP:   0.3961  -------
# -------  Class: person           AP:   0.7207  -------
# -------  Class: pottedplant      AP:   0.1395  -------
# -------  Class: sheep            AP:   0.1721  -------
# -------  Class: sofa             AP:   0.2467  -------
# -------  Class: train            AP:   0.5282  -------
# -------  Class: tvmonitor        AP:   0.1953  -------
# mAP: 0.3433
# Avg loss: 0.2980734251439571
# Evaluating classifier
# Mean Precision Score for Testing on Epoch 80 is 0.3433086117524855
# Starting epoch number 81
# Loss for Training on Epoch 81 is 0.06738013029098511
# Starting epoch number 82
# Loss for Training on Epoch 82 is 0.06717289984226227
# Starting epoch number 83
# Loss for Training on Epoch 83 is 0.06265325099229813
# Starting epoch number 84
# Loss for Training on Epoch 84 is 0.06221136450767517
# Starting epoch number 85
# Loss for Training on Epoch 85 is 0.06116311624646187
# -------  Class: aeroplane        AP:   0.5933  -------
# -------  Class: bicycle          AP:   0.3339  -------
# -------  Class: bird             AP:   0.2412  -------
# -------  Class: boat             AP:   0.4184  -------
# -------  Class: bottle           AP:   0.0915  -------
# -------  Class: bus              AP:   0.2003  -------
# -------  Class: car              AP:   0.4686  -------
# -------  Class: cat              AP:   0.3400  -------
# -------  Class: chair            AP:   0.3627  -------
# -------  Class: cow              AP:   0.1635  -------
# -------  Class: diningtable      AP:   0.3472  -------
# -------  Class: dog              AP:   0.2117  -------
# -------  Class: horse            AP:   0.4800  -------
# -------  Class: motorbike        AP:   0.3122  -------
# -------  Class: person           AP:   0.7173  -------
# -------  Class: pottedplant      AP:   0.1390  -------
# -------  Class: sheep            AP:   0.1840  -------
# -------  Class: sofa             AP:   0.2162  -------
# -------  Class: train            AP:   0.3633  -------
# -------  Class: tvmonitor        AP:   0.2411  -------
# mAP: 0.3213
# Avg loss: 0.39699639156460764
# Evaluating classifier
# Mean Precision Score for Testing on Epoch 85 is 0.32127932164677664
# Starting epoch number 86
# Loss for Training on Epoch 86 is 0.07090437412261963
# Starting epoch number 87
# Loss for Training on Epoch 87 is 0.05648484826087952
# Starting epoch number 88
# Loss for Training on Epoch 88 is 0.06541645526885986
# Starting epoch number 89
# Loss for Training on Epoch 89 is 0.05634823068976402
# Starting epoch number 90
# Loss for Training on Epoch 90 is 0.05156843736767769
# -------  Class: aeroplane        AP:   0.5846  -------
# -------  Class: bicycle          AP:   0.3900  -------
# -------  Class: bird             AP:   0.2035  -------
# -------  Class: boat             AP:   0.4301  -------
# -------  Class: bottle           AP:   0.1282  -------
# -------  Class: bus              AP:   0.2341  -------
# -------  Class: car              AP:   0.5140  -------
# -------  Class: cat              AP:   0.3345  -------
# -------  Class: chair            AP:   0.4363  -------
# -------  Class: cow              AP:   0.1757  -------
# -------  Class: diningtable      AP:   0.3933  -------
# -------  Class: dog              AP:   0.2227  -------
# -------  Class: horse            AP:   0.4318  -------
# -------  Class: motorbike        AP:   0.4128  -------
# -------  Class: person           AP:   0.7340  -------
# -------  Class: pottedplant      AP:   0.1366  -------
# -------  Class: sheep            AP:   0.1689  -------
# -------  Class: sofa             AP:   0.2764  -------
# -------  Class: train            AP:   0.5684  -------
# -------  Class: tvmonitor        AP:   0.2323  -------
# mAP: 0.3504
# Avg loss: 0.2696715272963047
# Evaluating classifier
# Mean Precision Score for Testing on Epoch 90 is 0.35041347105447573
# Starting epoch number 91
# Loss for Training on Epoch 91 is 0.05129885673522949
# Starting epoch number 92
# Loss for Training on Epoch 92 is 0.05141512304544449
# Starting epoch number 93
# Loss for Training on Epoch 93 is 0.0683569684624672
# Starting epoch number 94
# Loss for Training on Epoch 94 is 0.05391930416226387
# Starting epoch number 95
# Loss for Training on Epoch 95 is 0.04397042095661163
# -------  Class: aeroplane        AP:   0.5970  -------
# -------  Class: bicycle          AP:   0.3689  -------
# -------  Class: bird             AP:   0.2490  -------
# -------  Class: boat             AP:   0.4377  -------
# -------  Class: bottle           AP:   0.0994  -------
# -------  Class: bus              AP:   0.2584  -------
# -------  Class: car              AP:   0.5244  -------
# -------  Class: cat              AP:   0.3191  -------
# -------  Class: chair            AP:   0.3874  -------
# -------  Class: cow              AP:   0.1492  -------
# -------  Class: diningtable      AP:   0.3693  -------
# -------  Class: dog              AP:   0.1805  -------
# -------  Class: horse            AP:   0.4791  -------
# -------  Class: motorbike        AP:   0.3868  -------
# -------  Class: person           AP:   0.7204  -------
# -------  Class: pottedplant      AP:   0.1523  -------
# -------  Class: sheep            AP:   0.1624  -------
# -------  Class: sofa             AP:   0.2203  -------
# -------  Class: train            AP:   0.5113  -------
# -------  Class: tvmonitor        AP:   0.2527  -------
# mAP: 0.3413
# Avg loss: 0.29746015295386313
# Evaluating classifier
# Mean Precision Score for Testing on Epoch 95 is 0.3412771217561406
# Starting epoch number 96
# Loss for Training on Epoch 96 is 0.04200220853090286
# Starting epoch number 97
# Loss for Training on Epoch 97 is 0.044506799429655075
# Starting epoch number 98
# Loss for Training on Epoch 98 is 0.041855521500110626
# Starting epoch number 99
# Loss for Training on Epoch 99 is 0.04012445732951164
# Starting epoch number 100
# Loss for Training on Epoch 100 is 0.03827749565243721
# -------  Class: aeroplane        AP:   0.5987  -------
# -------  Class: bicycle          AP:   0.3943  -------
# -------  Class: bird             AP:   0.2377  -------
# -------  Class: boat             AP:   0.4275  -------
# -------  Class: bottle           AP:   0.1119  -------
# -------  Class: bus              AP:   0.2916  -------
# -------  Class: car              AP:   0.5162  -------
# -------  Class: cat              AP:   0.3324  -------
# -------  Class: chair            AP:   0.3908  -------
# -------  Class: cow              AP:   0.1798  -------
# -------  Class: diningtable      AP:   0.3258  -------
# -------  Class: dog              AP:   0.2189  -------
# -------  Class: horse            AP:   0.4766  -------
# -------  Class: motorbike        AP:   0.4159  -------
# -------  Class: person           AP:   0.7277  -------
# -------  Class: pottedplant      AP:   0.1242  -------
# -------  Class: sheep            AP:   0.1464  -------
# -------  Class: sofa             AP:   0.2733  -------
# -------  Class: train            AP:   0.5719  -------
# -------  Class: tvmonitor        AP:   0.2779  -------
# mAP: 0.3520
# Avg loss: 0.2771749831736088
# Evaluating classifier
# Mean Precision Score for Testing on Epoch 100 is 0.351975803851971

# %%
ds_test = VocDataset('/content/VOCdevkit_2007/VOC2007test/','test', test_transform)

test_loader = torch.utils.data.DataLoader(dataset=ds_test,
                                               batch_size=50, 
                                               shuffle=False,
                                               num_workers=1)

# Transforms applied to the testing data
test_transform = transforms.Compose([
            transforms.Resize(227),
            transforms.CenterCrop(227),
            transforms.ToTensor(),
            normalize,
        ])

mAP_test, test_loss, test_aps = test_classifier(test_loader, classifier, criterion)
print(mAP_test)
plot_losses(train_losses, val_losses, test_frequency, num_epochs)
plot_mAP(train_mAPs, val_mAPs, test_frequency, num_epochs)
mAP_test, test_loss, test_aps = test_classifier(test_loader, classifier, criterion)
print(mAP_test)
torch.save(classifier.state_dict(), './voc_my_best_classifier.pth')
output_submission_csv('my_solution.csv', test_aps)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-19-8a9dd6c909a8> in <module>()
# ----> 1 ds_test = VocDataset('/content/VOCdevkit_2007/VOC2007test/','test', test_transform)
#       2
#       3 test_loader = torch.utils.data.DataLoader(dataset=ds_test,
#       4                                                batch_size=50,
#       5                                                shuffle=False,
#
# NameError: name 'test_transform' is not defined

# %% [markdown]
# ## With image augmentation
# - epochs = 100
# - image augmentation

# %%
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

normalize = transforms.Normalize(mean=[0.485, 0.456, 0.406],
                                     std= [0.229, 0.224, 0.225])
train_transform = transforms.Compose([
    transforms.Resize(227),
    transforms.ColorJitter(hue=0.05, saturation=0.05, brightness= 0.05, contrast = 0.05),
    transforms.RandomHorizontalFlip(),
    transforms.RandomRotation(20),
    transforms.CenterCrop(227),
    transforms.ToTensor(),
    normalize,
])
    
# train_transform = ImgAugTransform()
test_transform = transforms.Compose([
            transforms.Resize(227),
            transforms.CenterCrop(227),
            transforms.ToTensor(),
            normalize,
        ])

ds_train = VocDataset('/content/VOCdevkit_2007/VOC2007','train',train_transform)
ds_val = VocDataset('/content/VOCdevkit_2007/VOC2007','val',test_transform)

# %%
num_epochs = 100
test_frequency = 5
batch_size = 64


train_loader = torch.utils.data.DataLoader(dataset=ds_train,
                                               batch_size=batch_size, 
                                               shuffle=True,
                                               num_workers=1)

val_loader = torch.utils.data.DataLoader(dataset=ds_val,
                                               batch_size=batch_size, 
                                               shuffle=True,
                                               num_workers=1)

# TODO: Run your own classifier here
classifier = Alexnet().to(device)

criterion = nn.MultiLabelSoftMarginLoss()
optimizer = torch.optim.SGD(classifier.parameters(), lr=0.01, momentum=0.9)
# optimizer = torch.optim.Adam(classifier.parameters(), lr=1e-4)

classifier, train_losses, val_losses, train_mAPs, val_mAPs = train(classifier, num_epochs, train_loader, val_loader, criterion, optimizer, test_frequency)
# Out:
# Starting epoch number 1
# Loss for Training on Epoch 1 is 0.3372208774089813
# -------  Class: aeroplane        AP:   0.0522  -------
# -------  Class: bicycle          AP:   0.0511  -------
# -------  Class: bird             AP:   0.0802  -------
# -------  Class: boat             AP:   0.0359  -------
# -------  Class: bottle           AP:   0.0620  -------
# -------  Class: bus              AP:   0.0306  -------
# -------  Class: car              AP:   0.1186  -------
# -------  Class: cat              AP:   0.0895  -------
# -------  Class: chair            AP:   0.1486  -------
# -------  Class: cow              AP:   0.0423  -------
# -------  Class: diningtable      AP:   0.0826  -------
# -------  Class: dog              AP:   0.1080  -------
# -------  Class: horse            AP:   0.0595  -------
# -------  Class: motorbike        AP:   0.0358  -------
# -------  Class: person           AP:   0.4767  -------
# -------  Class: pottedplant      AP:   0.0626  -------
# -------  Class: sheep            AP:   0.0388  -------
# -------  Class: sofa             AP:   0.1104  -------
# -------  Class: train            AP:   0.0664  -------
# -------  Class: tvmonitor        AP:   0.0471  -------
# mAP: 0.0899
# Avg loss: 0.24366164803504944
# Evaluating classifier
# Mean Precision Score for Testing on Epoch 1 is 0.08994963775938643
# Starting epoch number 2
# Loss for Training on Epoch 2 is 0.23716285824775696
# Starting epoch number 3
# Loss for Training on Epoch 3 is 0.2369517832994461
# Starting epoch number 4
# Loss for Training on Epoch 4 is 0.23330508172512054
# Starting epoch number 5
# Loss for Training on Epoch 5 is 0.23074448108673096
# -------  Class: aeroplane        AP:   0.2283  -------
# -------  Class: bicycle          AP:   0.1219  -------
# -------  Class: bird             AP:   0.1224  -------
# -------  Class: boat             AP:   0.1512  -------
# -------  Class: bottle           AP:   0.0880  -------
# -------  Class: bus              AP:   0.0771  -------
# -------  Class: car              AP:   0.2450  -------
# -------  Class: cat              AP:   0.1466  -------
# -------  Class: chair            AP:   0.2076  -------
# -------  Class: cow              AP:   0.0426  -------
# -------  Class: diningtable      AP:   0.1350  -------
# -------  Class: dog              AP:   0.1430  -------
# -------  Class: horse            AP:   0.1114  -------
# -------  Class: motorbike        AP:   0.1248  -------
# -------  Class: person           AP:   0.5272  -------
# -------  Class: pottedplant      AP:   0.1193  -------
# -------  Class: sheep            AP:   0.0569  -------
# -------  Class: sofa             AP:   0.1493  -------
# -------  Class: train            AP:   0.2175  -------
# -------  Class: tvmonitor        AP:   0.0631  -------
# mAP: 0.1539
# Avg loss: 0.23311165310442447
# Evaluating classifier
# Mean Precision Score for Testing on Epoch 5 is 0.15391273331409852
# Starting epoch number 6
# Loss for Training on Epoch 6 is 0.2275124043226242
# Starting epoch number 7
# Loss for Training on Epoch 7 is 0.22287702560424805
# Starting epoch number 8
# Loss for Training on Epoch 8 is 0.22096048295497894
# Starting epoch number 9
# Loss for Training on Epoch 9 is 0.21445278823375702
# Starting epoch number 10
# Loss for Training on Epoch 10 is 0.2144279032945633
# -------  Class: aeroplane        AP:   0.3973  -------
# -------  Class: bicycle          AP:   0.1397  -------
# -------  Class: bird             AP:   0.1396  -------
# -------  Class: boat             AP:   0.2142  -------
# -------  Class: bottle           AP:   0.1150  -------
# -------  Class: bus              AP:   0.1165  -------
# -------  Class: car              AP:   0.3426  -------
# -------  Class: cat              AP:   0.2429  -------
# -------  Class: chair            AP:   0.2450  -------
# -------  Class: cow              AP:   0.0533  -------
# -------  Class: diningtable      AP:   0.1804  -------
# -------  Class: dog              AP:   0.1902  -------
# -------  Class: horse            AP:   0.1267  -------
# -------  Class: motorbike        AP:   0.1746  -------
# -------  Class: person           AP:   0.5967  -------
# -------  Class: pottedplant      AP:   0.0977  -------
# -------  Class: sheep            AP:   0.1176  -------
# -------  Class: sofa             AP:   0.1638  -------
# -------  Class: train            AP:   0.2429  -------
# -------  Class: tvmonitor        AP:   0.0881  -------
# mAP: 0.1992
# Avg loss: 0.22051424384117127
# Evaluating classifier
# Mean Precision Score for Testing on Epoch 10 is 0.19923298528609526
# Starting epoch number 11
# Loss for Training on Epoch 11 is 0.21217317879199982
# Starting epoch number 12
# Loss for Training on Epoch 12 is 0.20791010558605194
# Starting epoch number 13
# Loss for Training on Epoch 13 is 0.20782189071178436
# Starting epoch number 14
# Loss for Training on Epoch 14 is 0.20535242557525635
# Starting epoch number 15
# Loss for Training on Epoch 15 is 0.2030547708272934
# -------  Class: aeroplane        AP:   0.4265  -------
# -------  Class: bicycle          AP:   0.2162  -------
# -------  Class: bird             AP:   0.1912  -------
# -------  Class: boat             AP:   0.2356  -------
# -------  Class: bottle           AP:   0.1168  -------
# -------  Class: bus              AP:   0.1235  -------
# -------  Class: car              AP:   0.4399  -------
# -------  Class: cat              AP:   0.2714  -------
# -------  Class: chair            AP:   0.2906  -------
# -------  Class: cow              AP:   0.0825  -------
# -------  Class: diningtable      AP:   0.2026  -------
# -------  Class: dog              AP:   0.1934  -------
# -------  Class: horse            AP:   0.3072  -------
# -------  Class: motorbike        AP:   0.2039  -------
# -------  Class: person           AP:   0.6337  -------
# -------  Class: pottedplant      AP:   0.1141  -------
# -------  Class: sheep            AP:   0.0993  -------
# -------  Class: sofa             AP:   0.1960  -------
# -------  Class: train            AP:   0.2886  -------
# -------  Class: tvmonitor        AP:   0.1289  -------
# mAP: 0.2381
# Avg loss: 0.21771911308169364
# Evaluating classifier
# Mean Precision Score for Testing on Epoch 15 is 0.23808920853219367
# Starting epoch number 16
# Loss for Training on Epoch 16 is 0.20300570130348206
# Starting epoch number 17
# Loss for Training on Epoch 17 is 0.200911745429039
# Starting epoch number 18
# Loss for Training on Epoch 18 is 0.19990630447864532
# Starting epoch number 19
# Loss for Training on Epoch 19 is 0.19872449338436127
# Starting epoch number 20
# Loss for Training on Epoch 20 is 0.19723673164844513
# -------  Class: aeroplane        AP:   0.4481  -------
# -------  Class: bicycle          AP:   0.2340  -------
# -------  Class: bird             AP:   0.1930  -------
# -------  Class: boat             AP:   0.2773  -------
# -------  Class: bottle           AP:   0.1203  -------
# -------  Class: bus              AP:   0.1259  -------
# -------  Class: car              AP:   0.4591  -------
# -------  Class: cat              AP:   0.3106  -------
# -------  Class: chair            AP:   0.2832  -------
# -------  Class: cow              AP:   0.0981  -------
# -------  Class: diningtable      AP:   0.1809  -------
# -------  Class: dog              AP:   0.2099  -------
# -------  Class: horse            AP:   0.3261  -------
# -------  Class: motorbike        AP:   0.2082  -------
# -------  Class: person           AP:   0.6561  -------
# -------  Class: pottedplant      AP:   0.1303  -------
# -------  Class: sheep            AP:   0.1313  -------
# -------  Class: sofa             AP:   0.1654  -------
# -------  Class: train            AP:   0.2893  -------
# -------  Class: tvmonitor        AP:   0.1178  -------
# mAP: 0.2482
# Avg loss: 0.21962445899844169
# Evaluating classifier
# Mean Precision Score for Testing on Epoch 20 is 0.24824117215061187
# Starting epoch number 21
# Loss for Training on Epoch 21 is 0.1981600821018219
# Starting epoch number 22
# Loss for Training on Epoch 22 is 0.19459746778011322
# Starting epoch number 23
# Loss for Training on Epoch 23 is 0.19434420764446259
# Starting epoch number 24
# Loss for Training on Epoch 24 is 0.1919156312942505
# Starting epoch number 25
# Loss for Training on Epoch 25 is 0.1900758445262909
# -------  Class: aeroplane        AP:   0.4496  -------
# -------  Class: bicycle          AP:   0.2283  -------
# -------  Class: bird             AP:   0.2003  -------
# -------  Class: boat             AP:   0.2801  -------
# -------  Class: bottle           AP:   0.1322  -------
# -------  Class: bus              AP:   0.1393  -------
# -------  Class: car              AP:   0.5027  -------
# -------  Class: cat              AP:   0.3113  -------
# -------  Class: chair            AP:   0.2984  -------
# -------  Class: cow              AP:   0.1192  -------
# -------  Class: diningtable      AP:   0.2218  -------
# -------  Class: dog              AP:   0.2163  -------
# -------  Class: horse            AP:   0.3615  -------
# -------  Class: motorbike        AP:   0.2282  -------
# -------  Class: person           AP:   0.6684  -------
# -------  Class: pottedplant      AP:   0.1168  -------
# -------  Class: sheep            AP:   0.1474  -------
# -------  Class: sofa             AP:   0.1839  -------
# -------  Class: train            AP:   0.3241  -------
# -------  Class: tvmonitor        AP:   0.1471  -------
# mAP: 0.2638
# Avg loss: 0.21853637360036374
# Evaluating classifier
# Mean Precision Score for Testing on Epoch 25 is 0.26383433870164474
# Starting epoch number 26
# Loss for Training on Epoch 26 is 0.18948863446712494
# Starting epoch number 27
# Loss for Training on Epoch 27 is 0.19168232381343842
# Starting epoch number 28
# Loss for Training on Epoch 28 is 0.18999072909355164
# Starting epoch number 29
# Loss for Training on Epoch 29 is 0.18686605989933014
# Starting epoch number 30
# Loss for Training on Epoch 30 is 0.1882798671722412
# -------  Class: aeroplane        AP:   0.4881  -------
# -------  Class: bicycle          AP:   0.2625  -------
# -------  Class: bird             AP:   0.2032  -------
# -------  Class: boat             AP:   0.2803  -------
# -------  Class: bottle           AP:   0.1506  -------
# -------  Class: bus              AP:   0.1582  -------
# -------  Class: car              AP:   0.5256  -------
# -------  Class: cat              AP:   0.3381  -------
# -------  Class: chair            AP:   0.3603  -------
# -------  Class: cow              AP:   0.1545  -------
# -------  Class: diningtable      AP:   0.2937  -------
# -------  Class: dog              AP:   0.2386  -------
# -------  Class: horse            AP:   0.3433  -------
# -------  Class: motorbike        AP:   0.2207  -------
# -------  Class: person           AP:   0.6999  -------
# -------  Class: pottedplant      AP:   0.1462  -------
# -------  Class: sheep            AP:   0.1804  -------
# -------  Class: sofa             AP:   0.2465  -------
# -------  Class: train            AP:   0.3795  -------
# -------  Class: tvmonitor        AP:   0.1713  -------
# mAP: 0.2921
# Avg loss: 0.21272144317626954
# Evaluating classifier
# Mean Precision Score for Testing on Epoch 30 is 0.29207648594050023
# Starting epoch number 31
# Loss for Training on Epoch 31 is 0.18707315623760223
# Starting epoch number 32
# Loss for Training on Epoch 32 is 0.18445837497711182
# Starting epoch number 33
# Loss for Training on Epoch 33 is 0.18577538430690765
# Starting epoch number 34
# Loss for Training on Epoch 34 is 0.18258357048034668
# Starting epoch number 35
# Loss for Training on Epoch 35 is 0.18094293773174286
# -------  Class: aeroplane        AP:   0.4929  -------
# -------  Class: bicycle          AP:   0.2350  -------
# -------  Class: bird             AP:   0.1918  -------
# -------  Class: boat             AP:   0.2832  -------
# -------  Class: bottle           AP:   0.1265  -------
# -------  Class: bus              AP:   0.1500  -------
# -------  Class: car              AP:   0.5474  -------
# -------  Class: cat              AP:   0.3283  -------
# -------  Class: chair            AP:   0.3455  -------
# -------  Class: cow              AP:   0.1618  -------
# -------  Class: diningtable      AP:   0.2390  -------
# -------  Class: dog              AP:   0.2284  -------
# -------  Class: horse            AP:   0.3840  -------
# -------  Class: motorbike        AP:   0.2605  -------
# -------  Class: person           AP:   0.7025  -------
# -------  Class: pottedplant      AP:   0.1368  -------
# -------  Class: sheep            AP:   0.1477  -------
# -------  Class: sofa             AP:   0.2458  -------
# -------  Class: train            AP:   0.4145  -------
# -------  Class: tvmonitor        AP:   0.2187  -------
# mAP: 0.2920
# Avg loss: 0.2111298404633999
# Evaluating classifier
# Mean Precision Score for Testing on Epoch 35 is 0.29201188312799464
# Starting epoch number 36
# Loss for Training on Epoch 36 is 0.18258385360240936
# Starting epoch number 37
# Loss for Training on Epoch 37 is 0.17969326674938202
# Starting epoch number 38
# Loss for Training on Epoch 38 is 0.1790185421705246
# Starting epoch number 39
# Loss for Training on Epoch 39 is 0.1767408698797226
# Starting epoch number 40
# Loss for Training on Epoch 40 is 0.17590582370758057
# -------  Class: aeroplane        AP:   0.5347  -------
# -------  Class: bicycle          AP:   0.2501  -------
# -------  Class: bird             AP:   0.1914  -------
# -------  Class: boat             AP:   0.2481  -------
# -------  Class: bottle           AP:   0.1434  -------
# -------  Class: bus              AP:   0.1520  -------
# -------  Class: car              AP:   0.5386  -------
# -------  Class: cat              AP:   0.3289  -------
# -------  Class: chair            AP:   0.3859  -------
# -------  Class: cow              AP:   0.1525  -------
# -------  Class: diningtable      AP:   0.3081  -------
# -------  Class: dog              AP:   0.2395  -------
# -------  Class: horse            AP:   0.3641  -------
# -------  Class: motorbike        AP:   0.2073  -------
# -------  Class: person           AP:   0.7268  -------
# -------  Class: pottedplant      AP:   0.1556  -------
# -------  Class: sheep            AP:   0.1639  -------
# -------  Class: sofa             AP:   0.2935  -------
# -------  Class: train            AP:   0.4344  -------
# -------  Class: tvmonitor        AP:   0.1959  -------
# mAP: 0.3007
# Avg loss: 0.2093533094972372
# Evaluating classifier
# Mean Precision Score for Testing on Epoch 40 is 0.3007361657094512
# Starting epoch number 41
# Loss for Training on Epoch 41 is 0.17680858075618744
# Starting epoch number 42
# Loss for Training on Epoch 42 is 0.17727558314800262
# Starting epoch number 43
# Loss for Training on Epoch 43 is 0.17524875700473785
# Starting epoch number 44
# Loss for Training on Epoch 44 is 0.17493487894535065
# Starting epoch number 45
# Loss for Training on Epoch 45 is 0.17472228407859802
# -------  Class: aeroplane        AP:   0.5519  -------
# -------  Class: bicycle          AP:   0.3133  -------
# -------  Class: bird             AP:   0.1945  -------
# -------  Class: boat             AP:   0.3070  -------
# -------  Class: bottle           AP:   0.1627  -------
# -------  Class: bus              AP:   0.1975  -------
# -------  Class: car              AP:   0.5200  -------
# -------  Class: cat              AP:   0.3343  -------
# -------  Class: chair            AP:   0.3866  -------
# -------  Class: cow              AP:   0.1532  -------
# -------  Class: diningtable      AP:   0.3333  -------
# -------  Class: dog              AP:   0.2391  -------
# -------  Class: horse            AP:   0.4163  -------
# -------  Class: motorbike        AP:   0.2739  -------
# -------  Class: person           AP:   0.7227  -------
# -------  Class: pottedplant      AP:   0.1922  -------
# -------  Class: sheep            AP:   0.1743  -------
# -------  Class: sofa             AP:   0.2597  -------
# -------  Class: train            AP:   0.4455  -------
# -------  Class: tvmonitor        AP:   0.2354  -------
# mAP: 0.3207
# Avg loss: 0.2082153420895338
# Evaluating classifier
# Mean Precision Score for Testing on Epoch 45 is 0.32068458038835396
# Starting epoch number 46
# Loss for Training on Epoch 46 is 0.17141923308372498
# Starting epoch number 47
# Loss for Training on Epoch 47 is 0.17092344164848328
# Starting epoch number 48
# Loss for Training on Epoch 48 is 0.17126411199569702
# Starting epoch number 49
# Loss for Training on Epoch 49 is 0.17047539353370667
# Starting epoch number 50
# Loss for Training on Epoch 50 is 0.1689222902059555
# -------  Class: aeroplane        AP:   0.5699  -------
# -------  Class: bicycle          AP:   0.3263  -------
# -------  Class: bird             AP:   0.2047  -------
# -------  Class: boat             AP:   0.3017  -------
# -------  Class: bottle           AP:   0.1607  -------
# -------  Class: bus              AP:   0.2132  -------
# -------  Class: car              AP:   0.5693  -------
# -------  Class: cat              AP:   0.3684  -------
# -------  Class: chair            AP:   0.4259  -------
# -------  Class: cow              AP:   0.1634  -------
# -------  Class: diningtable      AP:   0.3737  -------
# -------  Class: dog              AP:   0.2618  -------
# -------  Class: horse            AP:   0.4356  -------
# -------  Class: motorbike        AP:   0.3356  -------
# -------  Class: person           AP:   0.7410  -------
# -------  Class: pottedplant      AP:   0.1917  -------
# -------  Class: sheep            AP:   0.1836  -------
# -------  Class: sofa             AP:   0.2886  -------
# -------  Class: train            AP:   0.4761  -------
# -------  Class: tvmonitor        AP:   0.2628  -------
# mAP: 0.3427
# Avg loss: 0.20666593760252
# Evaluating classifier
# Mean Precision Score for Testing on Epoch 50 is 0.34270592560105007
# Starting epoch number 51
# Loss for Training on Epoch 51 is 0.167271688580513
# Starting epoch number 52
# Loss for Training on Epoch 52 is 0.16829997301101685
# Starting epoch number 53
# Loss for Training on Epoch 53 is 0.16618311405181885
# Starting epoch number 54
# Loss for Training on Epoch 54 is 0.16463546454906464
# Starting epoch number 55
# Loss for Training on Epoch 55 is 0.1654670387506485
# -------  Class: aeroplane        AP:   0.5822  -------
# -------  Class: bicycle          AP:   0.3275  -------
# -------  Class: bird             AP:   0.2004  -------
# -------  Class: boat             AP:   0.3300  -------
# -------  Class: bottle           AP:   0.1551  -------
# -------  Class: bus              AP:   0.2299  -------
# -------  Class: car              AP:   0.5806  -------
# -------  Class: cat              AP:   0.3705  -------
# -------  Class: chair            AP:   0.4348  -------
# -------  Class: cow              AP:   0.1699  -------
# -------  Class: diningtable      AP:   0.3524  -------
# -------  Class: dog              AP:   0.2609  -------
# -------  Class: horse            AP:   0.4607  -------
# -------  Class: motorbike        AP:   0.3744  -------
# -------  Class: person           AP:   0.7486  -------
# -------  Class: pottedplant      AP:   0.1793  -------
# -------  Class: sheep            AP:   0.1898  -------
# -------  Class: sofa             AP:   0.3252  -------
# -------  Class: train            AP:   0.4970  -------
# -------  Class: tvmonitor        AP:   0.3117  -------
# mAP: 0.3540
# Avg loss: 0.20333233587443827
# Evaluating classifier
# Mean Precision Score for Testing on Epoch 55 is 0.3540463743580782
# Starting epoch number 56
# Loss for Training on Epoch 56 is 0.16249489784240723
# Starting epoch number 57
# Loss for Training on Epoch 57 is 0.16466794908046722
# Starting epoch number 58
# Loss for Training on Epoch 58 is 0.16546308994293213
# Starting epoch number 59
# Loss for Training on Epoch 59 is 0.16257065534591675
# Starting epoch number 60
# Loss for Training on Epoch 60 is 0.1615847796201706
# -------  Class: aeroplane        AP:   0.5844  -------
# -------  Class: bicycle          AP:   0.3289  -------
# -------  Class: bird             AP:   0.1944  -------
# -------  Class: boat             AP:   0.3259  -------
# -------  Class: bottle           AP:   0.1516  -------
# -------  Class: bus              AP:   0.2844  -------
# -------  Class: car              AP:   0.5721  -------
# -------  Class: cat              AP:   0.3745  -------
# -------  Class: chair            AP:   0.4334  -------
# -------  Class: cow              AP:   0.1692  -------
# -------  Class: diningtable      AP:   0.3509  -------
# -------  Class: dog              AP:   0.2686  -------
# -------  Class: horse            AP:   0.4584  -------
# -------  Class: motorbike        AP:   0.3872  -------
# -------  Class: person           AP:   0.7402  -------
# -------  Class: pottedplant      AP:   0.1737  -------
# -------  Class: sheep            AP:   0.1760  -------
# -------  Class: sofa             AP:   0.3230  -------
# -------  Class: train            AP:   0.5226  -------
# -------  Class: tvmonitor        AP:   0.3179  -------
# mAP: 0.3569
# Avg loss: 0.2018094290047884
# Evaluating classifier
# Mean Precision Score for Testing on Epoch 60 is 0.3568650573699037
# Starting epoch number 61
# Loss for Training on Epoch 61 is 0.16124878823757172
# Starting epoch number 62
# Loss for Training on Epoch 62 is 0.158750519156456
# Starting epoch number 63
# Loss for Training on Epoch 63 is 0.16131144762039185
# Starting epoch number 64
# Loss for Training on Epoch 64 is 0.15780797600746155
# Starting epoch number 65
# Loss for Training on Epoch 65 is 0.15872564911842346
# -------  Class: aeroplane        AP:   0.5926  -------
# -------  Class: bicycle          AP:   0.3539  -------
# -------  Class: bird             AP:   0.2198  -------
# -------  Class: boat             AP:   0.3814  -------
# -------  Class: bottle           AP:   0.1711  -------
# -------  Class: bus              AP:   0.2826  -------
# -------  Class: car              AP:   0.5868  -------
# -------  Class: cat              AP:   0.3612  -------
# -------  Class: chair            AP:   0.4338  -------
# -------  Class: cow              AP:   0.1788  -------
# -------  Class: diningtable      AP:   0.3639  -------
# -------  Class: dog              AP:   0.2637  -------
# -------  Class: horse            AP:   0.4825  -------
# -------  Class: motorbike        AP:   0.3996  -------
# -------  Class: person           AP:   0.7455  -------
# -------  Class: pottedplant      AP:   0.1796  -------
# -------  Class: sheep            AP:   0.1778  -------
# -------  Class: sofa             AP:   0.2992  -------
# -------  Class: train            AP:   0.5242  -------
# -------  Class: tvmonitor        AP:   0.3359  -------
# mAP: 0.3667
# Avg loss: 0.20670820847153665
# Evaluating classifier
# Mean Precision Score for Testing on Epoch 65 is 0.3666932777677304
# Starting epoch number 66
# Loss for Training on Epoch 66 is 0.1558145433664322
# Starting epoch number 67
# Loss for Training on Epoch 67 is 0.15929962694644928
# Starting epoch number 68
# Loss for Training on Epoch 68 is 0.15856535732746124
# Starting epoch number 69
# Loss for Training on Epoch 69 is 0.15695525705814362
# Starting epoch number 70
# Loss for Training on Epoch 70 is 0.15538877248764038
# -------  Class: aeroplane        AP:   0.5876  -------
# -------  Class: bicycle          AP:   0.3475  -------
# -------  Class: bird             AP:   0.2266  -------
# -------  Class: boat             AP:   0.3501  -------
# -------  Class: bottle           AP:   0.1737  -------
# -------  Class: bus              AP:   0.3071  -------
# -------  Class: car              AP:   0.5786  -------
# -------  Class: cat              AP:   0.3811  -------
# -------  Class: chair            AP:   0.4293  -------
# -------  Class: cow              AP:   0.1751  -------
# -------  Class: diningtable      AP:   0.3713  -------
# -------  Class: dog              AP:   0.2667  -------
# -------  Class: horse            AP:   0.4928  -------
# -------  Class: motorbike        AP:   0.4278  -------
# -------  Class: person           AP:   0.7541  -------
# -------  Class: pottedplant      AP:   0.1941  -------
# -------  Class: sheep            AP:   0.1711  -------
# -------  Class: sofa             AP:   0.3034  -------
# -------  Class: train            AP:   0.5216  -------
# -------  Class: tvmonitor        AP:   0.3176  -------
# mAP: 0.3689
# Avg loss: 0.2064620230346918
# Evaluating classifier
# Mean Precision Score for Testing on Epoch 70 is 0.3688699196362341
# Starting epoch number 71
# Loss for Training on Epoch 71 is 0.15607288479804993
# Starting epoch number 72
# Loss for Training on Epoch 72 is 0.15678638219833374
# Starting epoch number 73
# Loss for Training on Epoch 73 is 0.15417523682117462
# Starting epoch number 74
# Loss for Training on Epoch 74 is 0.15381696820259094
# Starting epoch number 75
# Loss for Training on Epoch 75 is 0.148252472281456
# -------  Class: aeroplane        AP:   0.5903  -------
# -------  Class: bicycle          AP:   0.3619  -------
# -------  Class: bird             AP:   0.2182  -------
# -------  Class: boat             AP:   0.3735  -------
# -------  Class: bottle           AP:   0.1651  -------
# -------  Class: bus              AP:   0.3248  -------
# -------  Class: car              AP:   0.5991  -------
# -------  Class: cat              AP:   0.3884  -------
# -------  Class: chair            AP:   0.4549  -------
# -------  Class: cow              AP:   0.1764  -------
# -------  Class: diningtable      AP:   0.3935  -------
# -------  Class: dog              AP:   0.2755  -------
# -------  Class: horse            AP:   0.4803  -------
# -------  Class: motorbike        AP:   0.4242  -------
# -------  Class: person           AP:   0.7451  -------
# -------  Class: pottedplant      AP:   0.1781  -------
# -------  Class: sheep            AP:   0.1569  -------
# -------  Class: sofa             AP:   0.3294  -------
# -------  Class: train            AP:   0.5744  -------
# -------  Class: tvmonitor        AP:   0.3239  -------
# mAP: 0.3767
# Avg loss: 0.20274475030601025
# Evaluating classifier
# Mean Precision Score for Testing on Epoch 75 is 0.37670738204193477
# Starting epoch number 76
# Loss for Training on Epoch 76 is 0.1506791114807129
# Starting epoch number 77
# Loss for Training on Epoch 77 is 0.149490624666214
# Starting epoch number 78
# Loss for Training on Epoch 78 is 0.14716029167175293
# Starting epoch number 79
# Loss for Training on Epoch 79 is 0.148979052901268
# Starting epoch number 80
# Loss for Training on Epoch 80 is 0.14823202788829803
# -------  Class: aeroplane        AP:   0.6024  -------
# -------  Class: bicycle          AP:   0.3553  -------
# -------  Class: bird             AP:   0.2588  -------
# -------  Class: boat             AP:   0.3529  -------
# -------  Class: bottle           AP:   0.1613  -------
# -------  Class: bus              AP:   0.3143  -------
# -------  Class: car              AP:   0.5926  -------
# -------  Class: cat              AP:   0.3817  -------
# -------  Class: chair            AP:   0.4676  -------
# -------  Class: cow              AP:   0.1615  -------
# -------  Class: diningtable      AP:   0.3984  -------
# -------  Class: dog              AP:   0.2559  -------
# -------  Class: horse            AP:   0.4969  -------
# -------  Class: motorbike        AP:   0.4527  -------
# -------  Class: person           AP:   0.7614  -------
# -------  Class: pottedplant      AP:   0.1860  -------
# -------  Class: sheep            AP:   0.1928  -------
# -------  Class: sofa             AP:   0.3194  -------
# -------  Class: train            AP:   0.5675  -------
# -------  Class: tvmonitor        AP:   0.3489  -------
# mAP: 0.3814
# Avg loss: 0.20116830095648766
# Evaluating classifier
# Mean Precision Score for Testing on Epoch 80 is 0.3814163328508586
# Starting epoch number 81
# Loss for Training on Epoch 81 is 0.14641328155994415
# Starting epoch number 82
# Loss for Training on Epoch 82 is 0.14708058536052704
# Starting epoch number 83
# Loss for Training on Epoch 83 is 0.14523136615753174
# Starting epoch number 84
# Loss for Training on Epoch 84 is 0.14545467495918274
# Starting epoch number 85
# Loss for Training on Epoch 85 is 0.1439809799194336
# -------  Class: aeroplane        AP:   0.5974  -------
# -------  Class: bicycle          AP:   0.3993  -------
# -------  Class: bird             AP:   0.2213  -------
# -------  Class: boat             AP:   0.3425  -------
# -------  Class: bottle           AP:   0.1668  -------
# -------  Class: bus              AP:   0.2999  -------
# -------  Class: car              AP:   0.5796  -------
# -------  Class: cat              AP:   0.4048  -------
# -------  Class: chair            AP:   0.4663  -------
# -------  Class: cow              AP:   0.1778  -------
# -------  Class: diningtable      AP:   0.4195  -------
# -------  Class: dog              AP:   0.2757  -------
# -------  Class: horse            AP:   0.4889  -------
# -------  Class: motorbike        AP:   0.4837  -------
# -------  Class: person           AP:   0.7672  -------
# -------  Class: pottedplant      AP:   0.1707  -------
# -------  Class: sheep            AP:   0.1905  -------
# -------  Class: sofa             AP:   0.3272  -------
# -------  Class: train            AP:   0.5241  -------
# -------  Class: tvmonitor        AP:   0.3131  -------
# mAP: 0.3808
# Avg loss: 0.2074796214699745
# Evaluating classifier
# Mean Precision Score for Testing on Epoch 85 is 0.38083079369751
# Starting epoch number 86
# Loss for Training on Epoch 86 is 0.14480051398277283
# Starting epoch number 87
# Loss for Training on Epoch 87 is 0.14934730529785156
# Starting epoch number 88
# Loss for Training on Epoch 88 is 0.14785246551036835
# Starting epoch number 89
# Loss for Training on Epoch 89 is 0.14209046959877014
# Starting epoch number 90
# Loss for Training on Epoch 90 is 0.14283119142055511
# -------  Class: aeroplane        AP:   0.6408  -------
# -------  Class: bicycle          AP:   0.3918  -------
# -------  Class: bird             AP:   0.2520  -------
# -------  Class: boat             AP:   0.3682  -------
# -------  Class: bottle           AP:   0.1595  -------
# -------  Class: bus              AP:   0.3486  -------
# -------  Class: car              AP:   0.5973  -------
# -------  Class: cat              AP:   0.3702  -------
# -------  Class: chair            AP:   0.4679  -------
# -------  Class: cow              AP:   0.1735  -------
# -------  Class: diningtable      AP:   0.4303  -------
# -------  Class: dog              AP:   0.2648  -------
# -------  Class: horse            AP:   0.4965  -------
# -------  Class: motorbike        AP:   0.4910  -------
# -------  Class: person           AP:   0.7700  -------
# -------  Class: pottedplant      AP:   0.1752  -------
# -------  Class: sheep            AP:   0.1767  -------
# -------  Class: sofa             AP:   0.3516  -------
# -------  Class: train            AP:   0.6072  -------
# -------  Class: tvmonitor        AP:   0.3473  -------
# mAP: 0.3940
# Avg loss: 0.2003209874033928
# Evaluating classifier
# Mean Precision Score for Testing on Epoch 90 is 0.3940296757279448
# Starting epoch number 91
# Loss for Training on Epoch 91 is 0.14329102635383606
# Starting epoch number 92
# Loss for Training on Epoch 92 is 0.1407517045736313
# Starting epoch number 93
# Loss for Training on Epoch 93 is 0.13849590718746185
# Starting epoch number 94
# Loss for Training on Epoch 94 is 0.14081497490406036
# Starting epoch number 95
# Loss for Training on Epoch 95 is 0.13986216485500336
# -------  Class: aeroplane        AP:   0.6310  -------
# -------  Class: bicycle          AP:   0.4268  -------
# -------  Class: bird             AP:   0.2326  -------
# -------  Class: boat             AP:   0.3711  -------
# -------  Class: bottle           AP:   0.1542  -------
# -------  Class: bus              AP:   0.3292  -------
# -------  Class: car              AP:   0.6191  -------
# -------  Class: cat              AP:   0.3859  -------
# -------  Class: chair            AP:   0.4552  -------
# -------  Class: cow              AP:   0.1776  -------
# -------  Class: diningtable      AP:   0.3813  -------
# -------  Class: dog              AP:   0.2735  -------
# -------  Class: horse            AP:   0.5063  -------
# -------  Class: motorbike        AP:   0.5059  -------
# -------  Class: person           AP:   0.7743  -------
# -------  Class: pottedplant      AP:   0.1729  -------
# -------  Class: sheep            AP:   0.1555  -------
# -------  Class: sofa             AP:   0.3287  -------
# -------  Class: train            AP:   0.5952  -------
# -------  Class: tvmonitor        AP:   0.3685  -------
# mAP: 0.3922
# Avg loss: 0.20222880728542805
# Evaluating classifier
# Mean Precision Score for Testing on Epoch 95 is 0.3922354644692729
# Starting epoch number 96
# Loss for Training on Epoch 96 is 0.13680826127529144
# Starting epoch number 97
# Loss for Training on Epoch 97 is 0.13814052939414978
# Starting epoch number 98
# Loss for Training on Epoch 98 is 0.13474245369434357
# Starting epoch number 99
# Loss for Training on Epoch 99 is 0.13533370196819305
# Starting epoch number 100
# Loss for Training on Epoch 100 is 0.13643987476825714
# -------  Class: aeroplane        AP:   0.6124  -------
# -------  Class: bicycle          AP:   0.4222  -------
# -------  Class: bird             AP:   0.2839  -------
# -------  Class: boat             AP:   0.3848  -------
# -------  Class: bottle           AP:   0.1709  -------
# -------  Class: bus              AP:   0.3413  -------
# -------  Class: car              AP:   0.5906  -------
# -------  Class: cat              AP:   0.3785  -------
# -------  Class: chair            AP:   0.4500  -------
# -------  Class: cow              AP:   0.1519  -------
# -------  Class: diningtable      AP:   0.4219  -------
# -------  Class: dog              AP:   0.2676  -------
# -------  Class: horse            AP:   0.4868  -------
# -------  Class: motorbike        AP:   0.5264  -------
# -------  Class: person           AP:   0.7620  -------
# -------  Class: pottedplant      AP:   0.1743  -------
# -------  Class: sheep            AP:   0.1736  -------
# -------  Class: sofa             AP:   0.3150  -------
# -------  Class: train            AP:   0.5888  -------
# -------  Class: tvmonitor        AP:   0.3603  -------
# mAP: 0.3932
# Avg loss: 0.20582936331629753
# Evaluating classifier
# Mean Precision Score for Testing on Epoch 100 is 0.3931616486665826

# %%
ds_test = VocDataset('/content/VOCdevkit_2007/VOC2007test/','test', test_transform)

test_loader = torch.utils.data.DataLoader(dataset=ds_test,
                                               batch_size=50, 
                                               shuffle=False,
                                               num_workers=1)

# %%
plot_losses(train_losses, val_losses, test_frequency, num_epochs)
plot_mAP(train_mAPs, val_mAPs, test_frequency, num_epochs)
mAP_test, test_loss, test_aps = test_classifier(test_loader, classifier, criterion)
print(mAP_test)
torch.save(classifier.state_dict(), './voc_my_best_classifier.pth')
output_submission_csv('my_solution1.csv', test_aps)
# Out:
# -------  Class: aeroplane        AP:   0.6273  -------
# -------  Class: bicycle          AP:   0.3675  -------
# -------  Class: bird             AP:   0.2854  -------
# -------  Class: boat             AP:   0.3717  -------
# -------  Class: bottle           AP:   0.1649  -------
# -------  Class: bus              AP:   0.3028  -------
# -------  Class: car              AP:   0.6337  -------
# -------  Class: cat              AP:   0.3676  -------
# -------  Class: chair            AP:   0.4343  -------
# -------  Class: cow              AP:   0.1885  -------
# -------  Class: diningtable      AP:   0.3906  -------
# -------  Class: dog              AP:   0.2879  -------
# -------  Class: horse            AP:   0.6305  -------
# -------  Class: motorbike        AP:   0.5053  -------
# -------  Class: person           AP:   0.7686  -------
# -------  Class: pottedplant      AP:   0.1785  -------
# -------  Class: sheep            AP:   0.2096  -------
# -------  Class: sofa             AP:   0.2658  -------
# -------  Class: train            AP:   0.6128  -------
# -------  Class: tvmonitor        AP:   0.3387  -------
# mAP: 0.3966
# Avg loss: 0.2021920697391033
# 0.39660239624441157

# %%
num_epochs = 50
test_frequency = 5
batch_size = 64


train_loader = torch.utils.data.DataLoader(dataset=ds_train,
                                               batch_size=batch_size, 
                                               shuffle=True,
                                               num_workers=1)

val_loader = torch.utils.data.DataLoader(dataset=ds_val,
                                               batch_size=batch_size, 
                                               shuffle=True,
                                               num_workers=1)

# TODO: Run your own classifier here
classifier = Alexnet().to(device)

criterion = nn.MultiLabelSoftMarginLoss()
optimizer = torch.optim.SGD(classifier.parameters(), lr=0.01, momentum=0.9)
# optimizer = torch.optim.Adam(classifier.parameters(), lr=1e-4)

classifier, train_losses, val_losses, train_mAPs, val_mAPs = train(classifier, num_epochs, train_loader, val_loader, criterion, optimizer, test_frequency)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-f4eb1c01e17c> in <module>()
#       4
#       5
# ----> 6 train_loader = torch.utils.data.DataLoader(dataset=ds_train,
#       7                                                batch_size=batch_size,
#       8                                                shuffle=True,
#
# NameError: name 'torch' is not defined

# %% [markdown]
# ## batchsize = 32

# %%
num_epochs = 100
test_frequency = 5
batch_size = 32
ds_train, ds_val = ImageAugmentation()

device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")


train_loader = torch.utils.data.DataLoader(dataset=ds_train,
                                               batch_size=batch_size, 
                                               shuffle=True,
                                               num_workers=1)

val_loader = torch.utils.data.DataLoader(dataset=ds_val,
                                               batch_size=batch_size, 
                                               shuffle=True,
                                               num_workers=1)

# TODO: Run your own classifier here
classifier = Alexnet().to(device)

criterion = nn.MultiLabelSoftMarginLoss()
optimizer = torch.optim.SGD(classifier.parameters(), lr=0.01, momentum=0.9)
# optimizer = torch.optim.Adam(classifier.parameters(), lr=1e-4)

classifier, train_losses, val_losses, train_mAPs, val_mAPs = train(classifier, num_epochs, train_loader, val_loader, criterion, optimizer, test_frequency)
# Out:
# Starting epoch number 1
# Loss for Training on Epoch 1 is 0.28701290488243103
# -------  Class: aeroplane        AP:   0.0959  -------
# -------  Class: bicycle          AP:   0.0827  -------
# -------  Class: bird             AP:   0.1301  -------
# -------  Class: boat             AP:   0.0616  -------
# -------  Class: bottle           AP:   0.0417  -------
# -------  Class: bus              AP:   0.0373  -------
# -------  Class: car              AP:   0.1509  -------
# -------  Class: cat              AP:   0.0752  -------
# -------  Class: chair            AP:   0.1113  -------
# -------  Class: cow              AP:   0.0521  -------
# -------  Class: diningtable      AP:   0.0548  -------
# -------  Class: dog              AP:   0.1055  -------
# -------  Class: horse            AP:   0.0809  -------
# -------  Class: motorbike        AP:   0.0558  -------
# -------  Class: person           AP:   0.5006  -------
# -------  Class: pottedplant      AP:   0.0676  -------
# -------  Class: sheep            AP:   0.0590  -------
# -------  Class: sofa             AP:   0.0747  -------
# -------  Class: train            AP:   0.0855  -------
# -------  Class: tvmonitor        AP:   0.0408  -------
# mAP: 0.0982
# Avg loss: 0.23875273669822306
# Evaluating classifier
# Mean Precision Score for Testing on Epoch 1 is 0.09820368800238728
# Starting epoch number 2
# Loss for Training on Epoch 2 is 0.23633407056331635
# Starting epoch number 3
# Loss for Training on Epoch 3 is 0.23174385726451874
# Starting epoch number 4
# Loss for Training on Epoch 4 is 0.22594590485095978
# Starting epoch number 5
# Loss for Training on Epoch 5 is 0.22116723656654358
# -------  Class: aeroplane        AP:   0.3618  -------
# -------  Class: bicycle          AP:   0.1320  -------
# -------  Class: bird             AP:   0.1060  -------
# -------  Class: boat             AP:   0.1870  -------
# -------  Class: bottle           AP:   0.1040  -------
# -------  Class: bus              AP:   0.1000  -------
# -------  Class: car              AP:   0.2862  -------
# -------  Class: cat              AP:   0.2316  -------
# -------  Class: chair            AP:   0.2278  -------
# -------  Class: cow              AP:   0.0447  -------
# -------  Class: diningtable      AP:   0.1736  -------
# -------  Class: dog              AP:   0.1681  -------
# -------  Class: horse            AP:   0.0999  -------
# -------  Class: motorbike        AP:   0.1724  -------
# -------  Class: person           AP:   0.5606  -------
# -------  Class: pottedplant      AP:   0.0987  -------
# -------  Class: sheep            AP:   0.0690  -------
# -------  Class: sofa             AP:   0.1528  -------
# -------  Class: train            AP:   0.1295  -------
# -------  Class: tvmonitor        AP:   0.0712  -------
# mAP: 0.1738
# Avg loss: 0.22246270749387861
# Evaluating classifier
# Mean Precision Score for Testing on Epoch 5 is 0.17384392226874995
# Starting epoch number 6
# Loss for Training on Epoch 6 is 0.2159452885389328
# Starting epoch number 7
# Loss for Training on Epoch 7 is 0.21293799579143524
# Starting epoch number 8
# Loss for Training on Epoch 8 is 0.21200494468212128
# Starting epoch number 9
# Loss for Training on Epoch 9 is 0.2098981738090515
# Starting epoch number 10
# Loss for Training on Epoch 10 is 0.2076626569032669
# -------  Class: aeroplane        AP:   0.4219  -------
# -------  Class: bicycle          AP:   0.1728  -------
# -------  Class: bird             AP:   0.1551  -------
# -------  Class: boat             AP:   0.1841  -------
# -------  Class: bottle           AP:   0.1219  -------
# -------  Class: bus              AP:   0.1276  -------
# -------  Class: car              AP:   0.4008  -------
# -------  Class: cat              AP:   0.2762  -------
# -------  Class: chair            AP:   0.2712  -------
# -------  Class: cow              AP:   0.0610  -------
# -------  Class: diningtable      AP:   0.1834  -------
# -------  Class: dog              AP:   0.1999  -------
# -------  Class: horse            AP:   0.2989  -------
# -------  Class: motorbike        AP:   0.1897  -------
# -------  Class: person           AP:   0.6073  -------
# -------  Class: pottedplant      AP:   0.1138  -------
# -------  Class: sheep            AP:   0.1003  -------
# -------  Class: sofa             AP:   0.1814  -------
# -------  Class: train            AP:   0.1938  -------
# -------  Class: tvmonitor        AP:   0.1280  -------
# mAP: 0.2195
# Avg loss: 0.2272050914507878
# Evaluating classifier
# Mean Precision Score for Testing on Epoch 10 is 0.2194572086959865
# Starting epoch number 11
# Loss for Training on Epoch 11 is 0.20521023869514465
# Starting epoch number 12
# Loss for Training on Epoch 12 is 0.20516909658908844
# Starting epoch number 13
# Loss for Training on Epoch 13 is 0.2050435096025467
# Starting epoch number 14
# Loss for Training on Epoch 14 is 0.20202010869979858
# Starting epoch number 15
# Loss for Training on Epoch 15 is 0.20188960433006287
# -------  Class: aeroplane        AP:   0.4355  -------
# -------  Class: bicycle          AP:   0.2459  -------
# -------  Class: bird             AP:   0.1742  -------
# -------  Class: boat             AP:   0.2080  -------
# -------  Class: bottle           AP:   0.1153  -------
# -------  Class: bus              AP:   0.1551  -------
# -------  Class: car              AP:   0.4705  -------
# -------  Class: cat              AP:   0.2632  -------
# -------  Class: chair            AP:   0.2765  -------
# -------  Class: cow              AP:   0.0936  -------
# -------  Class: diningtable      AP:   0.1696  -------
# -------  Class: dog              AP:   0.1876  -------
# -------  Class: horse            AP:   0.3434  -------
# -------  Class: motorbike        AP:   0.1887  -------
# -------  Class: person           AP:   0.6412  -------
# -------  Class: pottedplant      AP:   0.1118  -------
# -------  Class: sheep            AP:   0.1228  -------
# -------  Class: sofa             AP:   0.1918  -------
# -------  Class: train            AP:   0.2560  -------
# -------  Class: tvmonitor        AP:   0.1219  -------
# mAP: 0.2386
# Avg loss: 0.21458705448651616
# Evaluating classifier
# Mean Precision Score for Testing on Epoch 15 is 0.2386198726884312
# Starting epoch number 16
# Loss for Training on Epoch 16 is 0.1999048888683319
# Starting epoch number 17
# Loss for Training on Epoch 17 is 0.19870871305465698
# Starting epoch number 18
# Loss for Training on Epoch 18 is 0.1960902214050293
# Starting epoch number 19
# Loss for Training on Epoch 19 is 0.19521662592887878
# Starting epoch number 20
# Loss for Training on Epoch 20 is 0.1941717565059662
# -------  Class: aeroplane        AP:   0.4899  -------
# -------  Class: bicycle          AP:   0.2623  -------
# -------  Class: bird             AP:   0.1758  -------
# -------  Class: boat             AP:   0.2449  -------
# -------  Class: bottle           AP:   0.1378  -------
# -------  Class: bus              AP:   0.1489  -------
# -------  Class: car              AP:   0.4872  -------
# -------  Class: cat              AP:   0.2994  -------
# -------  Class: chair            AP:   0.3216  -------
# -------  Class: cow              AP:   0.1177  -------
# -------  Class: diningtable      AP:   0.2911  -------
# -------  Class: dog              AP:   0.2274  -------
# -------  Class: horse            AP:   0.3584  -------
# -------  Class: motorbike        AP:   0.1973  -------
# -------  Class: person           AP:   0.6682  -------
# -------  Class: pottedplant      AP:   0.1186  -------
# -------  Class: sheep            AP:   0.1509  -------
# -------  Class: sofa             AP:   0.2155  -------
# -------  Class: train            AP:   0.3397  -------
# -------  Class: tvmonitor        AP:   0.1339  -------
# mAP: 0.2693
# Avg loss: 0.20971778468995156
# Evaluating classifier
# Mean Precision Score for Testing on Epoch 20 is 0.2693180677495423
# Starting epoch number 21
# Loss for Training on Epoch 21 is 0.19373752176761627
# Starting epoch number 22
# Loss for Training on Epoch 22 is 0.19224843382835388
# Starting epoch number 23
# Loss for Training on Epoch 23 is 0.19052119553089142
# Starting epoch number 24
# Loss for Training on Epoch 24 is 0.18928371369838715
# Starting epoch number 25
# Loss for Training on Epoch 25 is 0.1897350698709488
# -------  Class: aeroplane        AP:   0.4939  -------
# -------  Class: bicycle          AP:   0.2869  -------
# -------  Class: bird             AP:   0.1834  -------
# -------  Class: boat             AP:   0.2259  -------
# -------  Class: bottle           AP:   0.1268  -------
# -------  Class: bus              AP:   0.1822  -------
# -------  Class: car              AP:   0.5138  -------
# -------  Class: cat              AP:   0.3586  -------
# -------  Class: chair            AP:   0.3722  -------
# -------  Class: cow              AP:   0.1249  -------
# -------  Class: diningtable      AP:   0.2933  -------
# -------  Class: dog              AP:   0.2379  -------
# -------  Class: horse            AP:   0.3541  -------
# -------  Class: motorbike        AP:   0.2690  -------
# -------  Class: person           AP:   0.6931  -------
# -------  Class: pottedplant      AP:   0.1575  -------
# -------  Class: sheep            AP:   0.1795  -------
# -------  Class: sofa             AP:   0.2484  -------
# -------  Class: train            AP:   0.3360  -------
# -------  Class: tvmonitor        AP:   0.2404  -------
# mAP: 0.2939
# Avg loss: 0.2175820445335364
# Evaluating classifier
# Mean Precision Score for Testing on Epoch 25 is 0.2938803885342375
# Starting epoch number 26
# Loss for Training on Epoch 26 is 0.18759746849536896
# Starting epoch number 27
# Loss for Training on Epoch 27 is 0.18732088804244995
# Starting epoch number 28
# Loss for Training on Epoch 28 is 0.18610285222530365
# Starting epoch number 29
# Loss for Training on Epoch 29 is 0.18422460556030273
# Starting epoch number 30
# Loss for Training on Epoch 30 is 0.18358299136161804
# -------  Class: aeroplane        AP:   0.5115  -------
# -------  Class: bicycle          AP:   0.3062  -------
# -------  Class: bird             AP:   0.1728  -------
# -------  Class: boat             AP:   0.2341  -------
# -------  Class: bottle           AP:   0.1406  -------
# -------  Class: bus              AP:   0.2122  -------
# -------  Class: car              AP:   0.5104  -------
# -------  Class: cat              AP:   0.3382  -------
# -------  Class: chair            AP:   0.3905  -------
# -------  Class: cow              AP:   0.1358  -------
# -------  Class: diningtable      AP:   0.2720  -------
# -------  Class: dog              AP:   0.2215  -------
# -------  Class: horse            AP:   0.4035  -------
# -------  Class: motorbike        AP:   0.2975  -------
# -------  Class: person           AP:   0.6868  -------
# -------  Class: pottedplant      AP:   0.1514  -------
# -------  Class: sheep            AP:   0.1802  -------
# -------  Class: sofa             AP:   0.2609  -------
# -------  Class: train            AP:   0.3529  -------
# -------  Class: tvmonitor        AP:   0.2900  -------
# mAP: 0.3035
# Avg loss: 0.2052120747445505
# Evaluating classifier
# Mean Precision Score for Testing on Epoch 30 is 0.30345043815715594
# Starting epoch number 31
# Loss for Training on Epoch 31 is 0.18327957391738892
# Starting epoch number 32
# Loss for Training on Epoch 32 is 0.18331865966320038
# Starting epoch number 33
# Loss for Training on Epoch 33 is 0.18291454017162323
# Starting epoch number 34
# Loss for Training on Epoch 34 is 0.18119367957115173
# Starting epoch number 35
# Loss for Training on Epoch 35 is 0.17944137752056122
# -------  Class: aeroplane        AP:   0.5479  -------
# -------  Class: bicycle          AP:   0.2780  -------
# -------  Class: bird             AP:   0.2153  -------
# -------  Class: boat             AP:   0.2536  -------
# -------  Class: bottle           AP:   0.1591  -------
# -------  Class: bus              AP:   0.1746  -------
# -------  Class: car              AP:   0.5228  -------
# -------  Class: cat              AP:   0.3565  -------
# -------  Class: chair            AP:   0.3767  -------
# -------  Class: cow              AP:   0.1360  -------
# -------  Class: diningtable      AP:   0.3386  -------
# -------  Class: dog              AP:   0.2605  -------
# -------  Class: horse            AP:   0.4357  -------
# -------  Class: motorbike        AP:   0.3999  -------
# -------  Class: person           AP:   0.7217  -------
# -------  Class: pottedplant      AP:   0.1486  -------
# -------  Class: sheep            AP:   0.1853  -------
# -------  Class: sofa             AP:   0.2564  -------
# -------  Class: train            AP:   0.3780  -------
# -------  Class: tvmonitor        AP:   0.2168  -------
# mAP: 0.3181
# Avg loss: 0.21005421895769577
# Evaluating classifier
# Mean Precision Score for Testing on Epoch 35 is 0.3180891014532508
# Starting epoch number 36
# Loss for Training on Epoch 36 is 0.17948505282402039
# Starting epoch number 37
# Loss for Training on Epoch 37 is 0.1786239743232727
# Starting epoch number 38
# Loss for Training on Epoch 38 is 0.1767701804637909
# Starting epoch number 39
# Loss for Training on Epoch 39 is 0.17768444120883942
# Starting epoch number 40
# Loss for Training on Epoch 40 is 0.17680929601192474
# -------  Class: aeroplane        AP:   0.5317  -------
# -------  Class: bicycle          AP:   0.3361  -------
# -------  Class: bird             AP:   0.2421  -------
# -------  Class: boat             AP:   0.2046  -------
# -------  Class: bottle           AP:   0.1480  -------
# -------  Class: bus              AP:   0.2163  -------
# -------  Class: car              AP:   0.5228  -------
# -------  Class: cat              AP:   0.3537  -------
# -------  Class: chair            AP:   0.4087  -------
# -------  Class: cow              AP:   0.1292  -------
# -------  Class: diningtable      AP:   0.3242  -------
# -------  Class: dog              AP:   0.2486  -------
# -------  Class: horse            AP:   0.4624  -------
# -------  Class: motorbike        AP:   0.4244  -------
# -------  Class: person           AP:   0.7361  -------
# -------  Class: pottedplant      AP:   0.1764  -------
# -------  Class: sheep            AP:   0.1970  -------
# -------  Class: sofa             AP:   0.2539  -------
# -------  Class: train            AP:   0.4403  -------
# -------  Class: tvmonitor        AP:   0.2762  -------
# mAP: 0.3316
# Avg loss: 0.20056070990954775
# Evaluating classifier
# Mean Precision Score for Testing on Epoch 40 is 0.3316296152830972
# Starting epoch number 41
# Loss for Training on Epoch 41 is 0.17310838401317596
# Starting epoch number 42
# Loss for Training on Epoch 42 is 0.17363972961902618
# Starting epoch number 43
# Loss for Training on Epoch 43 is 0.17274333536624908
# Starting epoch number 44
# Loss for Training on Epoch 44 is 0.17416732013225555
# Starting epoch number 45
# Loss for Training on Epoch 45 is 0.1718064844608307
# -------  Class: aeroplane        AP:   0.5813  -------
# -------  Class: bicycle          AP:   0.3056  -------
# -------  Class: bird             AP:   0.2082  -------
# -------  Class: boat             AP:   0.2699  -------
# -------  Class: bottle           AP:   0.1666  -------
# -------  Class: bus              AP:   0.2018  -------
# -------  Class: car              AP:   0.5486  -------
# -------  Class: cat              AP:   0.3758  -------
# -------  Class: chair            AP:   0.4285  -------
# -------  Class: cow              AP:   0.1358  -------
# -------  Class: diningtable      AP:   0.3836  -------
# -------  Class: dog              AP:   0.2684  -------
# -------  Class: horse            AP:   0.4569  -------
# -------  Class: motorbike        AP:   0.4356  -------
# -------  Class: person           AP:   0.7416  -------
# -------  Class: pottedplant      AP:   0.1582  -------
# -------  Class: sheep            AP:   0.1786  -------
# -------  Class: sofa             AP:   0.2847  -------
# -------  Class: train            AP:   0.5158  -------
# -------  Class: tvmonitor        AP:   0.2890  -------
# mAP: 0.3467
# Avg loss: 0.20409679092183897
# Evaluating classifier
# Mean Precision Score for Testing on Epoch 45 is 0.34671930875604906
# Starting epoch number 46
# Loss for Training on Epoch 46 is 0.16850033402442932
# Starting epoch number 47
# Loss for Training on Epoch 47 is 0.1677439957857132
# Starting epoch number 48
# Loss for Training on Epoch 48 is 0.16933071613311768
# Starting epoch number 49
# Loss for Training on Epoch 49 is 0.16849245131015778
# Starting epoch number 50
# Loss for Training on Epoch 50 is 0.16929465532302856
# -------  Class: aeroplane        AP:   0.5655  -------
# -------  Class: bicycle          AP:   0.3488  -------
# -------  Class: bird             AP:   0.2092  -------
# -------  Class: boat             AP:   0.2455  -------
# -------  Class: bottle           AP:   0.1754  -------
# -------  Class: bus              AP:   0.2101  -------
# -------  Class: car              AP:   0.5682  -------
# -------  Class: cat              AP:   0.3795  -------
# -------  Class: chair            AP:   0.4243  -------
# -------  Class: cow              AP:   0.1472  -------
# -------  Class: diningtable      AP:   0.3648  -------
# -------  Class: dog              AP:   0.2634  -------
# -------  Class: horse            AP:   0.4630  -------
# -------  Class: motorbike        AP:   0.4677  -------
# -------  Class: person           AP:   0.7304  -------
# -------  Class: pottedplant      AP:   0.1911  -------
# -------  Class: sheep            AP:   0.2269  -------
# -------  Class: sofa             AP:   0.2656  -------
# -------  Class: train            AP:   0.4925  -------
# -------  Class: tvmonitor        AP:   0.3077  -------
# mAP: 0.3523
# Avg loss: 0.20099310426017905
# Evaluating classifier
# Mean Precision Score for Testing on Epoch 50 is 0.35234145425569646
# Starting epoch number 51
# Loss for Training on Epoch 51 is 0.16707687079906464
# Starting epoch number 52
# Loss for Training on Epoch 52 is 0.16474521160125732
# Starting epoch number 53
# Loss for Training on Epoch 53 is 0.1662215292453766
# Starting epoch number 54
# Loss for Training on Epoch 54 is 0.16327497363090515
# Starting epoch number 55
# Loss for Training on Epoch 55 is 0.16320256888866425
# -------  Class: aeroplane        AP:   0.5944  -------
# -------  Class: bicycle          AP:   0.3387  -------
# -------  Class: bird             AP:   0.2561  -------
# -------  Class: boat             AP:   0.2543  -------
# -------  Class: bottle           AP:   0.1646  -------
# -------  Class: bus              AP:   0.2221  -------
# -------  Class: car              AP:   0.5637  -------
# -------  Class: cat              AP:   0.3879  -------
# -------  Class: chair            AP:   0.4388  -------
# -------  Class: cow              AP:   0.1535  -------
# -------  Class: diningtable      AP:   0.4047  -------
# -------  Class: dog              AP:   0.2686  -------
# -------  Class: horse            AP:   0.4822  -------
# -------  Class: motorbike        AP:   0.4894  -------
# -------  Class: person           AP:   0.7594  -------
# -------  Class: pottedplant      AP:   0.1644  -------
# -------  Class: sheep            AP:   0.1807  -------
# -------  Class: sofa             AP:   0.2671  -------
# -------  Class: train            AP:   0.5069  -------
# -------  Class: tvmonitor        AP:   0.3186  -------
# mAP: 0.3608
# Avg loss: 0.19957715763321407
# Evaluating classifier
# Mean Precision Score for Testing on Epoch 55 is 0.3607968027430906
# Starting epoch number 56
# Loss for Training on Epoch 56 is 0.16371889412403107
# Starting epoch number 57
# Loss for Training on Epoch 57 is 0.16233707964420319
# Starting epoch number 58
# Loss for Training on Epoch 58 is 0.1630263477563858
# Starting epoch number 59
# Loss for Training on Epoch 59 is 0.1598423421382904
# Starting epoch number 60
# Loss for Training on Epoch 60 is 0.16207663714885712
# -------  Class: aeroplane        AP:   0.5912  -------
# -------  Class: bicycle          AP:   0.3521  -------
# -------  Class: bird             AP:   0.2803  -------
# -------  Class: boat             AP:   0.2318  -------
# -------  Class: bottle           AP:   0.1543  -------
# -------  Class: bus              AP:   0.2280  -------
# -------  Class: car              AP:   0.5368  -------
# -------  Class: cat              AP:   0.3788  -------
# -------  Class: chair            AP:   0.4325  -------
# -------  Class: cow              AP:   0.1377  -------
# -------  Class: diningtable      AP:   0.3921  -------
# -------  Class: dog              AP:   0.2928  -------
# -------  Class: horse            AP:   0.4842  -------
# -------  Class: motorbike        AP:   0.4710  -------
# -------  Class: person           AP:   0.7661  -------
# -------  Class: pottedplant      AP:   0.1960  -------
# -------  Class: sheep            AP:   0.1867  -------
# -------  Class: sofa             AP:   0.2978  -------
# -------  Class: train            AP:   0.5402  -------
# -------  Class: tvmonitor        AP:   0.2938  -------
# mAP: 0.3622
# Avg loss: 0.20010629635822924
# Evaluating classifier
# Mean Precision Score for Testing on Epoch 60 is 0.36221134765083296
# Starting epoch number 61
# Loss for Training on Epoch 61 is 0.1593235433101654
# Starting epoch number 62
# Loss for Training on Epoch 62 is 0.15693846344947815
# Starting epoch number 63
# Loss for Training on Epoch 63 is 0.15891315042972565
# Starting epoch number 64
# Loss for Training on Epoch 64 is 0.15792840719223022
# Starting epoch number 65
# Loss for Training on Epoch 65 is 0.1563086062669754
# -------  Class: aeroplane        AP:   0.5869  -------
# -------  Class: bicycle          AP:   0.4114  -------
# -------  Class: bird             AP:   0.3048  -------
# -------  Class: boat             AP:   0.2846  -------
# -------  Class: bottle           AP:   0.1756  -------
# -------  Class: bus              AP:   0.2657  -------
# -------  Class: car              AP:   0.5836  -------
# -------  Class: cat              AP:   0.3766  -------
# -------  Class: chair            AP:   0.4558  -------
# -------  Class: cow              AP:   0.1374  -------
# -------  Class: diningtable      AP:   0.3922  -------
# -------  Class: dog              AP:   0.2972  -------
# -------  Class: horse            AP:   0.4977  -------
# -------  Class: motorbike        AP:   0.4819  -------
# -------  Class: person           AP:   0.7672  -------
# -------  Class: pottedplant      AP:   0.1653  -------
# -------  Class: sheep            AP:   0.1953  -------
# -------  Class: sofa             AP:   0.3008  -------
# -------  Class: train            AP:   0.5430  -------
# -------  Class: tvmonitor        AP:   0.3167  -------
# mAP: 0.3770
# Avg loss: 0.20102369596686545
# Evaluating classifier
# Mean Precision Score for Testing on Epoch 65 is 0.37697624225473997
# Starting epoch number 66
# Loss for Training on Epoch 66 is 0.15587958693504333
# Starting epoch number 67
# Loss for Training on Epoch 67 is 0.15704987943172455
# Starting epoch number 68
# Loss for Training on Epoch 68 is 0.1564854383468628
# Starting epoch number 69
# Loss for Training on Epoch 69 is 0.15412329137325287
# Starting epoch number 70
# Loss for Training on Epoch 70 is 0.15394063293933868
# -------  Class: aeroplane        AP:   0.5948  -------
# -------  Class: bicycle          AP:   0.3681  -------
# -------  Class: bird             AP:   0.2870  -------
# -------  Class: boat             AP:   0.2990  -------
# -------  Class: bottle           AP:   0.1634  -------
# -------  Class: bus              AP:   0.2509  -------
# -------  Class: car              AP:   0.5654  -------
# -------  Class: cat              AP:   0.3535  -------
# -------  Class: chair            AP:   0.4404  -------
# -------  Class: cow              AP:   0.1462  -------
# -------  Class: diningtable      AP:   0.3631  -------
# -------  Class: dog              AP:   0.2591  -------
# -------  Class: horse            AP:   0.4620  -------
# -------  Class: motorbike        AP:   0.4365  -------
# -------  Class: person           AP:   0.7502  -------
# -------  Class: pottedplant      AP:   0.2078  -------
# -------  Class: sheep            AP:   0.1768  -------
# -------  Class: sofa             AP:   0.2979  -------
# -------  Class: train            AP:   0.5607  -------
# -------  Class: tvmonitor        AP:   0.3392  -------
# mAP: 0.3661
# Avg loss: 0.20409530797336675
# Evaluating classifier
# Mean Precision Score for Testing on Epoch 70 is 0.3660978222703173
# Starting epoch number 71
# Loss for Training on Epoch 71 is 0.15421783924102783
# Starting epoch number 72
# Loss for Training on Epoch 72 is 0.15143431723117828
# Starting epoch number 73
# Loss for Training on Epoch 73 is 0.15290986001491547
# Starting epoch number 74
# Loss for Training on Epoch 74 is 0.153079092502594
# Starting epoch number 75
# Loss for Training on Epoch 75 is 0.14846983551979065
# -------  Class: aeroplane        AP:   0.5792  -------
# -------  Class: bicycle          AP:   0.3857  -------
# -------  Class: bird             AP:   0.2712  -------
# -------  Class: boat             AP:   0.2731  -------
# -------  Class: bottle           AP:   0.1655  -------
# -------  Class: bus              AP:   0.1927  -------
# -------  Class: car              AP:   0.5642  -------
# -------  Class: cat              AP:   0.3481  -------
# -------  Class: chair            AP:   0.4201  -------
# -------  Class: cow              AP:   0.1534  -------
# -------  Class: diningtable      AP:   0.3521  -------
# -------  Class: dog              AP:   0.2813  -------
# -------  Class: horse            AP:   0.4855  -------
# -------  Class: motorbike        AP:   0.4898  -------
# -------  Class: person           AP:   0.7646  -------
# -------  Class: pottedplant      AP:   0.1913  -------
# -------  Class: sheep            AP:   0.1604  -------
# -------  Class: sofa             AP:   0.2747  -------
# -------  Class: train            AP:   0.5674  -------
# -------  Class: tvmonitor        AP:   0.2476  -------
# mAP: 0.3584
# Avg loss: 0.20272440755669074
# Evaluating classifier
# Mean Precision Score for Testing on Epoch 75 is 0.3583944453099457
# Starting epoch number 76
# Loss for Training on Epoch 76 is 0.1499483734369278
# Starting epoch number 77
# Loss for Training on Epoch 77 is 0.14953894913196564
# Starting epoch number 78
# Loss for Training on Epoch 78 is 0.14916056394577026
# Starting epoch number 79
# Loss for Training on Epoch 79 is 0.14636273682117462
# Starting epoch number 80
# Loss for Training on Epoch 80 is 0.147519052028656
# -------  Class: aeroplane        AP:   0.5755  -------
# -------  Class: bicycle          AP:   0.3898  -------
# -------  Class: bird             AP:   0.2523  -------
# -------  Class: boat             AP:   0.2753  -------
# -------  Class: bottle           AP:   0.1873  -------
# -------  Class: bus              AP:   0.2268  -------
# -------  Class: car              AP:   0.5731  -------
# -------  Class: cat              AP:   0.3797  -------
# -------  Class: chair            AP:   0.4363  -------
# -------  Class: cow              AP:   0.1463  -------
# -------  Class: diningtable      AP:   0.3665  -------
# -------  Class: dog              AP:   0.2620  -------
# -------  Class: horse            AP:   0.4908  -------
# -------  Class: motorbike        AP:   0.5139  -------
# -------  Class: person           AP:   0.7608  -------
# -------  Class: pottedplant      AP:   0.2072  -------
# -------  Class: sheep            AP:   0.1684  -------
# -------  Class: sofa             AP:   0.2645  -------
# -------  Class: train            AP:   0.5734  -------
# -------  Class: tvmonitor        AP:   0.2502  -------
# mAP: 0.3650
# Avg loss: 0.20303519485117513
# Evaluating classifier
# Mean Precision Score for Testing on Epoch 80 is 0.3650058363449325
# Starting epoch number 81
# Loss for Training on Epoch 81 is 0.14629514515399933
# Starting epoch number 82
# Loss for Training on Epoch 82 is 0.14446772634983063
# Starting epoch number 83
# Loss for Training on Epoch 83 is 0.14479520916938782
# Starting epoch number 84
# Loss for Training on Epoch 84 is 0.1442895233631134
# Starting epoch number 85
# Loss for Training on Epoch 85 is 0.14273038506507874
# -------  Class: aeroplane        AP:   0.6219  -------
# -------  Class: bicycle          AP:   0.4352  -------
# -------  Class: bird             AP:   0.3457  -------
# -------  Class: boat             AP:   0.3147  -------
# -------  Class: bottle           AP:   0.1787  -------
# -------  Class: bus              AP:   0.2840  -------
# -------  Class: car              AP:   0.5597  -------
# -------  Class: cat              AP:   0.3618  -------
# -------  Class: chair            AP:   0.4296  -------
# -------  Class: cow              AP:   0.1636  -------
# -------  Class: diningtable      AP:   0.3649  -------
# -------  Class: dog              AP:   0.2754  -------
# -------  Class: horse            AP:   0.4978  -------
# -------  Class: motorbike        AP:   0.5680  -------
# -------  Class: person           AP:   0.7748  -------
# -------  Class: pottedplant      AP:   0.1899  -------
# -------  Class: sheep            AP:   0.1497  -------
# -------  Class: sofa             AP:   0.2947  -------
# -------  Class: train            AP:   0.6012  -------
# -------  Class: tvmonitor        AP:   0.3124  -------
# mAP: 0.3862
# Avg loss: 0.1975023759694039
# Evaluating classifier
# Mean Precision Score for Testing on Epoch 85 is 0.38617978805045017
# Starting epoch number 86
# Loss for Training on Epoch 86 is 0.141598179936409
# Starting epoch number 87
# Loss for Training on Epoch 87 is 0.14291520416736603
# Starting epoch number 88
# Loss for Training on Epoch 88 is 0.14104609191417694
# Starting epoch number 89
# Loss for Training on Epoch 89 is 0.14134514331817627
# Starting epoch number 90
# Loss for Training on Epoch 90 is 0.14133431017398834
# -------  Class: aeroplane        AP:   0.6057  -------
# -------  Class: bicycle          AP:   0.4330  -------
# -------  Class: bird             AP:   0.3434  -------
# -------  Class: boat             AP:   0.3549  -------
# -------  Class: bottle           AP:   0.1789  -------
# -------  Class: bus              AP:   0.2907  -------
# -------  Class: car              AP:   0.6054  -------
# -------  Class: cat              AP:   0.3674  -------
# -------  Class: chair            AP:   0.4521  -------
# -------  Class: cow              AP:   0.1662  -------
# -------  Class: diningtable      AP:   0.3693  -------
# -------  Class: dog              AP:   0.2595  -------
# -------  Class: horse            AP:   0.4850  -------
# -------  Class: motorbike        AP:   0.5741  -------
# -------  Class: person           AP:   0.7650  -------
# -------  Class: pottedplant      AP:   0.1911  -------
# -------  Class: sheep            AP:   0.1561  -------
# -------  Class: sofa             AP:   0.3283  -------
# -------  Class: train            AP:   0.6354  -------
# -------  Class: tvmonitor        AP:   0.3227  -------
# mAP: 0.3942
# Avg loss: 0.1942725941727433
# Evaluating classifier
# Mean Precision Score for Testing on Epoch 90 is 0.39421480578327606
# Starting epoch number 91
# Loss for Training on Epoch 91 is 0.1388109028339386
# Starting epoch number 92
# Loss for Training on Epoch 92 is 0.1374916285276413
# Starting epoch number 93
# Loss for Training on Epoch 93 is 0.13718944787979126
# Starting epoch number 94
# Loss for Training on Epoch 94 is 0.13767969608306885
# Starting epoch number 95
# Loss for Training on Epoch 95 is 0.1357092410326004
# -------  Class: aeroplane        AP:   0.6173  -------
# -------  Class: bicycle          AP:   0.4389  -------
# -------  Class: bird             AP:   0.3271  -------
# -------  Class: boat             AP:   0.3592  -------
# -------  Class: bottle           AP:   0.1909  -------
# -------  Class: bus              AP:   0.3044  -------
# -------  Class: car              AP:   0.5943  -------
# -------  Class: cat              AP:   0.3705  -------
# -------  Class: chair            AP:   0.4490  -------
# -------  Class: cow              AP:   0.1905  -------
# -------  Class: diningtable      AP:   0.3834  -------
# -------  Class: dog              AP:   0.2909  -------
# -------  Class: horse            AP:   0.5111  -------
# -------  Class: motorbike        AP:   0.5673  -------
# -------  Class: person           AP:   0.7832  -------
# -------  Class: pottedplant      AP:   0.1935  -------
# -------  Class: sheep            AP:   0.1717  -------
# -------  Class: sofa             AP:   0.3147  -------
# -------  Class: train            AP:   0.6040  -------
# -------  Class: tvmonitor        AP:   0.3237  -------
# mAP: 0.3993
# Avg loss: 0.1951891142356245
# Evaluating classifier
# Mean Precision Score for Testing on Epoch 95 is 0.39926858164986007
# Starting epoch number 96
# Loss for Training on Epoch 96 is 0.13564276695251465
# Starting epoch number 97
# Loss for Training on Epoch 97 is 0.13654568791389465
# Starting epoch number 98
# Loss for Training on Epoch 98 is 0.13410797715187073
# Starting epoch number 99
# Loss for Training on Epoch 99 is 0.13259345293045044
# Starting epoch number 100
# Loss for Training on Epoch 100 is 0.1329672932624817
# -------  Class: aeroplane        AP:   0.6408  -------
# -------  Class: bicycle          AP:   0.4220  -------
# -------  Class: bird             AP:   0.2938  -------
# -------  Class: boat             AP:   0.3605  -------
# -------  Class: bottle           AP:   0.1768  -------
# -------  Class: bus              AP:   0.3498  -------
# -------  Class: car              AP:   0.5701  -------
# -------  Class: cat              AP:   0.3790  -------
# -------  Class: chair            AP:   0.4656  -------
# -------  Class: cow              AP:   0.1566  -------
# -------  Class: diningtable      AP:   0.3819  -------
# -------  Class: dog              AP:   0.2869  -------
# -------  Class: horse            AP:   0.5218  -------
# -------  Class: motorbike        AP:   0.5326  -------
# -------  Class: person           AP:   0.7786  -------
# -------  Class: pottedplant      AP:   0.1893  -------
# -------  Class: sheep            AP:   0.2047  -------
# -------  Class: sofa             AP:   0.3129  -------
# -------  Class: train            AP:   0.5968  -------
# -------  Class: tvmonitor        AP:   0.3708  -------
# mAP: 0.3996
# Avg loss: 0.19757729881926428
# Evaluating classifier
# Mean Precision Score for Testing on Epoch 100 is 0.3995703515982015

# %%
ds_test = VocDataset('/content/VOCdevkit_2007/VOC2007test/','test', test_transform)

test_loader = torch.utils.data.DataLoader(dataset=ds_test,
                                               batch_size=50, 
                                               shuffle=False,
                                               num_workers=1)

# Transforms applied to the testing data
test_transform = transforms.Compose([
            transforms.Resize(227),
            transforms.CenterCrop(227),
            transforms.ToTensor(),
            normalize,
        ])

plot_losses(train_losses, val_losses, test_frequency, num_epochs)
plot_mAP(train_mAPs, val_mAPs, test_frequency, num_epochs)
mAP_test, test_loss, test_aps = test_classifier(test_loader, classifier, criterion)
print(mAP_test)
torch.save(classifier.state_dict(), './voc_my_best_classifier.pth')
output_submission_csv('my_solution.csv', test_aps)
# Out:
# -------  Class: aeroplane        AP:   0.6404  -------
# -------  Class: bicycle          AP:   0.3569  -------
# -------  Class: bird             AP:   0.3067  -------
# -------  Class: boat             AP:   0.4186  -------
# -------  Class: bottle           AP:   0.1674  -------
# -------  Class: bus              AP:   0.2763  -------
# -------  Class: car              AP:   0.6258  -------
# -------  Class: cat              AP:   0.3400  -------
# -------  Class: chair            AP:   0.4755  -------
# -------  Class: cow              AP:   0.1795  -------
# -------  Class: diningtable      AP:   0.3919  -------
# -------  Class: dog              AP:   0.2953  -------
# -------  Class: horse            AP:   0.6320  -------
# -------  Class: motorbike        AP:   0.5129  -------
# -------  Class: person           AP:   0.7799  -------
# -------  Class: pottedplant      AP:   0.2266  -------
# -------  Class: sheep            AP:   0.2480  -------
# -------  Class: sofa             AP:   0.2487  -------
# -------  Class: train            AP:   0.6016  -------
# -------  Class: tvmonitor        AP:   0.3293  -------
# mAP: 0.4027
# Avg loss: 0.19430384889245034
# 0.40266954323446447

# %% [markdown]
# ## Alexnet with learning rate decay

# %%
def train_with_decay(classifier, num_epochs, train_loader, val_loader, criterion, optimizer, scheduler, test_frequency=5):
    train_losses = []
    train_mAPs = []
    val_losses = []
    val_mAPs = []

    for epoch in range(1,num_epochs+1):
        print("Starting epoch number " + str(epoch))
        train_loss = train_classifier_with_decay(train_loader, classifier, criterion, optimizer, scheduler)
        train_losses.append(train_loss)
        print("Loss for Training on Epoch " +str(epoch) + " is "+ str(train_loss))
        if(epoch%test_frequency==0 or epoch==1):
            mAP_train, _, _ = test_classifier(train_loader, classifier, criterion, False, False)
            train_mAPs.append(mAP_train)
            mAP_val, val_loss, _ = test_classifier(val_loader, classifier, criterion)
            print('Evaluating classifier')
            print("Mean Precision Score for Testing on Epoch " +str(epoch) + " is "+ str(mAP_val))
            val_losses.append(val_loss)
            val_mAPs.append(mAP_val)
    
    return classifier, train_losses, val_losses, train_mAPs, val_mAPs
def train_classifier_with_decay(train_loader, classifier, criterion, optimizer, scheduler):
    classifier.train()
    loss_ = 0.0
    losses = []
    for i, (images, labels, _) in enumerate(train_loader):
        # print(type(images), images.size())
        # images = images.permute(0, 3, 1, 2)
        images, labels = images.to(device), labels.to(device)
        optimizer.zero_grad()
        logits = classifier(images)
        loss = criterion(logits, labels)
        loss.backward()
        optimizer.step()
        scheduler.step()
        losses.append(loss)
    return torch.stack(losses).mean().item()

# %%
num_epochs = 5
test_frequency = 5
batch_size = 64

ds_train, ds_val = ImageAugmentation()

train_loader = torch.utils.data.DataLoader(dataset=ds_train,
                                               batch_size=batch_size, 
                                               shuffle=True,
                                               num_workers=1)

val_loader = torch.utils.data.DataLoader(dataset=ds_val,
                                               batch_size=batch_size, 
                                               shuffle=True,
                                               num_workers=1)

# TODO: Run your own classifier here
classifier = Alexnet().to(device)

criterion = nn.MultiLabelSoftMarginLoss()
optimizer = torch.optim.SGD(classifier.parameters(), lr=0.01, momentum=0.9)
# optimizer = torch.optim.Adam(classifier.parameters(), lr=1e-4)
scheduler = torch.optim.lr_scheduler.StepLR(optimizer, step_size=30, gamma=0.1)
# classifier, train_losses, val_losses, train_mAPs, val_mAPs = train_with_decay(classifier, num_epochs, train_loader, val_loader, criterion, optimizer, scheduler, test_frequency)
classifier, train_losses, val_losses, train_mAPs, val_mAPs = train(classifier, num_epochs, train_loader, val_loader, criterion, optimizer, test_frequency)
# Out:
# Starting epoch number 1
# Loss for Training on Epoch 1 is 0.33075639605522156
# -------  Class: aeroplane        AP:   0.0681  -------
# -------  Class: bicycle          AP:   0.0614  -------
# -------  Class: bird             AP:   0.0933  -------
# -------  Class: boat             AP:   0.0461  -------
# -------  Class: bottle           AP:   0.0447  -------
# -------  Class: bus              AP:   0.0403  -------
# -------  Class: car              AP:   0.1461  -------
# -------  Class: cat              AP:   0.0668  -------
# -------  Class: chair            AP:   0.1118  -------
# -------  Class: cow              AP:   0.0447  -------
# -------  Class: diningtable      AP:   0.0545  -------
# -------  Class: dog              AP:   0.0866  -------
# -------  Class: horse            AP:   0.0668  -------
# -------  Class: motorbike        AP:   0.0449  -------
# -------  Class: person           AP:   0.5012  -------
# -------  Class: pottedplant      AP:   0.0610  -------
# -------  Class: sheep            AP:   0.0366  -------
# -------  Class: sofa             AP:   0.0758  -------
# -------  Class: train            AP:   0.0996  -------
# -------  Class: tvmonitor        AP:   0.0417  -------
# mAP: 0.0896
# Avg loss: 0.24331632889807225
# Evaluating classifier
# Mean Precision Score for Testing on Epoch 1 is 0.08959426053887247
# Starting epoch number 2
# Loss for Training on Epoch 2 is 0.2377227544784546
# Starting epoch number 3
# Loss for Training on Epoch 3 is 0.2363441437482834
# Starting epoch number 4
# Loss for Training on Epoch 4 is 0.2333773821592331
# Starting epoch number 5
# Loss for Training on Epoch 5 is 0.23177383840084076
# -------  Class: aeroplane        AP:   0.2808  -------
# -------  Class: bicycle          AP:   0.1117  -------
# -------  Class: bird             AP:   0.1376  -------
# -------  Class: boat             AP:   0.1171  -------
# -------  Class: bottle           AP:   0.0708  -------
# -------  Class: bus              AP:   0.0753  -------
# -------  Class: car              AP:   0.2348  -------
# -------  Class: cat              AP:   0.1565  -------
# -------  Class: chair            AP:   0.2059  -------
# -------  Class: cow              AP:   0.0412  -------
# -------  Class: diningtable      AP:   0.1136  -------
# -------  Class: dog              AP:   0.1493  -------
# -------  Class: horse            AP:   0.1047  -------
# -------  Class: motorbike        AP:   0.1160  -------
# -------  Class: person           AP:   0.5095  -------
# -------  Class: pottedplant      AP:   0.1147  -------
# -------  Class: sheep            AP:   0.0432  -------
# -------  Class: sofa             AP:   0.1548  -------
# -------  Class: train            AP:   0.1347  -------
# -------  Class: tvmonitor        AP:   0.0593  -------
# mAP: 0.1466
# Avg loss: 0.23404295928776264
# Evaluating classifier
# Mean Precision Score for Testing on Epoch 5 is 0.14657865231606504

# %%
num_epochs = 100
test_frequency = 5
batch_size = 64
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

ds_train, ds_val = ImageAugmentation()

train_loader = torch.utils.data.DataLoader(dataset=ds_train,
                                               batch_size=batch_size, 
                                               shuffle=True,
                                               num_workers=1)

val_loader = torch.utils.data.DataLoader(dataset=ds_val,
                                               batch_size=batch_size, 
                                               shuffle=True,
                                               num_workers=1)

# TODO: Run your own classifier here
classifier = Alexnet().to(device)

criterion = nn.MultiLabelSoftMarginLoss()
optimizer = torch.optim.SGD(classifier.parameters(), lr=0.005, momentum=0.9)
# optimizer = torch.optim.Adam(classifier.parameters(), lr=1e-4)
scheduler = torch.optim.lr_scheduler.StepLR(optimizer, step_size=30, gamma=0.1)
# classifier, train_losses, val_losses, train_mAPs, val_mAPs = train_with_decay(classifier, num_epochs, train_loader, val_loader, criterion, optimizer, scheduler, test_frequency)
classifier, train_losses, val_losses, train_mAPs, val_mAPs = train(classifier, num_epochs, train_loader, val_loader, criterion, optimizer, test_frequency)
# Out:
# Starting epoch number 1
# Loss for Training on Epoch 1 is 0.3768998086452484
# -------  Class: aeroplane        AP:   0.1280  -------
# -------  Class: bicycle          AP:   0.0540  -------
# -------  Class: bird             AP:   0.0907  -------
# -------  Class: boat             AP:   0.0776  -------
# -------  Class: bottle           AP:   0.0399  -------
# -------  Class: bus              AP:   0.0311  -------
# -------  Class: car              AP:   0.1174  -------
# -------  Class: cat              AP:   0.0973  -------
# -------  Class: chair            AP:   0.1061  -------
# -------  Class: cow              AP:   0.0469  -------
# -------  Class: diningtable      AP:   0.0461  -------
# -------  Class: dog              AP:   0.1002  -------
# -------  Class: horse            AP:   0.0527  -------
# -------  Class: motorbike        AP:   0.0322  -------
# -------  Class: person           AP:   0.4763  -------
# -------  Class: pottedplant      AP:   0.0420  -------
# -------  Class: sheep            AP:   0.0489  -------
# -------  Class: sofa             AP:   0.0874  -------
# -------  Class: train            AP:   0.0554  -------
# -------  Class: tvmonitor        AP:   0.0420  -------
# mAP: 0.0886
# Avg loss: 0.3075851298868656
# Evaluating classifier
# Mean Precision Score for Testing on Epoch 1 is 0.0886169107186208
# Starting epoch number 2
# Loss for Training on Epoch 2 is 0.23979508876800537
# Starting epoch number 3
# Loss for Training on Epoch 3 is 0.23654213547706604
# Starting epoch number 4
# Loss for Training on Epoch 4 is 0.23613177239894867
# Starting epoch number 5
# Loss for Training on Epoch 5 is 0.23412306606769562
# -------  Class: aeroplane        AP:   0.1231  -------
# -------  Class: bicycle          AP:   0.0915  -------
# -------  Class: bird             AP:   0.1297  -------
# -------  Class: boat             AP:   0.0812  -------
# -------  Class: bottle           AP:   0.0510  -------
# -------  Class: bus              AP:   0.0509  -------
# -------  Class: car              AP:   0.1990  -------
# -------  Class: cat              AP:   0.1369  -------
# -------  Class: chair            AP:   0.1588  -------
# -------  Class: cow              AP:   0.0529  -------
# -------  Class: diningtable      AP:   0.0701  -------
# -------  Class: dog              AP:   0.1267  -------
# -------  Class: horse            AP:   0.0867  -------
# -------  Class: motorbike        AP:   0.0670  -------
# -------  Class: person           AP:   0.5050  -------
# -------  Class: pottedplant      AP:   0.0760  -------
# -------  Class: sheep            AP:   0.0578  -------
# -------  Class: sofa             AP:   0.1094  -------
# -------  Class: train            AP:   0.1111  -------
# -------  Class: tvmonitor        AP:   0.0445  -------
# mAP: 0.1165
# Avg loss: 0.23650974854826928
# Evaluating classifier
# Mean Precision Score for Testing on Epoch 5 is 0.11646340917822459
# Starting epoch number 6
# Loss for Training on Epoch 6 is 0.23418574035167694
# Starting epoch number 7
# Loss for Training on Epoch 7 is 0.23216354846954346
# Starting epoch number 8
# Loss for Training on Epoch 8 is 0.23134930431842804
# Starting epoch number 9
# Loss for Training on Epoch 9 is 0.23027925193309784
# Starting epoch number 10
# Loss for Training on Epoch 10 is 0.22729921340942383
# -------  Class: aeroplane        AP:   0.3112  -------
# -------  Class: bicycle          AP:   0.1276  -------
# -------  Class: bird             AP:   0.1227  -------
# -------  Class: boat             AP:   0.1982  -------
# -------  Class: bottle           AP:   0.0844  -------
# -------  Class: bus              AP:   0.0880  -------
# -------  Class: car              AP:   0.2380  -------
# -------  Class: cat              AP:   0.2011  -------
# -------  Class: chair            AP:   0.2205  -------
# -------  Class: cow              AP:   0.0499  -------
# -------  Class: diningtable      AP:   0.1363  -------
# -------  Class: dog              AP:   0.1590  -------
# -------  Class: horse            AP:   0.0995  -------
# -------  Class: motorbike        AP:   0.1331  -------
# -------  Class: person           AP:   0.5232  -------
# -------  Class: pottedplant      AP:   0.1048  -------
# -------  Class: sheep            AP:   0.0740  -------
# -------  Class: sofa             AP:   0.1619  -------
# -------  Class: train            AP:   0.1240  -------
# -------  Class: tvmonitor        AP:   0.0593  -------
# mAP: 0.1608
# Avg loss: 0.227381244674325
# Evaluating classifier
# Mean Precision Score for Testing on Epoch 10 is 0.16083474517811605
# Starting epoch number 11
# Loss for Training on Epoch 11 is 0.2255287915468216
# Starting epoch number 12
# Loss for Training on Epoch 12 is 0.22290430963039398
# Starting epoch number 13
# Loss for Training on Epoch 13 is 0.22258572280406952
# Starting epoch number 14
# Loss for Training on Epoch 14 is 0.22134581208229065
# Starting epoch number 15
# Loss for Training on Epoch 15 is 0.2183004915714264
# -------  Class: aeroplane        AP:   0.3675  -------
# -------  Class: bicycle          AP:   0.1350  -------
# -------  Class: bird             AP:   0.1091  -------
# -------  Class: boat             AP:   0.2044  -------
# -------  Class: bottle           AP:   0.1101  -------
# -------  Class: bus              AP:   0.1062  -------
# -------  Class: car              AP:   0.2735  -------
# -------  Class: cat              AP:   0.2250  -------
# -------  Class: chair            AP:   0.2375  -------
# -------  Class: cow              AP:   0.0447  -------
# -------  Class: diningtable      AP:   0.1868  -------
# -------  Class: dog              AP:   0.1663  -------
# -------  Class: horse            AP:   0.1001  -------
# -------  Class: motorbike        AP:   0.1619  -------
# -------  Class: person           AP:   0.5533  -------
# -------  Class: pottedplant      AP:   0.0891  -------
# -------  Class: sheep            AP:   0.0951  -------
# -------  Class: sofa             AP:   0.1697  -------
# -------  Class: train            AP:   0.1378  -------
# -------  Class: tvmonitor        AP:   0.0703  -------
# mAP: 0.1772
# Avg loss: 0.22219624184072018
# Evaluating classifier
# Mean Precision Score for Testing on Epoch 15 is 0.17716999463286126
# Starting epoch number 16
# Loss for Training on Epoch 16 is 0.21712251007556915
# Starting epoch number 17
# Loss for Training on Epoch 17 is 0.21494601666927338
# Starting epoch number 18
# Loss for Training on Epoch 18 is 0.2129252403974533
# Starting epoch number 19
# Loss for Training on Epoch 19 is 0.2132505476474762
# Starting epoch number 20
# Loss for Training on Epoch 20 is 0.21064312756061554
# -------  Class: aeroplane        AP:   0.3846  -------
# -------  Class: bicycle          AP:   0.1444  -------
# -------  Class: bird             AP:   0.1452  -------
# -------  Class: boat             AP:   0.2036  -------
# -------  Class: bottle           AP:   0.1003  -------
# -------  Class: bus              AP:   0.1086  -------
# -------  Class: car              AP:   0.3502  -------
# -------  Class: cat              AP:   0.2406  -------
# -------  Class: chair            AP:   0.2622  -------
# -------  Class: cow              AP:   0.0544  -------
# -------  Class: diningtable      AP:   0.1888  -------
# -------  Class: dog              AP:   0.1700  -------
# -------  Class: horse            AP:   0.1862  -------
# -------  Class: motorbike        AP:   0.1795  -------
# -------  Class: person           AP:   0.5964  -------
# -------  Class: pottedplant      AP:   0.0900  -------
# -------  Class: sheep            AP:   0.1031  -------
# -------  Class: sofa             AP:   0.1551  -------
# -------  Class: train            AP:   0.1779  -------
# -------  Class: tvmonitor        AP:   0.0813  -------
# mAP: 0.1961
# Avg loss: 0.21693820096552371
# Evaluating classifier
# Mean Precision Score for Testing on Epoch 20 is 0.19610742527375719
# Starting epoch number 21
# Loss for Training on Epoch 21 is 0.21492956578731537
# Starting epoch number 22
# Loss for Training on Epoch 22 is 0.21061860024929047
# Starting epoch number 23
# Loss for Training on Epoch 23 is 0.21017666161060333
# Starting epoch number 24
# Loss for Training on Epoch 24 is 0.2093423455953598
# Starting epoch number 25
# Loss for Training on Epoch 25 is 0.2090476006269455
# -------  Class: aeroplane        AP:   0.3997  -------
# -------  Class: bicycle          AP:   0.1562  -------
# -------  Class: bird             AP:   0.1567  -------
# -------  Class: boat             AP:   0.1988  -------
# -------  Class: bottle           AP:   0.1142  -------
# -------  Class: bus              AP:   0.1036  -------
# -------  Class: car              AP:   0.3668  -------
# -------  Class: cat              AP:   0.2417  -------
# -------  Class: chair            AP:   0.2521  -------
# -------  Class: cow              AP:   0.0603  -------
# -------  Class: diningtable      AP:   0.1855  -------
# -------  Class: dog              AP:   0.1762  -------
# -------  Class: horse            AP:   0.2103  -------
# -------  Class: motorbike        AP:   0.1882  -------
# -------  Class: person           AP:   0.5994  -------
# -------  Class: pottedplant      AP:   0.1000  -------
# -------  Class: sheep            AP:   0.1395  -------
# -------  Class: sofa             AP:   0.1577  -------
# -------  Class: train            AP:   0.2084  -------
# -------  Class: tvmonitor        AP:   0.0856  -------
# mAP: 0.2050
# Avg loss: 0.2254983965307474
# Evaluating classifier
# Mean Precision Score for Testing on Epoch 25 is 0.2050439375582352
# Starting epoch number 26
# Loss for Training on Epoch 26 is 0.21000643074512482
# Starting epoch number 27
# Loss for Training on Epoch 27 is 0.2083338350057602
# Starting epoch number 28
# Loss for Training on Epoch 28 is 0.20629167556762695
# Starting epoch number 29
# Loss for Training on Epoch 29 is 0.20511069893836975
# Starting epoch number 30
# Loss for Training on Epoch 30 is 0.20300643146038055
# -------  Class: aeroplane        AP:   0.4283  -------
# -------  Class: bicycle          AP:   0.1598  -------
# -------  Class: bird             AP:   0.1644  -------
# -------  Class: boat             AP:   0.2047  -------
# -------  Class: bottle           AP:   0.1088  -------
# -------  Class: bus              AP:   0.1194  -------
# -------  Class: car              AP:   0.4046  -------
# -------  Class: cat              AP:   0.2766  -------
# -------  Class: chair            AP:   0.2592  -------
# -------  Class: cow              AP:   0.0717  -------
# -------  Class: diningtable      AP:   0.1726  -------
# -------  Class: dog              AP:   0.1845  -------
# -------  Class: horse            AP:   0.2736  -------
# -------  Class: motorbike        AP:   0.1926  -------
# -------  Class: person           AP:   0.6189  -------
# -------  Class: pottedplant      AP:   0.1097  -------
# -------  Class: sheep            AP:   0.1451  -------
# -------  Class: sofa             AP:   0.1563  -------
# -------  Class: train            AP:   0.2103  -------
# -------  Class: tvmonitor        AP:   0.1002  -------
# mAP: 0.2180
# Avg loss: 0.22480667419731618
# Evaluating classifier
# Mean Precision Score for Testing on Epoch 30 is 0.21804957586381027
# Starting epoch number 31
# Loss for Training on Epoch 31 is 0.20353884994983673
# Starting epoch number 32
# Loss for Training on Epoch 32 is 0.20373974740505219
# Starting epoch number 33
# Loss for Training on Epoch 33 is 0.20278072357177734
# Starting epoch number 34
# Loss for Training on Epoch 34 is 0.20309136807918549
# Starting epoch number 35
# Loss for Training on Epoch 35 is 0.2009647935628891
# -------  Class: aeroplane        AP:   0.4321  -------
# -------  Class: bicycle          AP:   0.2023  -------
# -------  Class: bird             AP:   0.1656  -------
# -------  Class: boat             AP:   0.2079  -------
# -------  Class: bottle           AP:   0.1139  -------
# -------  Class: bus              AP:   0.1347  -------
# -------  Class: car              AP:   0.4307  -------
# -------  Class: cat              AP:   0.2741  -------
# -------  Class: chair            AP:   0.2720  -------
# -------  Class: cow              AP:   0.0817  -------
# -------  Class: diningtable      AP:   0.1910  -------
# -------  Class: dog              AP:   0.1800  -------
# -------  Class: horse            AP:   0.2993  -------
# -------  Class: motorbike        AP:   0.1886  -------
# -------  Class: person           AP:   0.6318  -------
# -------  Class: pottedplant      AP:   0.1141  -------
# -------  Class: sheep            AP:   0.1466  -------
# -------  Class: sofa             AP:   0.1854  -------
# -------  Class: train            AP:   0.2275  -------
# -------  Class: tvmonitor        AP:   0.1099  -------
# mAP: 0.2295
# Avg loss: 0.2229577772319317
# Evaluating classifier
# Mean Precision Score for Testing on Epoch 35 is 0.2294668225261022
# Starting epoch number 36
# Loss for Training on Epoch 36 is 0.201005220413208
# Starting epoch number 37
# Loss for Training on Epoch 37 is 0.2020844966173172
# Starting epoch number 38
# Loss for Training on Epoch 38 is 0.199929878115654
# Starting epoch number 39
# Loss for Training on Epoch 39 is 0.2013590782880783
# Starting epoch number 40
# Loss for Training on Epoch 40 is 0.200401172041893
# -------  Class: aeroplane        AP:   0.4496  -------
# -------  Class: bicycle          AP:   0.2068  -------
# -------  Class: bird             AP:   0.1719  -------
# -------  Class: boat             AP:   0.2173  -------
# -------  Class: bottle           AP:   0.1188  -------
# -------  Class: bus              AP:   0.1348  -------
# -------  Class: car              AP:   0.4537  -------
# -------  Class: cat              AP:   0.2797  -------
# -------  Class: chair            AP:   0.2829  -------
# -------  Class: cow              AP:   0.0877  -------
# -------  Class: diningtable      AP:   0.2008  -------
# -------  Class: dog              AP:   0.1935  -------
# -------  Class: horse            AP:   0.3139  -------
# -------  Class: motorbike        AP:   0.1899  -------
# -------  Class: person           AP:   0.6428  -------
# -------  Class: pottedplant      AP:   0.1193  -------
# -------  Class: sheep            AP:   0.1282  -------
# -------  Class: sofa             AP:   0.1870  -------
# -------  Class: train            AP:   0.2513  -------
# -------  Class: tvmonitor        AP:   0.1143  -------
# mAP: 0.2372
# Avg loss: 0.21143463775515556
# Evaluating classifier
# Mean Precision Score for Testing on Epoch 40 is 0.23722369653930206
# Starting epoch number 41
# Loss for Training on Epoch 41 is 0.20019017159938812
# Starting epoch number 42
# Loss for Training on Epoch 42 is 0.2007194608449936
# Starting epoch number 43
# Loss for Training on Epoch 43 is 0.1985216587781906
# Starting epoch number 44
# Loss for Training on Epoch 44 is 0.1973910629749298
# Starting epoch number 45
# Loss for Training on Epoch 45 is 0.19772927463054657
# -------  Class: aeroplane        AP:   0.4438  -------
# -------  Class: bicycle          AP:   0.2059  -------
# -------  Class: bird             AP:   0.1673  -------
# -------  Class: boat             AP:   0.2486  -------
# -------  Class: bottle           AP:   0.1184  -------
# -------  Class: bus              AP:   0.1475  -------
# -------  Class: car              AP:   0.4428  -------
# -------  Class: cat              AP:   0.3082  -------
# -------  Class: chair            AP:   0.2535  -------
# -------  Class: cow              AP:   0.0938  -------
# -------  Class: diningtable      AP:   0.1827  -------
# -------  Class: dog              AP:   0.1912  -------
# -------  Class: horse            AP:   0.3151  -------
# -------  Class: motorbike        AP:   0.1908  -------
# -------  Class: person           AP:   0.6508  -------
# -------  Class: pottedplant      AP:   0.1375  -------
# -------  Class: sheep            AP:   0.1403  -------
# -------  Class: sofa             AP:   0.1617  -------
# -------  Class: train            AP:   0.2276  -------
# -------  Class: tvmonitor        AP:   0.1053  -------
# mAP: 0.2366
# Avg loss: 0.2169406596571207
# Evaluating classifier
# Mean Precision Score for Testing on Epoch 45 is 0.23664384681029776
# Starting epoch number 46
# Loss for Training on Epoch 46 is 0.19689978659152985
# Starting epoch number 47
# Loss for Training on Epoch 47 is 0.19583232700824738
# Starting epoch number 48
# Loss for Training on Epoch 48 is 0.19379106163978577
# Starting epoch number 49
# Loss for Training on Epoch 49 is 0.19511869549751282
# Starting epoch number 50
# Loss for Training on Epoch 50 is 0.19567936658859253
# -------  Class: aeroplane        AP:   0.4537  -------
# -------  Class: bicycle          AP:   0.2114  -------
# -------  Class: bird             AP:   0.1635  -------
# -------  Class: boat             AP:   0.2330  -------
# -------  Class: bottle           AP:   0.1208  -------
# -------  Class: bus              AP:   0.1471  -------
# -------  Class: car              AP:   0.4497  -------
# -------  Class: cat              AP:   0.2640  -------
# -------  Class: chair            AP:   0.2760  -------
# -------  Class: cow              AP:   0.0905  -------
# -------  Class: diningtable      AP:   0.2059  -------
# -------  Class: dog              AP:   0.1923  -------
# -------  Class: horse            AP:   0.3257  -------
# -------  Class: motorbike        AP:   0.1668  -------
# -------  Class: person           AP:   0.6558  -------
# -------  Class: pottedplant      AP:   0.1222  -------
# -------  Class: sheep            AP:   0.1613  -------
# -------  Class: sofa             AP:   0.1920  -------
# -------  Class: train            AP:   0.2681  -------
# -------  Class: tvmonitor        AP:   0.1152  -------
# mAP: 0.2408
# Avg loss: 0.2173994593322277
# Evaluating classifier
# Mean Precision Score for Testing on Epoch 50 is 0.24075348037753236
# Starting epoch number 51
# Loss for Training on Epoch 51 is 0.19316323101520538
# Starting epoch number 52
# Loss for Training on Epoch 52 is 0.19258765876293182
# Starting epoch number 53
# Loss for Training on Epoch 53 is 0.19415418803691864
# Starting epoch number 54
# Loss for Training on Epoch 54 is 0.1937628537416458
# Starting epoch number 55
# Loss for Training on Epoch 55 is 0.19066350162029266
# -------  Class: aeroplane        AP:   0.4651  -------
# -------  Class: bicycle          AP:   0.2243  -------
# -------  Class: bird             AP:   0.1604  -------
# -------  Class: boat             AP:   0.2543  -------
# -------  Class: bottle           AP:   0.1318  -------
# -------  Class: bus              AP:   0.1503  -------
# -------  Class: car              AP:   0.4821  -------
# -------  Class: cat              AP:   0.3021  -------
# -------  Class: chair            AP:   0.3013  -------
# -------  Class: cow              AP:   0.0962  -------
# -------  Class: diningtable      AP:   0.2201  -------
# -------  Class: dog              AP:   0.2131  -------
# -------  Class: horse            AP:   0.3376  -------
# -------  Class: motorbike        AP:   0.1897  -------
# -------  Class: person           AP:   0.6755  -------
# -------  Class: pottedplant      AP:   0.1291  -------
# -------  Class: sheep            AP:   0.1665  -------
# -------  Class: sofa             AP:   0.2089  -------
# -------  Class: train            AP:   0.2816  -------
# -------  Class: tvmonitor        AP:   0.1612  -------
# mAP: 0.2576
# Avg loss: 0.20915787145495415
# Evaluating classifier
# Mean Precision Score for Testing on Epoch 55 is 0.2575563308651537
# Starting epoch number 56
# Loss for Training on Epoch 56 is 0.19532708823680878
# Starting epoch number 57
# Loss for Training on Epoch 57 is 0.19235928356647491
# Starting epoch number 58
# Loss for Training on Epoch 58 is 0.1897011399269104
# Starting epoch number 59
# Loss for Training on Epoch 59 is 0.19290080666542053
# Starting epoch number 60
# Loss for Training on Epoch 60 is 0.18954037129878998
# -------  Class: aeroplane        AP:   0.4588  -------
# -------  Class: bicycle          AP:   0.2505  -------
# -------  Class: bird             AP:   0.1566  -------
# -------  Class: boat             AP:   0.2447  -------
# -------  Class: bottle           AP:   0.1382  -------
# -------  Class: bus              AP:   0.1385  -------
# -------  Class: car              AP:   0.4856  -------
# -------  Class: cat              AP:   0.3237  -------
# -------  Class: chair            AP:   0.3113  -------
# -------  Class: cow              AP:   0.1039  -------
# -------  Class: diningtable      AP:   0.2391  -------
# -------  Class: dog              AP:   0.2246  -------
# -------  Class: horse            AP:   0.3569  -------
# -------  Class: motorbike        AP:   0.2061  -------
# -------  Class: person           AP:   0.6888  -------
# -------  Class: pottedplant      AP:   0.1287  -------
# -------  Class: sheep            AP:   0.1657  -------
# -------  Class: sofa             AP:   0.2013  -------
# -------  Class: train            AP:   0.2875  -------
# -------  Class: tvmonitor        AP:   0.1431  -------
# mAP: 0.2627
# Avg loss: 0.2135823979973793
# Evaluating classifier
# Mean Precision Score for Testing on Epoch 60 is 0.26267272209785786
# Starting epoch number 61
# Loss for Training on Epoch 61 is 0.18707966804504395
# Starting epoch number 62
# Loss for Training on Epoch 62 is 0.18973422050476074
# Starting epoch number 63
# Loss for Training on Epoch 63 is 0.19083575904369354
# Starting epoch number 64
# Loss for Training on Epoch 64 is 0.18842685222625732
# Starting epoch number 65
# Loss for Training on Epoch 65 is 0.18702049553394318
# -------  Class: aeroplane        AP:   0.4463  -------
# -------  Class: bicycle          AP:   0.2711  -------
# -------  Class: bird             AP:   0.1547  -------
# -------  Class: boat             AP:   0.2631  -------
# -------  Class: bottle           AP:   0.1344  -------
# -------  Class: bus              AP:   0.1480  -------
# -------  Class: car              AP:   0.4975  -------
# -------  Class: cat              AP:   0.3284  -------
# -------  Class: chair            AP:   0.3616  -------
# -------  Class: cow              AP:   0.1081  -------
# -------  Class: diningtable      AP:   0.2795  -------
# -------  Class: dog              AP:   0.2312  -------
# -------  Class: horse            AP:   0.4045  -------
# -------  Class: motorbike        AP:   0.2012  -------
# -------  Class: person           AP:   0.6906  -------
# -------  Class: pottedplant      AP:   0.1327  -------
# -------  Class: sheep            AP:   0.1831  -------
# -------  Class: sofa             AP:   0.2463  -------
# -------  Class: train            AP:   0.3211  -------
# -------  Class: tvmonitor        AP:   0.2018  -------
# mAP: 0.2803
# Avg loss: 0.20457245521247386
# Evaluating classifier
# Mean Precision Score for Testing on Epoch 65 is 0.2802572255054127
# Starting epoch number 66
# Loss for Training on Epoch 66 is 0.18776561319828033
# Starting epoch number 67
# Loss for Training on Epoch 67 is 0.18851695954799652
# Starting epoch number 68
# Loss for Training on Epoch 68 is 0.18737122416496277
# Starting epoch number 69
# Loss for Training on Epoch 69 is 0.18561027944087982
# Starting epoch number 70
# Loss for Training on Epoch 70 is 0.18689033389091492
# -------  Class: aeroplane        AP:   0.4819  -------
# -------  Class: bicycle          AP:   0.2547  -------
# -------  Class: bird             AP:   0.1608  -------
# -------  Class: boat             AP:   0.2346  -------
# -------  Class: bottle           AP:   0.1193  -------
# -------  Class: bus              AP:   0.1330  -------
# -------  Class: car              AP:   0.5109  -------
# -------  Class: cat              AP:   0.3282  -------
# -------  Class: chair            AP:   0.3585  -------
# -------  Class: cow              AP:   0.1072  -------
# -------  Class: diningtable      AP:   0.3001  -------
# -------  Class: dog              AP:   0.2419  -------
# -------  Class: horse            AP:   0.4095  -------
# -------  Class: motorbike        AP:   0.2126  -------
# -------  Class: person           AP:   0.7100  -------
# -------  Class: pottedplant      AP:   0.1278  -------
# -------  Class: sheep            AP:   0.1923  -------
# -------  Class: sofa             AP:   0.2514  -------
# -------  Class: train            AP:   0.3903  -------
# -------  Class: tvmonitor        AP:   0.1635  -------
# mAP: 0.2844
# Avg loss: 0.2074894394725561
# Evaluating classifier
# Mean Precision Score for Testing on Epoch 70 is 0.2844266721176155
# Starting epoch number 71
# Loss for Training on Epoch 71 is 0.18394674360752106
# Starting epoch number 72
# Loss for Training on Epoch 72 is 0.18489623069763184
# Starting epoch number 73
# Loss for Training on Epoch 73 is 0.18683229386806488
# Starting epoch number 74
# Loss for Training on Epoch 74 is 0.18493656814098358
# Starting epoch number 75
# Loss for Training on Epoch 75 is 0.1843491643667221
# -------  Class: aeroplane        AP:   0.4725  -------
# -------  Class: bicycle          AP:   0.2907  -------
# -------  Class: bird             AP:   0.1547  -------
# -------  Class: boat             AP:   0.2420  -------
# -------  Class: bottle           AP:   0.1560  -------
# -------  Class: bus              AP:   0.1702  -------
# -------  Class: car              AP:   0.5185  -------
# -------  Class: cat              AP:   0.3323  -------
# -------  Class: chair            AP:   0.3678  -------
# -------  Class: cow              AP:   0.1223  -------
# -------  Class: diningtable      AP:   0.2980  -------
# -------  Class: dog              AP:   0.2403  -------
# -------  Class: horse            AP:   0.4026  -------
# -------  Class: motorbike        AP:   0.2504  -------
# -------  Class: person           AP:   0.7120  -------
# -------  Class: pottedplant      AP:   0.1446  -------
# -------  Class: sheep            AP:   0.2062  -------
# -------  Class: sofa             AP:   0.2647  -------
# -------  Class: train            AP:   0.3376  -------
# -------  Class: tvmonitor        AP:   0.2434  -------
# mAP: 0.2963
# Avg loss: 0.20942925848066807
# Evaluating classifier
# Mean Precision Score for Testing on Epoch 75 is 0.29633085148471855
# Starting epoch number 76
# Loss for Training on Epoch 76 is 0.18152287602424622
# Starting epoch number 77
# Loss for Training on Epoch 77 is 0.18331784009933472
# Starting epoch number 78
# Loss for Training on Epoch 78 is 0.18231213092803955
# Starting epoch number 79
# Loss for Training on Epoch 79 is 0.18242262303829193
# Starting epoch number 80
# Loss for Training on Epoch 80 is 0.1813705414533615
# -------  Class: aeroplane        AP:   0.4603  -------
# -------  Class: bicycle          AP:   0.2448  -------
# -------  Class: bird             AP:   0.1579  -------
# -------  Class: boat             AP:   0.2346  -------
# -------  Class: bottle           AP:   0.1289  -------
# -------  Class: bus              AP:   0.1724  -------
# -------  Class: car              AP:   0.4742  -------
# -------  Class: cat              AP:   0.3462  -------
# -------  Class: chair            AP:   0.3668  -------
# -------  Class: cow              AP:   0.1298  -------
# -------  Class: diningtable      AP:   0.2899  -------
# -------  Class: dog              AP:   0.2216  -------
# -------  Class: horse            AP:   0.4176  -------
# -------  Class: motorbike        AP:   0.2302  -------
# -------  Class: person           AP:   0.7122  -------
# -------  Class: pottedplant      AP:   0.1393  -------
# -------  Class: sheep            AP:   0.1843  -------
# -------  Class: sofa             AP:   0.2561  -------
# -------  Class: train            AP:   0.2960  -------
# -------  Class: tvmonitor        AP:   0.2150  -------
# mAP: 0.2839
# Avg loss: 0.2078655742108822
# Evaluating classifier
# Mean Precision Score for Testing on Epoch 80 is 0.2839139517298519
# Starting epoch number 81
# Loss for Training on Epoch 81 is 0.18211166560649872
# Starting epoch number 82
# Loss for Training on Epoch 82 is 0.18211044371128082
# Starting epoch number 83
# Loss for Training on Epoch 83 is 0.1816016286611557
# Starting epoch number 84
# Loss for Training on Epoch 84 is 0.18191732466220856
# Starting epoch number 85
# Loss for Training on Epoch 85 is 0.17816613614559174
# -------  Class: aeroplane        AP:   0.4717  -------
# -------  Class: bicycle          AP:   0.2957  -------
# -------  Class: bird             AP:   0.1744  -------
# -------  Class: boat             AP:   0.2625  -------
# -------  Class: bottle           AP:   0.1563  -------
# -------  Class: bus              AP:   0.1750  -------
# -------  Class: car              AP:   0.5214  -------
# -------  Class: cat              AP:   0.3552  -------
# -------  Class: chair            AP:   0.3840  -------
# -------  Class: cow              AP:   0.1264  -------
# -------  Class: diningtable      AP:   0.3066  -------
# -------  Class: dog              AP:   0.2561  -------
# -------  Class: horse            AP:   0.4286  -------
# -------  Class: motorbike        AP:   0.3026  -------
# -------  Class: person           AP:   0.7146  -------
# -------  Class: pottedplant      AP:   0.1570  -------
# -------  Class: sheep            AP:   0.2107  -------
# -------  Class: sofa             AP:   0.2503  -------
# -------  Class: train            AP:   0.3558  -------
# -------  Class: tvmonitor        AP:   0.2611  -------
# mAP: 0.3083
# Avg loss: 0.20652119256556034
# Evaluating classifier
# Mean Precision Score for Testing on Epoch 85 is 0.3083012771704571
# Starting epoch number 86
# Loss for Training on Epoch 86 is 0.1821986585855484
# Starting epoch number 87
# Loss for Training on Epoch 87 is 0.18022964894771576
# Starting epoch number 88
# Loss for Training on Epoch 88 is 0.1807336062192917
# Starting epoch number 89
# Loss for Training on Epoch 89 is 0.1799984574317932
# Starting epoch number 90
# Loss for Training on Epoch 90 is 0.17741695046424866
# -------  Class: aeroplane        AP:   0.4862  -------
# -------  Class: bicycle          AP:   0.2821  -------
# -------  Class: bird             AP:   0.1805  -------
# -------  Class: boat             AP:   0.2774  -------
# -------  Class: bottle           AP:   0.1461  -------
# -------  Class: bus              AP:   0.1615  -------
# -------  Class: car              AP:   0.5185  -------
# -------  Class: cat              AP:   0.3533  -------
# -------  Class: chair            AP:   0.4157  -------
# -------  Class: cow              AP:   0.1319  -------
# -------  Class: diningtable      AP:   0.3341  -------
# -------  Class: dog              AP:   0.2379  -------
# -------  Class: horse            AP:   0.4577  -------
# -------  Class: motorbike        AP:   0.3427  -------
# -------  Class: person           AP:   0.7126  -------
# -------  Class: pottedplant      AP:   0.1574  -------
# -------  Class: sheep            AP:   0.2051  -------
# -------  Class: sofa             AP:   0.2709  -------
# -------  Class: train            AP:   0.3625  -------
# -------  Class: tvmonitor        AP:   0.2487  -------
# mAP: 0.3141
# Avg loss: 0.2092556606978178
# Evaluating classifier
# Mean Precision Score for Testing on Epoch 90 is 0.31413598076723714
# Starting epoch number 91
# Loss for Training on Epoch 91 is 0.17547360062599182
# Starting epoch number 92
# Loss for Training on Epoch 92 is 0.1761844903230667
# Starting epoch number 93
# Loss for Training on Epoch 93 is 0.17827674746513367
# Starting epoch number 94
# Loss for Training on Epoch 94 is 0.1785983443260193
# Starting epoch number 95
# Loss for Training on Epoch 95 is 0.1772831827402115
# -------  Class: aeroplane        AP:   0.4890  -------
# -------  Class: bicycle          AP:   0.2761  -------
# -------  Class: bird             AP:   0.1665  -------
# -------  Class: boat             AP:   0.2826  -------
# -------  Class: bottle           AP:   0.1627  -------
# -------  Class: bus              AP:   0.1887  -------
# -------  Class: car              AP:   0.5311  -------
# -------  Class: cat              AP:   0.3418  -------
# -------  Class: chair            AP:   0.4110  -------
# -------  Class: cow              AP:   0.1330  -------
# -------  Class: diningtable      AP:   0.3257  -------
# -------  Class: dog              AP:   0.2649  -------
# -------  Class: horse            AP:   0.4289  -------
# -------  Class: motorbike        AP:   0.3532  -------
# -------  Class: person           AP:   0.7104  -------
# -------  Class: pottedplant      AP:   0.1588  -------
# -------  Class: sheep            AP:   0.2172  -------
# -------  Class: sofa             AP:   0.2753  -------
# -------  Class: train            AP:   0.4001  -------
# -------  Class: tvmonitor        AP:   0.2798  -------
# mAP: 0.3198
# Avg loss: 0.20523428730666637
# Evaluating classifier
# Mean Precision Score for Testing on Epoch 95 is 0.3198310982043942
# Starting epoch number 96
# Loss for Training on Epoch 96 is 0.17505145072937012
# Starting epoch number 97
# Loss for Training on Epoch 97 is 0.1759171038866043
# Starting epoch number 98
# Loss for Training on Epoch 98 is 0.17802797257900238
# Starting epoch number 99
# Loss for Training on Epoch 99 is 0.17657940089702606
# Starting epoch number 100
# Loss for Training on Epoch 100 is 0.17492027580738068
# -------  Class: aeroplane        AP:   0.5050  -------
# -------  Class: bicycle          AP:   0.2982  -------
# -------  Class: bird             AP:   0.1916  -------
# -------  Class: boat             AP:   0.2551  -------
# -------  Class: bottle           AP:   0.1487  -------
# -------  Class: bus              AP:   0.1855  -------
# -------  Class: car              AP:   0.5287  -------
# -------  Class: cat              AP:   0.3687  -------
# -------  Class: chair            AP:   0.3871  -------
# -------  Class: cow              AP:   0.1421  -------
# -------  Class: diningtable      AP:   0.3105  -------
# -------  Class: dog              AP:   0.2512  -------
# -------  Class: horse            AP:   0.4609  -------
# -------  Class: motorbike        AP:   0.3801  -------
# -------  Class: person           AP:   0.7259  -------
# -------  Class: pottedplant      AP:   0.1704  -------
# -------  Class: sheep            AP:   0.1918  -------
# -------  Class: sofa             AP:   0.2368  -------
# -------  Class: train            AP:   0.4125  -------
# -------  Class: tvmonitor        AP:   0.2528  -------
# mAP: 0.3202
# Avg loss: 0.2003836877644062
# Evaluating classifier
# Mean Precision Score for Testing on Epoch 100 is 0.32018237200676947
